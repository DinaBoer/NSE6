# %% [markdown]
# Imports

# %%
# imports
from esdl import esdl
from esdl.esdl_handler import EnergySystemHandler
import pandas as pd
import numpy as np
import numpy_financial as npf
from decimal import Decimal, ROUND_HALF_UP
import matplotlib.pyplot as plt

# %%
# This imports all input variables from ET_input_data.py
from HT_input_data import *

# import all data from ESDL
from NSE_get_data_from_ESDL import *

# Make sure to select the scenario (e.g., pessimistic, most likely, optimistic) in the NSE_get_data_from_ESDL file
# Check the scenario that is selected 

print(f'Current scenario = {current_scenario}')
# Out:
# XMLResource loading...
# All variables saved to NSE_get_data_from_ESDL.pkl
# Current scenario = ['most_likely']

# %% [markdown]
# Set up calendar_year, business_case_year, operations_years, and decommissioning_years lists

# %%
# to do sensitivity analysis on lifetime_investment we need to be able to recalculate calendar_year_list, operation_years_list etc. 

def construct_calendar_year_list(lifetime_investment_variable):
    
    year_construction_start = tender_year + 1
    year_start_operation = year_construction_start + duration_construction
    year_decommissioning_start = (year_start_operation + int(Decimal(lifetime_investment_variable).to_integral_value(rounding=ROUND_HALF_UP)))
    # use Decimal.to_integral_value to prevent python to round to nearest even integral
    # this method uses the same rounding method as Excel (i.e., x.5 is rounded up)

    calendar_year_list = list(range(tender_year, year_decommissioning_start + duration_decommissioning))  

    return calendar_year_list

def construct_business_case_year_list(lifetime_investment_variable):

    business_case_year_list = np.array(range(len(construct_calendar_year_list(lifetime_investment_variable))))
    
    return business_case_year_list

def construct_operations_years_list(lifetime_investment_variable):

    year_construction_start = tender_year + 1
    year_start_operation = year_construction_start + duration_construction

    operations_years_list = list(range(year_start_operation, year_start_operation + int(Decimal(lifetime_investment_variable).to_integral_value(rounding=ROUND_HALF_UP))))
    
    return operations_years_list

def construct_decomissioning_years_list(lifetime_investment_variable):

    year_construction_start = tender_year + 1
    year_start_operation = year_construction_start + duration_construction
    year_decommissioning_start = year_start_operation + int(Decimal(lifetime_investment_variable).to_integral_value(rounding=ROUND_HALF_UP))

    decomissioning_years_list = list(range(year_decommissioning_start, year_decommissioning_start + duration_decommissioning))

    return decomissioning_years_list

# %% [markdown]
# Start business case analysis

# %% [markdown]
# Construction phase

# %%
def construction_phase(pipeline_capex_variable, compression_capex_variable, inflation_variable, lifetime_investment_variable, pipeline_length_variable):
    ''' This function creates a dataframe that contains all cashflows in the construction phase'''

    # set up df
    df_construction_phase = pd.DataFrame(columns=construct_calendar_year_list(lifetime_investment_variable))
    df_construction_phase.columns.name = "construction_phase"
    
    # made a separate function for the pipeline capex and the compressor capex, 
    # because this way the pipeline length can be used as a variable for the pipeline capex, while it is not required for the compression capex.
    # and a reinvestment is added for the compressor
    
    #### function to calculate CAPEX
    def calculate_capex(capex_variable):
        ''' This function calculates the yearly capex for each of the construction years'''
        capex_list = []
    
        for x in construct_calendar_year_list(lifetime_investment_variable): 
            if x in construction_years_list:
                capex_list.append(-capex_variable*pipeline_length_variable/duration_construction)
            else: 
                capex_list.append(0)

        return capex_list
    
    # add CAPEX to df
    df_construction_phase.loc['pipeline_capex'] = calculate_capex(pipeline_capex_variable)

    def calculate_compressor_capex():
        '''This function calculates the yearly compression capex for each of the construction years'''
        capex_list = []

        for i,x in enumerate(construct_calendar_year_list(lifetime_investment_variable)):
            if x in construction_years_list:
                capex_list.append(-compression_capex_variable/duration_construction)

            # check if in operation years and if the atr plant is depricated
            # it is assumed that the re-investment takes place in one year, and the construction is also in 1 year
            # investment is made in the year before it has to be operational, so in year (x+1) it should be deprecated
            elif (x+1) in construct_operations_years_list(lifetime_investment_variable) and (x+1 - construct_operations_years_list(lifetime_investment_variable)[0]) % HT_compressor_lifetime == 0:
                capex_list.append(-compression_capex_variable * ((1+inflation_variable)**i))

            else:
                capex_list.append(0)

        return capex_list
    
    # add CAPEX to df   
    df_construction_phase.loc['compression_capex'] = calculate_compressor_capex()

    #### function - resale value
    def resale_value():
        '''This function calculates the resale value of the compressor if the business case length is not equal to the compressor lifetime. 
           This is necessary because compressor lifetime is lower than infrastructure lifetime and therefore re-investments are required
           The re-investments occur every 15 year, but in reality you would not invest in a compressor if the business case is nearing the end, so to adjust for this we use the resale value'''

        resale_list = []
        reinvestment_counter = 0
                
        yearly_depreciation = compression_capex_variable * ((1+inflation_variable)**(tender_year-2025)) / HT_compressor_depreciation
        # Tender year for base case =2025. If the tender year is later (for example to determine bc in the future) the capex of the boiler needs to be corrected for inflation 
        # because we do not have 2040/2050 data. 
        
         
        for x in construct_calendar_year_list(lifetime_investment_variable):
            
            if (x+1) in construct_operations_years_list(lifetime_investment_variable) and \
               (x+1 - construct_operations_years_list(lifetime_investment_variable)[0]) % HT_compressor_lifetime == 0 and \
               ((x+1) > construct_operations_years_list(lifetime_investment_variable)[0]):
                          
                reinvestment_counter += 1 
                reinvestment_year = x
                yearly_depreciation = compression_capex_variable * ((1+inflation_variable)**(reinvestment_year-tender_year)) / HT_compressor_depreciation
                resale_list.append(0)

            # resale occurs in first year of decommissioning
            # resale occurs when business case length (i.e., lifetime_investment_variable) is larger than compressor deprciation * reinvestment +1 (+1 to take original investment into account)
            elif x == construct_decomissioning_years_list(lifetime_investment_variable)[0] and lifetime_investment_variable < ((reinvestment_counter + 1) * HT_compressor_depreciation):
                resale_list.append((compression_capex_variable * ((1+inflation_variable)**(reinvestment_year-tender_year)) - (yearly_depreciation * (construct_decomissioning_years_list(lifetime_investment_variable)[0]-reinvestment_year))))

            else:
                resale_list.append(0)

        return  resale_list
    

    # add resale value to df    
    df_construction_phase.loc['compression_capex'] = df_construction_phase.loc['compression_capex'] + resale_value()

    # calculate total cashflow from investments then add to df
    # because there are multiple CAPEX cash flows, the columns need to be summed to obtain the total CAPEX cash flow
    total_cashflow_investment = df_construction_phase.sum(axis=0)
    df_construction_phase.loc['total_cashflow_investment'] = total_cashflow_investment
    
    return df_construction_phase

# %%
construction_phase(pipeline_capex, compression_capex, HT_inflation, HT_lifetime, pipeline_distance).style.format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2b83f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >construction_phase</th>
#       <th id="T_2b83f_level0_col0" class="col_heading level0 col0" >2045</th>
#       <th id="T_2b83f_level0_col1" class="col_heading level0 col1" >2046</th>
#       <th id="T_2b83f_level0_col2" class="col_heading level0 col2" >2047</th>
#       <th id="T_2b83f_level0_col3" class="col_heading level0 col3" >2048</th>
#       <th id="T_2b83f_level0_col4" class="col_heading level0 col4" >2049</th>
#       <th id="T_2b83f_level0_col5" class="col_heading level0 col5" >2050</th>
#       <th id="T_2b83f_level0_col6" class="col_heading level0 col6" >2051</th>
#       <th id="T_2b83f_level0_col7" class="col_heading level0 col7" >2052</th>
#       <th id="T_2b83f_level0_col8" class="col_heading level0 col8" >2053</th>
#       <th id="T_2b83f_level0_col9" class="col_heading level0 col9" >2054</th>
#       <th id="T_2b83f_level0_col10" class="col_heading level0 col10" >2055</th>
#       <th id="T_2b83f_level0_col11" class="col_heading level0 col11" >2056</th>
#       <th id="T_2b83f_level0_col12" class="col_heading level0 col12" >2057</th>
#       <th id="T_2b83f_level0_col13" class="col_heading level0 col13" >2058</th>
#       <th id="T_2b83f_level0_col14" class="col_heading level0 col14" >2059</th>
#       <th id="T_2b83f_level0_col15" class="col_heading level0 col15" >2060</th>
#       <th id="T_2b83f_level0_col16" class="col_heading level0 col16" >2061</th>
#       <th id="T_2b83f_level0_col17" class="col_heading level0 col17" >2062</th>
#       <th id="T_2b83f_level0_col18" class="col_heading level0 col18" >2063</th>
#       <th id="T_2b83f_level0_col19" class="col_heading level0 col19" >2064</th>
#       <th id="T_2b83f_level0_col20" class="col_heading level0 col20" >2065</th>
#       <th id="T_2b83f_level0_col21" class="col_heading level0 col21" >2066</th>
#       <th id="T_2b83f_level0_col22" class="col_heading level0 col22" >2067</th>
#       <th id="T_2b83f_level0_col23" class="col_heading level0 col23" >2068</th>
#       <th id="T_2b83f_level0_col24" class="col_heading level0 col24" >2069</th>
#       <th id="T_2b83f_level0_col25" class="col_heading level0 col25" >2070</th>
#       <th id="T_2b83f_level0_col26" class="col_heading level0 col26" >2071</th>
#       <th id="T_2b83f_level0_col27" class="col_heading level0 col27" >2072</th>
#       <th id="T_2b83f_level0_col28" class="col_heading level0 col28" >2073</th>
#       <th id="T_2b83f_level0_col29" class="col_heading level0 col29" >2074</th>
#       <th id="T_2b83f_level0_col30" class="col_heading level0 col30" >2075</th>
#       <th id="T_2b83f_level0_col31" class="col_heading level0 col31" >2076</th>
#       <th id="T_2b83f_level0_col32" class="col_heading level0 col32" >2077</th>
#       <th id="T_2b83f_level0_col33" class="col_heading level0 col33" >2078</th>
#       <th id="T_2b83f_level0_col34" class="col_heading level0 col34" >2079</th>
#       <th id="T_2b83f_level0_col35" class="col_heading level0 col35" >2080</th>
#       <th id="T_2b83f_level0_col36" class="col_heading level0 col36" >2081</th>
#       <th id="T_2b83f_level0_col37" class="col_heading level0 col37" >2082</th>
#       <th id="T_2b83f_level0_col38" class="col_heading level0 col38" >2083</th>
#       <th id="T_2b83f_level0_col39" class="col_heading level0 col39" >2084</th>
#       <th id="T_2b83f_level0_col40" class="col_heading level0 col40" >2085</th>
#       <th id="T_2b83f_level0_col41" class="col_heading level0 col41" >2086</th>
#       <th id="T_2b83f_level0_col42" class="col_heading level0 col42" >2087</th>
#       <th id="T_2b83f_level0_col43" class="col_heading level0 col43" >2088</th>
#       <th id="T_2b83f_level0_col44" class="col_heading level0 col44" >2089</th>
#       <th id="T_2b83f_level0_col45" class="col_heading level0 col45" >2090</th>
#       <th id="T_2b83f_level0_col46" class="col_heading level0 col46" >2091</th>
#       <th id="T_2b83f_level0_col47" class="col_heading level0 col47" >2092</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b83f_level0_row0" class="row_heading level0 row0" >pipeline_capex</th>
#       <td id="T_2b83f_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_2b83f_row0_col1" class="data row0 col1" >-290.04</td>
#       <td id="T_2b83f_row0_col2" class="data row0 col2" >-290.04</td>
#       <td id="T_2b83f_row0_col3" class="data row0 col3" >-290.04</td>
#       <td id="T_2b83f_row0_col4" class="data row0 col4" >-290.04</td>
#       <td id="T_2b83f_row0_col5" class="data row0 col5" >-290.04</td>
#       <td id="T_2b83f_row0_col6" class="data row0 col6" >0.00</td>
#       <td id="T_2b83f_row0_col7" class="data row0 col7" >0.00</td>
#       <td id="T_2b83f_row0_col8" class="data row0 col8" >0.00</td>
#       <td id="T_2b83f_row0_col9" class="data row0 col9" >0.00</td>
#       <td id="T_2b83f_row0_col10" class="data row0 col10" >0.00</td>
#       <td id="T_2b83f_row0_col11" class="data row0 col11" >0.00</td>
#       <td id="T_2b83f_row0_col12" class="data row0 col12" >0.00</td>
#       <td id="T_2b83f_row0_col13" class="data row0 col13" >0.00</td>
#       <td id="T_2b83f_row0_col14" class="data row0 col14" >0.00</td>
#       <td id="T_2b83f_row0_col15" class="data row0 col15" >0.00</td>
#       <td id="T_2b83f_row0_col16" class="data row0 col16" >0.00</td>
#       <td id="T_2b83f_row0_col17" class="data row0 col17" >0.00</td>
#       <td id="T_2b83f_row0_col18" class="data row0 col18" >0.00</td>
#       <td id="T_2b83f_row0_col19" class="data row0 col19" >0.00</td>
#       <td id="T_2b83f_row0_col20" class="data row0 col20" >0.00</td>
#       <td id="T_2b83f_row0_col21" class="data row0 col21" >0.00</td>
#       <td id="T_2b83f_row0_col22" class="data row0 col22" >0.00</td>
#       <td id="T_2b83f_row0_col23" class="data row0 col23" >0.00</td>
#       <td id="T_2b83f_row0_col24" class="data row0 col24" >0.00</td>
#       <td id="T_2b83f_row0_col25" class="data row0 col25" >0.00</td>
#       <td id="T_2b83f_row0_col26" class="data row0 col26" >0.00</td>
#       <td id="T_2b83f_row0_col27" class="data row0 col27" >0.00</td>
#       <td id="T_2b83f_row0_col28" class="data row0 col28" >0.00</td>
#       <td id="T_2b83f_row0_col29" class="data row0 col29" >0.00</td>
#       <td id="T_2b83f_row0_col30" class="data row0 col30" >0.00</td>
#       <td id="T_2b83f_row0_col31" class="data row0 col31" >0.00</td>
#       <td id="T_2b83f_row0_col32" class="data row0 col32" >0.00</td>
#       <td id="T_2b83f_row0_col33" class="data row0 col33" >0.00</td>
#       <td id="T_2b83f_row0_col34" class="data row0 col34" >0.00</td>
#       <td id="T_2b83f_row0_col35" class="data row0 col35" >0.00</td>
#       <td id="T_2b83f_row0_col36" class="data row0 col36" >0.00</td>
#       <td id="T_2b83f_row0_col37" class="data row0 col37" >0.00</td>
#       <td id="T_2b83f_row0_col38" class="data row0 col38" >0.00</td>
#       <td id="T_2b83f_row0_col39" class="data row0 col39" >0.00</td>
#       <td id="T_2b83f_row0_col40" class="data row0 col40" >0.00</td>
#       <td id="T_2b83f_row0_col41" class="data row0 col41" >0.00</td>
#       <td id="T_2b83f_row0_col42" class="data row0 col42" >0.00</td>
#       <td id="T_2b83f_row0_col43" class="data row0 col43" >0.00</td>
#       <td id="T_2b83f_row0_col44" class="data row0 col44" >0.00</td>
#       <td id="T_2b83f_row0_col45" class="data row0 col45" >0.00</td>
#       <td id="T_2b83f_row0_col46" class="data row0 col46" >0.00</td>
#       <td id="T_2b83f_row0_col47" class="data row0 col47" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_2b83f_level0_row1" class="row_heading level0 row1" >compression_capex</th>
#       <td id="T_2b83f_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_2b83f_row1_col1" class="data row1 col1" >-233.12</td>
#       <td id="T_2b83f_row1_col2" class="data row1 col2" >-233.12</td>
#       <td id="T_2b83f_row1_col3" class="data row1 col3" >-233.12</td>
#       <td id="T_2b83f_row1_col4" class="data row1 col4" >-233.12</td>
#       <td id="T_2b83f_row1_col5" class="data row1 col5" >-233.12</td>
#       <td id="T_2b83f_row1_col6" class="data row1 col6" >0.00</td>
#       <td id="T_2

# %% [markdown]
# Operational phase

# %%
def operational_phase(df_opex_variable,
                      df_opex_compressor_variable,
                      df_compressor_power_costs_variable,
                      inflation_variable,
                      df_revenues_transport_tariffs,
                      df_revenues_connection_tariffs,
                      lifetime_investment_variable,
                      pipeline_length_variable):
    ''' This function creates a dataframe that contains all cashflows in the operational phase'''

    #construct df
    df_operational_phase = pd.DataFrame(columns=construct_calendar_year_list(lifetime_investment_variable))
    df_operational_phase.columns.name = "operational_phase"
    
    #calculate opex of cables based on pipeline length
    df_opex_variable.loc['opex'] = df_opex_variable.loc['opex_km'] * pipeline_length_variable

    #### function
    def calculate_opex(df_opex_variable, variable_name):
        '''This function calculates the opex for all the operational years'''

        opex_list = []

        for i,x in enumerate(construct_calendar_year_list(lifetime_investment_variable)):

            if x in construct_operations_years_list(lifetime_investment_variable):
                opex_list.append(-df_opex_variable.loc[variable_name,x]*((1 + inflation_variable)**i))

            else:
                opex_list.append(0)

        return opex_list
    
    # add opex to df
    df_operational_phase.loc['opex'] = calculate_opex(df_opex_variable, 'opex')
    df_operational_phase.loc['opex_compressor'] = calculate_opex(df_opex_compressor_variable, 'opex_compressor')
    df_operational_phase.loc['compressor_power_consumption'] = calculate_opex(df_compressor_power_costs_variable, 'compressor_power_costs')

    # calculate total outflow opex and add to df
    total_outflow_opex = (np.array(calculate_opex(df_opex_variable, 'opex')) + 
                          np.array(calculate_opex(df_opex_compressor_variable, 'opex_compressor')) + 
                          np.array(calculate_opex(df_compressor_power_costs_variable, 'compressor_power_costs')))
    df_operational_phase.loc['total_outflow_opex'] = total_outflow_opex
    
    #### function 
    def revenues_connection_tariffs(inflation_variable, variable_name):
        ''' This function calculates the revenues from transport and connection tariffs for all years'''

        revenues_connection_tariffs_list = []

        for i, x in enumerate(construct_calendar_year_list(lifetime_investment_variable)):

            if x in construct_operations_years_list(lifetime_investment_variable):
                revenues_connection_tariffs_list.append(df_revenues_connection_tariffs.loc[variable_name,x]*((1 + inflation_variable)**i))
            else: 
                revenues_connection_tariffs_list.append(0)

        return revenues_connection_tariffs_list  
    
    # add connection tariff revenues to df
    df_operational_phase.loc['revenues_connection_tariffs'] = revenues_connection_tariffs(inflation_variable, 'revenue_connections')

    #### function 
    def revenues_transport_tariffs(inflation_variable, variable_name):
        ''' This function calculates the electricity revenues to market for all the operationl years'''

        revenues_transport_tariffs_list = []

        for i, x in enumerate(construct_calendar_year_list(lifetime_investment_variable)):
            
            if x in construct_operations_years_list(lifetime_investment_variable):
                revenues_transport_tariffs_list.append(df_revenues_transport_tariffs.loc[variable_name,x]*((1 + inflation_variable)**i))
            else: 
                revenues_transport_tariffs_list.append(0)

        return revenues_transport_tariffs_list   

    # add electricity revenues from market to df
    df_operational_phase.loc['revenues_transport_tariffs'] = revenues_transport_tariffs(inflation_variable, 'revenue_transport')

    # calculate total revenues and add to df 
    #total_revenues_opex = revenues_connection_tariffs(inflation_variable, 'revenue_connections') + np.array(revenues_transport_tariffs(inflation_variable))
    revenues_transport_tariff = np.array(revenues_transport_tariffs(inflation_variable, 'revenue_transport'))
    df_operational_phase.loc['total_revenues_opex'] = revenues_connection_tariffs(inflation_variable, 'revenue_connections') + revenues_transport_tariff
    total_revenues_opex = df_operational_phase.loc['total_revenues_opex'].tolist()

    # calculate net cashflow from operation (=EBITDA) and add to df
    net_cashflow_operation = total_outflow_opex + total_revenues_opex
    df_operational_phase.loc['net_cashflow_operations'] = net_cashflow_operation
    
    return df_operational_phase

# %%
operational_phase(df_HT_opex,df_opex_compressor, df_HT_compressor_power_costs, HT_inflation,df_HT_revenues_transport,df_HT_revenues_connections,HT_lifetime,pipeline_distance).style.format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_af7f7">
#   <thead>
#     <tr>
#       <th class="index_name level0" >operational_phase</th>
#       <th id="T_af7f7_level0_col0" class="col_heading level0 col0" >2045</th>
#       <th id="T_af7f7_level0_col1" class="col_heading level0 col1" >2046</th>
#       <th id="T_af7f7_level0_col2" class="col_heading level0 col2" >2047</th>
#       <th id="T_af7f7_level0_col3" class="col_heading level0 col3" >2048</th>
#       <th id="T_af7f7_level0_col4" class="col_heading level0 col4" >2049</th>
#       <th id="T_af7f7_level0_col5" class="col_heading level0 col5" >2050</th>
#       <th id="T_af7f7_level0_col6" class="col_heading level0 col6" >2051</th>
#       <th id="T_af7f7_level0_col7" class="col_heading level0 col7" >2052</th>
#       <th id="T_af7f7_level0_col8" class="col_heading level0 col8" >2053</th>
#       <th id="T_af7f7_level0_col9" class="col_heading level0 col9" >2054</th>
#       <th id="T_af7f7_level0_col10" class="col_heading level0 col10" >2055</th>
#       <th id="T_af7f7_level0_col11" class="col_heading level0 col11" >2056</th>
#       <th id="T_af7f7_level0_col12" class="col_heading level0 col12" >2057</th>
#       <th id="T_af7f7_level0_col13" class="col_heading level0 col13" >2058</th>
#       <th id="T_af7f7_level0_col14" class="col_heading level0 col14" >2059</th>
#       <th id="T_af7f7_level0_col15" class="col_heading level0 col15" >2060</th>
#       <th id="T_af7f7_level0_col16" class="col_heading level0 col16" >2061</th>
#       <th id="T_af7f7_level0_col17" class="col_heading level0 col17" >2062</th>
#       <th id="T_af7f7_level0_col18" class="col_heading level0 col18" >2063</th>
#       <th id="T_af7f7_level0_col19" class="col_heading level0 col19" >2064</th>
#       <th id="T_af7f7_level0_col20" class="col_heading level0 col20" >2065</th>
#       <th id="T_af7f7_level0_col21" class="col_heading level0 col21" >2066</th>
#       <th id="T_af7f7_level0_col22" class="col_heading level0 col22" >2067</th>
#       <th id="T_af7f7_level0_col23" class="col_heading level0 col23" >2068</th>
#       <th id="T_af7f7_level0_col24" class="col_heading level0 col24" >2069</th>
#       <th id="T_af7f7_level0_col25" class="col_heading level0 col25" >2070</th>
#       <th id="T_af7f7_level0_col26" class="col_heading level0 col26" >2071</th>
#       <th id="T_af7f7_level0_col27" class="col_heading level0 col27" >2072</th>
#       <th id="T_af7f7_level0_col28" class="col_heading level0 col28" >2073</th>
#       <th id="T_af7f7_level0_col29" class="col_heading level0 col29" >2074</th>
#       <th id="T_af7f7_level0_col30" class="col_heading level0 col30" >2075</th>
#       <th id="T_af7f7_level0_col31" class="col_heading level0 col31" >2076</th>
#       <th id="T_af7f7_level0_col32" class="col_heading level0 col32" >2077</th>
#       <th id="T_af7f7_level0_col33" class="col_heading level0 col33" >2078</th>
#       <th id="T_af7f7_level0_col34" class="col_heading level0 col34" >2079</th>
#       <th id="T_af7f7_level0_col35" class="col_heading level0 col35" >2080</th>
#       <th id="T_af7f7_level0_col36" class="col_heading level0 col36" >2081</th>
#       <th id="T_af7f7_level0_col37" class="col_heading level0 col37" >2082</th>
#       <th id="T_af7f7_level0_col38" class="col_heading level0 col38" >2083</th>
#       <th id="T_af7f7_level0_col39" class="col_heading level0 col39" >2084</th>
#       <th id="T_af7f7_level0_col40" class="col_heading level0 col40" >2085</th>
#       <th id="T_af7f7_level0_col41" class="col_heading level0 col41" >2086</th>
#       <th id="T_af7f7_level0_col42" class="col_heading level0 col42" >2087</th>
#       <th id="T_af7f7_level0_col43" class="col_heading level0 col43" >2088</th>
#       <th id="T_af7f7_level0_col44" class="col_heading level0 col44" >2089</th>
#       <th id="T_af7f7_level0_col45" class="col_heading level0 col45" >2090</th>
#       <th id="T_af7f7_level0_col46" class="col_heading level0 col46" >2091</th>
#       <th id="T_af7f7_level0_col47" class="col_heading level0 col47" >2092</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af7f7_level0_row0" class="row_heading level0 row0" >opex</th>
#       <td id="T_af7f7_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_af7f7_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_af7f7_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_af7f7_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_af7f7_row0_col4" class="data row0 col4" >0.00</td>
#       <td id="T_af7f7_row0_col5" class="data row0 col5" >0.00</td>
#       <td id="T_af7f7_row0_col6" class="data row0 col6" >-61.56</td>
#       <td id="T_af7f7_row0_col7" class="data row0 col7" >-62.79</td>
#       <td id="T_af7f7_row0_col8" class="data row0 col8" >-64.04</td>
#       <td id="T_af7f7_row0_col9" class="data row0 col9" >-65.32</td>
#       <td id="T_af7f7_row0_col10" class="data row0 col10" >-66.63</td>
#       <td id="T_af7f7_row0_col11" class="data row0 col11" >-67.96</td>
#       <td id="T_af7f7_row0_col12" class="data row0 col12" >-69.32</td>
#       <td id="T_af7f7_row0_col13" class="data row0 col13" >-70.71</td>
#       <td id="T_af7f7_row0_col14" class="data row0 col14" >-72.12</td>
#       <td id="T_af7f7_row0_col15" class="data row0 col15" >-73.56</td>
#       <td id="T_af7f7_row0_col16" class="data row0 col16" >-75.04</td>
#       <td id="T_af7f7_row0_col17" class="data row0 col17" >-76.54</td>
#       <td id="T_af7f7_row0_col18" class="data row0 col18" >-78.07</td>
#       <td id="T_af7f7_row0_col19" class="data row0 col19" >-79.63</td>
#       <td id="T_af7f7_row0_col20" class="data row0 col20" >-81.22</td>
#       <td id="T_af7f7_row0_col21" class="data row0 col21" >-82.85</td>
#       <td id="T_af7f7_row0_col22" class="data row0 col22" >-84.50</td>
#       <td id="T_af7f7_row0_col23" class="data row0 col23" >-86.19</td>
#       <td id="T_af7f7_row0_col24" class="data row0 col24" >-87.92</td>
#       <td id="T_af7f7_row0_col25" class="data row0 col25" >-89.67</td>
#       <td id="T_af7f7_row0_col26" class="data row0 col26" >-91.47</td>
#       <td id="T_af7f7_row0_col27" class="data row0 col27" >-93.30</td>
#       <td id="T_af7f7_row0_col28" class="data row0 col28" >-95.16</td>
#       <td id="T_af7f7_row0_col29" class="data row0 col29" >-97.07</td>
#       <td id="T_af7f7_row0_col30" class="data row0 col30" >-99.01</td>
#       <td id="T_af7f7_row0_col31" class="data row0 col31" >-100.99</td>
#       <td id="T_af7f7_row0_col32" class="data row0 col32" >-103.01</td>
#       <td id="T_af7f7_row0_col33" class="data row0 col33" >-105.07</td>
#       <td id="T_af7f7_row0_col34" class="data row0 col34" >-107.17</td>
#       <td id="T_af7f7_row0_col35" class="data row0 col35" >-109.31</td>
#       <td id="T_af7f7_row0_col36" class="data row0 col36" >-111.50</td>
#       <td id="T_af7f7_row0_col37" class="data row0 col37" >-113.73</td>
#       <td id="T_af7f7_row0_col38" class="data row0 col38" >-116.00</td>
#       <td id="T_af7f7_row0_col39" class="data row0 col39" >-118.32</td>
#       <td id="T_af7f7_row0_col40" class="data row0 col40" >-120.69</td>
#       <td id="T_af7f7_row0_col41" class="data row0 col41" >-123.10</td>
#       <td id="T_af7f7_row0_col42" class="data row0 col42" >-125.57</td>
#       <td id="T_af7f7_row0_col43" class="data row0 col43" >-128.08</td>
#       <td id="T_af7f7_row0_col44" class="data row0 col44" >-130.64</td>
#       <td id="T_af7f7_row0_col45" class="data row0 col45" >-133.25</td>
#       <td id="T_af7f7_row0_col46" class="data row0 col46" >0.00</td>
#       <td id="T_af7f7_row0_col47" class="data row0 col47" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_af7f7_level0_row1" class="row_heading level0 row1" >opex_compressor</th>
#       <td id="T_af7f7_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_af7f7_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_af7f7_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_af7f7_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_af7f7_row1_col4" class="data row1 col4" >0.00</td>
#       <td id="T_af7f7_row1_col5" class="data row1 col5" >0.00</td>
#       <td id="T_af7f7_row1_col6"

# %%
# #compute 'capex_variable' from the different capex and cable lenght input data
# def total_capex(pipeline_capex_variable, compression_capex_variable, pipeline_length_variable):
#     "This function calculates the total capex, to make implementation in the other functions a bit easier"

#     HT_tot_capex = pipeline_capex_variable*pipeline_length_variable + compression_capex_variable  
#     return HT_tot_capex

# HT_tot_capex = total_capex(pipeline_capex, compression_capex, pipeline_distance)

# REMOVED THIS BECAUSE THE DEPRECIATION OF THE DIFFERENT ASSETS IS DIFFERENT DUE TO SHORTER LIFETIME FOR COMPRESSOR
# DOES NOT WORK IF WE COMBINE THE CAPEX OF THE PIPELINE AND COMPRESSOR IN A TOTAL CAPEX

# %% [markdown]
# Decommissioning phase

# %%
def decommissioning_phase(pipeline_capex_variable, 
                          compression_capex_variable, 
                          inflation_variable, 
                          decommissioning_variable, 
                          lifetime_investment_variable, 
                          pipeline_length_variable):
    ''' This function creates a dataframe that contains all cashflows in the decommissioning phase'''
    
    #set up df
    df_decommissioning_phase = pd.DataFrame(columns=construct_calendar_year_list(lifetime_investment_variable))
    df_decommissioning_phase.columns.name = "decommissioning_phase"
    
    pipeline_capex = pipeline_capex_variable * pipeline_length_variable 

    #### function 
    def decommissioning_cost(capex_variable):
        ''' This function calculated the decommissioning costs for all the decommissioning years '''

        decommissioning_cost_list = []

        for i,x in enumerate(construct_calendar_year_list(lifetime_investment_variable)):

            if x in construct_decomissioning_years_list(lifetime_investment_variable):
                decommissioning_cost_list.append(-capex_variable * decommissioning_variable * (1 + inflation_variable)**i)

            else:
                decommissioning_cost_list.append(0)

        return decommissioning_cost_list  
    
    # add decommissioning costs to df
    df_decommissioning_phase.loc['pipeline_decommissioning_cost'] = decommissioning_cost(pipeline_capex)
    df_decommissioning_phase.loc['compressor_decommissioning_cost'] = decommissioning_cost(compression_capex_variable)

    #add a row for the total decommissioning cashflows. Includes at this moment only one decommissioning cost, but could include more at a later stage.
    df_decommissioning_phase.loc['total_cashflow_decommissioning'] = np.array(decommissioning_cost(pipeline_capex)) + np.array(decommissioning_cost(compression_capex_variable))
    
    
    return df_decommissioning_phase

# %%
decommissioning_phase(pipeline_capex, compression_capex, HT_inflation, HT_decomissioning_percentage, HT_lifetime, pipeline_distance).style.format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bbad5">
#   <thead>
#     <tr>
#       <th class="index_name level0" >decommissioning_phase</th>
#       <th id="T_bbad5_level0_col0" class="col_heading level0 col0" >2045</th>
#       <th id="T_bbad5_level0_col1" class="col_heading level0 col1" >2046</th>
#       <th id="T_bbad5_level0_col2" class="col_heading level0 col2" >2047</th>
#       <th id="T_bbad5_level0_col3" class="col_heading level0 col3" >2048</th>
#       <th id="T_bbad5_level0_col4" class="col_heading level0 col4" >2049</th>
#       <th id="T_bbad5_level0_col5" class="col_heading level0 col5" >2050</th>
#       <th id="T_bbad5_level0_col6" class="col_heading level0 col6" >2051</th>
#       <th id="T_bbad5_level0_col7" class="col_heading level0 col7" >2052</th>
#       <th id="T_bbad5_level0_col8" class="col_heading level0 col8" >2053</th>
#       <th id="T_bbad5_level0_col9" class="col_heading level0 col9" >2054</th>
#       <th id="T_bbad5_level0_col10" class="col_heading level0 col10" >2055</th>
#       <th id="T_bbad5_level0_col11" class="col_heading level0 col11" >2056</th>
#       <th id="T_bbad5_level0_col12" class="col_heading level0 col12" >2057</th>
#       <th id="T_bbad5_level0_col13" class="col_heading level0 col13" >2058</th>
#       <th id="T_bbad5_level0_col14" class="col_heading level0 col14" >2059</th>
#       <th id="T_bbad5_level0_col15" class="col_heading level0 col15" >2060</th>
#       <th id="T_bbad5_level0_col16" class="col_heading level0 col16" >2061</th>
#       <th id="T_bbad5_level0_col17" class="col_heading level0 col17" >2062</th>
#       <th id="T_bbad5_level0_col18" class="col_heading level0 col18" >2063</th>
#       <th id="T_bbad5_level0_col19" class="col_heading level0 col19" >2064</th>
#       <th id="T_bbad5_level0_col20" class="col_heading level0 col20" >2065</th>
#       <th id="T_bbad5_level0_col21" class="col_heading level0 col21" >2066</th>
#       <th id="T_bbad5_level0_col22" class="col_heading level0 col22" >2067</th>
#       <th id="T_bbad5_level0_col23" class="col_heading level0 col23" >2068</th>
#       <th id="T_bbad5_level0_col24" class="col_heading level0 col24" >2069</th>
#       <th id="T_bbad5_level0_col25" class="col_heading level0 col25" >2070</th>
#       <th id="T_bbad5_level0_col26" class="col_heading level0 col26" >2071</th>
#       <th id="T_bbad5_level0_col27" class="col_heading level0 col27" >2072</th>
#       <th id="T_bbad5_level0_col28" class="col_heading level0 col28" >2073</th>
#       <th id="T_bbad5_level0_col29" class="col_heading level0 col29" >2074</th>
#       <th id="T_bbad5_level0_col30" class="col_heading level0 col30" >2075</th>
#       <th id="T_bbad5_level0_col31" class="col_heading level0 col31" >2076</th>
#       <th id="T_bbad5_level0_col32" class="col_heading level0 col32" >2077</th>
#       <th id="T_bbad5_level0_col33" class="col_heading level0 col33" >2078</th>
#       <th id="T_bbad5_level0_col34" class="col_heading level0 col34" >2079</th>
#       <th id="T_bbad5_level0_col35" class="col_heading level0 col35" >2080</th>
#       <th id="T_bbad5_level0_col36" class="col_heading level0 col36" >2081</th>
#       <th id="T_bbad5_level0_col37" class="col_heading level0 col37" >2082</th>
#       <th id="T_bbad5_level0_col38" class="col_heading level0 col38" >2083</th>
#       <th id="T_bbad5_level0_col39" class="col_heading level0 col39" >2084</th>
#       <th id="T_bbad5_level0_col40" class="col_heading level0 col40" >2085</th>
#       <th id="T_bbad5_level0_col41" class="col_heading level0 col41" >2086</th>
#       <th id="T_bbad5_level0_col42" class="col_heading level0 col42" >2087</th>
#       <th id="T_bbad5_level0_col43" class="col_heading level0 col43" >2088</th>
#       <th id="T_bbad5_level0_col44" class="col_heading level0 col44" >2089</th>
#       <th id="T_bbad5_level0_col45" class="col_heading level0 col45" >2090</th>
#       <th id="T_bbad5_level0_col46" class="col_heading level0 col46" >2091</th>
#       <th id="T_bbad5_level0_col47" class="col_heading level0 col47" >2092</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bbad5_level0_row0" class="row_heading level0 row0" >pipeline_decommissioning_cost</th>
#       <td id="T_bbad5_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_bbad5_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_bbad5_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_bbad5_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_bbad5_row0_col4" class="data row0 col4" >0.00</td>
#       <td id="T_bbad5_row0_col5" class="data row0 col5" >0.00</td>
#       <td id="T_bbad5_row0_col6" class="data row0 col6" >0.00</td>
#       <td id="T_bbad5_row0_col7" class="data row0 col7" >0.00</td>
#       <td id="T_bbad5_row0_col8" class="data row0 col8" >0.00</td>
#       <td id="T_bbad5_row0_col9" class="data row0 col9" >0.00</td>
#       <td id="T_bbad5_row0_col10" class="data row0 col10" >0.00</td>
#       <td id="T_bbad5_row0_col11" class="data row0 col11" >0.00</td>
#       <td id="T_bbad5_row0_col12" class="data row0 col12" >0.00</td>
#       <td id="T_bbad5_row0_col13" class="data row0 col13" >0.00</td>
#       <td id="T_bbad5_row0_col14" class="data row0 col14" >0.00</td>
#       <td id="T_bbad5_row0_col15" class="data row0 col15" >0.00</td>
#       <td id="T_bbad5_row0_col16" class="data row0 col16" >0.00</td>
#       <td id="T_bbad5_row0_col17" class="data row0 col17" >0.00</td>
#       <td id="T_bbad5_row0_col18" class="data row0 col18" >0.00</td>
#       <td id="T_bbad5_row0_col19" class="data row0 col19" >0.00</td>
#       <td id="T_bbad5_row0_col20" class="data row0 col20" >0.00</td>
#       <td id="T_bbad5_row0_col21" class="data row0 col21" >0.00</td>
#       <td id="T_bbad5_row0_col22" class="data row0 col22" >0.00</td>
#       <td id="T_bbad5_row0_col23" class="data row0 col23" >0.00</td>
#       <td id="T_bbad5_row0_col24" class="data row0 col24" >0.00</td>
#       <td id="T_bbad5_row0_col25" class="data row0 col25" >0.00</td>
#       <td id="T_bbad5_row0_col26" class="data row0 col26" >0.00</td>
#       <td id="T_bbad5_row0_col27" class="data row0 col27" >0.00</td>
#       <td id="T_bbad5_row0_col28" class="data row0 col28" >0.00</td>
#       <td id="T_bbad5_row0_col29" class="data row0 col29" >0.00</td>
#       <td id="T_bbad5_row0_col30" class="data row0 col30" >0.00</td>
#       <td id="T_bbad5_row0_col31" class="data row0 col31" >0.00</td>
#       <td id="T_bbad5_row0_col32" class="data row0 col32" >0.00</td>
#       <td id="T_bbad5_row0_col33" class="data row0 col33" >0.00</td>
#       <td id="T_bbad5_row0_col34" class="data row0 col34" >0.00</td>
#       <td id="T_bbad5_row0_col35" class="data row0 col35" >0.00</td>
#       <td id="T_bbad5_row0_col36" class="data row0 col36" >0.00</td>
#       <td id="T_bbad5_row0_col37" class="data row0 col37" >0.00</td>
#       <td id="T_bbad5_row0_col38" class="data row0 col38" >0.00</td>
#       <td id="T_bbad5_row0_col39" class="data row0 col39" >0.00</td>
#       <td id="T_bbad5_row0_col40" class="data row0 col40" >0.00</td>
#       <td id="T_bbad5_row0_col41" class="data row0 col41" >0.00</td>
#       <td id="T_bbad5_row0_col42" class="data row0 col42" >0.00</td>
#       <td id="T_bbad5_row0_col43" class="data row0 col43" >0.00</td>
#       <td id="T_bbad5_row0_col44" class="data row0 col44" >0.00</td>
#       <td id="T_bbad5_row0_col45" class="data row0 col45" >0.00</td>
#       <td id="T_bbad5_row0_col46" class="data row0 col46" >-72.12</td>
#       <td id="T_bbad5_row0_col47" class="data row0 col47" >-73.57</td>
#     </tr>
#     <tr>
#       <th id="T_bbad5_level0_row1" class="row_heading level0 row1" >compressor_decommissioning_cost</th>
#       <td id="T_bbad5_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_bbad5_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_bbad5_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_bbad5_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_bbad5_row1_col4" class="data row1 col4" >0.00</td>
#       <td id="T_bbad5_row1_col5" class="data row1 col5" >0.00</td>
#       <td id="T_bbad5_row1_col6" class="data row1 col6" >0.00</td>
#       <td i

# %% [markdown]
# Taxes & profits - part 1

# %%
def taxes_and_profits_part1(pipeline_capex_variable, 
                            compression_capex_variable,
                            df_opex_variable,
                            df_opex_compressor_variable,
                            df_compressor_power_costs_variable,
                            inflation_variable,
                            df_revenues_transport_tariffs,
                            df_revenues_connection_tariffs,
                            lifetime_investment_variable,
                            pipeline_length_variable):
    ''' This function creates a dataframe that contains all cashflows for taxes & profits
        It consists of two parts, as it is dependent on the debt and loan calculations'''

    # construct a df
    df_taxes_profits = pd.DataFrame(columns=construct_calendar_year_list(lifetime_investment_variable))
    df_taxes_profits.columns.name = "taxes_and_profits"
    
    

    #### function
    def depreciation(capex_variable, depreciation):
        ''' This function calculates the depreciation for the capex investment during the operational years'''

        depreciation_list = []

        for x in construct_calendar_year_list(lifetime_investment_variable):

            if x in construct_operations_years_list(lifetime_investment_variable):
                depreciation_list.append(-capex_variable*pipeline_length_variable/HT_depreciation)
            else: 
                depreciation_list.append(0)

        return depreciation_list  
    
    df_taxes_profits.loc['pipeline_depreciation'] = depreciation(pipeline_capex_variable,HT_depreciation)

    def compressor_depreciation(): 

        depreciation_list = []
        reinvestment_year = []

        for x in construct_calendar_year_list(lifetime_investment_variable):
            
            if (x+1) in construct_operations_years_list(lifetime_investment_variable) and \
               (x+1 - construct_operations_years_list(lifetime_investment_variable)[0]) % HT_compressor_lifetime == 0 and \
               ((x+1) > construct_operations_years_list(lifetime_investment_variable)[0]):
                          
                reinvestment_year.append(x)

        # calculate depreciation for each year
        for x in construct_calendar_year_list(lifetime_investment_variable):
            # total_depreciation = 0

            if x in construct_operations_years_list(lifetime_investment_variable):
            
                # initial investment depreciation
                if construct_operations_years_list(lifetime_investment_variable)[0] <= x < construct_operations_years_list(lifetime_investment_variable)[0] + HT_compressor_lifetime:
                    depreciation_list.append(-compression_capex_variable/HT_compressor_depreciation)

                for year in reinvestment_year:
                    if year < x <= year + HT_compressor_lifetime:
                        reinvestment_value = compression_capex_variable * (1+inflation_variable) ** (year - tender_year)
                        depreciation_list.append(-reinvestment_value/HT_compressor_depreciation)

            else: 
                depreciation_list.append(0)

        return depreciation_list  
    

    df_taxes_profits.loc['compressor_depreciation'] = compressor_depreciation()       

    #### function 
    def ebit():
        ''' This function calculates the ebit by adding depreciation (which is negative) to ebitda (net cashflow operations)'''

        net_cashflow_operations = (operational_phase(df_opex_variable,
                                                     df_opex_compressor_variable,
                                                     df_compressor_power_costs_variable,
                                                     inflation_variable,
                                                     df_revenues_transport_tariffs,
                                                     df_revenues_connection_tariffs,
                                                     lifetime_investment_variable,
                                                     pipeline_length_variable).loc['net_cashflow_operations'])
        
        ebit_list = np.array(net_cashflow_operations) + np.array(depreciation(pipeline_capex_variable,HT_depreciation)) + np.array(compressor_depreciation())

        return ebit_list

    # add depreciation and ebit to df
    
    df_taxes_profits.loc['ebit'] = ebit()

    
    return df_taxes_profits

# %%
taxes_and_profits_part1(pipeline_capex, 
                        compression_capex, 
                        df_HT_opex, 
                        df_opex_compressor, 
                        df_HT_compressor_power_costs,
                        HT_inflation, 
                        df_HT_revenues_transport, 
                        df_HT_revenues_connections, 
                        HT_lifetime, 
                        pipeline_distance).style.format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_170bf">
#   <thead>
#     <tr>
#       <th class="index_name level0" >taxes_and_profits</th>
#       <th id="T_170bf_level0_col0" class="col_heading level0 col0" >2045</th>
#       <th id="T_170bf_level0_col1" class="col_heading level0 col1" >2046</th>
#       <th id="T_170bf_level0_col2" class="col_heading level0 col2" >2047</th>
#       <th id="T_170bf_level0_col3" class="col_heading level0 col3" >2048</th>
#       <th id="T_170bf_level0_col4" class="col_heading level0 col4" >2049</th>
#       <th id="T_170bf_level0_col5" class="col_heading level0 col5" >2050</th>
#       <th id="T_170bf_level0_col6" class="col_heading level0 col6" >2051</th>
#       <th id="T_170bf_level0_col7" class="col_heading level0 col7" >2052</th>
#       <th id="T_170bf_level0_col8" class="col_heading level0 col8" >2053</th>
#       <th id="T_170bf_level0_col9" class="col_heading level0 col9" >2054</th>
#       <th id="T_170bf_level0_col10" class="col_heading level0 col10" >2055</th>
#       <th id="T_170bf_level0_col11" class="col_heading level0 col11" >2056</th>
#       <th id="T_170bf_level0_col12" class="col_heading level0 col12" >2057</th>
#       <th id="T_170bf_level0_col13" class="col_heading level0 col13" >2058</th>
#       <th id="T_170bf_level0_col14" class="col_heading level0 col14" >2059</th>
#       <th id="T_170bf_level0_col15" class="col_heading level0 col15" >2060</th>
#       <th id="T_170bf_level0_col16" class="col_heading level0 col16" >2061</th>
#       <th id="T_170bf_level0_col17" class="col_heading level0 col17" >2062</th>
#       <th id="T_170bf_level0_col18" class="col_heading level0 col18" >2063</th>
#       <th id="T_170bf_level0_col19" class="col_heading level0 col19" >2064</th>
#       <th id="T_170bf_level0_col20" class="col_heading level0 col20" >2065</th>
#       <th id="T_170bf_level0_col21" class="col_heading level0 col21" >2066</th>
#       <th id="T_170bf_level0_col22" class="col_heading level0 col22" >2067</th>
#       <th id="T_170bf_level0_col23" class="col_heading level0 col23" >2068</th>
#       <th id="T_170bf_level0_col24" class="col_heading level0 col24" >2069</th>
#       <th id="T_170bf_level0_col25" class="col_heading level0 col25" >2070</th>
#       <th id="T_170bf_level0_col26" class="col_heading level0 col26" >2071</th>
#       <th id="T_170bf_level0_col27" class="col_heading level0 col27" >2072</th>
#       <th id="T_170bf_level0_col28" class="col_heading level0 col28" >2073</th>
#       <th id="T_170bf_level0_col29" class="col_heading level0 col29" >2074</th>
#       <th id="T_170bf_level0_col30" class="col_heading level0 col30" >2075</th>
#       <th id="T_170bf_level0_col31" class="col_heading level0 col31" >2076</th>
#       <th id="T_170bf_level0_col32" class="col_heading level0 col32" >2077</th>
#       <th id="T_170bf_level0_col33" class="col_heading level0 col33" >2078</th>
#       <th id="T_170bf_level0_col34" class="col_heading level0 col34" >2079</th>
#       <th id="T_170bf_level0_col35" class="col_heading level0 col35" >2080</th>
#       <th id="T_170bf_level0_col36" class="col_heading level0 col36" >2081</th>
#       <th id="T_170bf_level0_col37" class="col_heading level0 col37" >2082</th>
#       <th id="T_170bf_level0_col38" class="col_heading level0 col38" >2083</th>
#       <th id="T_170bf_level0_col39" class="col_heading level0 col39" >2084</th>
#       <th id="T_170bf_level0_col40" class="col_heading level0 col40" >2085</th>
#       <th id="T_170bf_level0_col41" class="col_heading level0 col41" >2086</th>
#       <th id="T_170bf_level0_col42" class="col_heading level0 col42" >2087</th>
#       <th id="T_170bf_level0_col43" class="col_heading level0 col43" >2088</th>
#       <th id="T_170bf_level0_col44" class="col_heading level0 col44" >2089</th>
#       <th id="T_170bf_level0_col45" class="col_heading level0 col45" >2090</th>
#       <th id="T_170bf_level0_col46" class="col_heading level0 col46" >2091</th>
#       <th id="T_170bf_level0_col47" class="col_heading level0 col47" >2092</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_170bf_level0_row0" class="row_heading level0 row0" >pipeline_depreciation</th>
#       <td id="T_170bf_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_170bf_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_170bf_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_170bf_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_170bf_row0_col4" class="data row0 col4" >0.00</td>
#       <td id="T_170bf_row0_col5" class="data row0 col5" >0.00</td>
#       <td id="T_170bf_row0_col6" class="data row0 col6" >-36.26</td>
#       <td id="T_170bf_row0_col7" class="data row0 col7" >-36.26</td>
#       <td id="T_170bf_row0_col8" class="data row0 col8" >-36.26</td>
#       <td id="T_170bf_row0_col9" class="data row0 col9" >-36.26</td>
#       <td id="T_170bf_row0_col10" class="data row0 col10" >-36.26</td>
#       <td id="T_170bf_row0_col11" class="data row0 col11" >-36.26</td>
#       <td id="T_170bf_row0_col12" class="data row0 col12" >-36.26</td>
#       <td id="T_170bf_row0_col13" class="data row0 col13" >-36.26</td>
#       <td id="T_170bf_row0_col14" class="data row0 col14" >-36.26</td>
#       <td id="T_170bf_row0_col15" class="data row0 col15" >-36.26</td>
#       <td id="T_170bf_row0_col16" class="data row0 col16" >-36.26</td>
#       <td id="T_170bf_row0_col17" class="data row0 col17" >-36.26</td>
#       <td id="T_170bf_row0_col18" class="data row0 col18" >-36.26</td>
#       <td id="T_170bf_row0_col19" class="data row0 col19" >-36.26</td>
#       <td id="T_170bf_row0_col20" class="data row0 col20" >-36.26</td>
#       <td id="T_170bf_row0_col21" class="data row0 col21" >-36.26</td>
#       <td id="T_170bf_row0_col22" class="data row0 col22" >-36.26</td>
#       <td id="T_170bf_row0_col23" class="data row0 col23" >-36.26</td>
#       <td id="T_170bf_row0_col24" class="data row0 col24" >-36.26</td>
#       <td id="T_170bf_row0_col25" class="data row0 col25" >-36.26</td>
#       <td id="T_170bf_row0_col26" class="data row0 col26" >-36.26</td>
#       <td id="T_170bf_row0_col27" class="data row0 col27" >-36.26</td>
#       <td id="T_170bf_row0_col28" class="data row0 col28" >-36.26</td>
#       <td id="T_170bf_row0_col29" class="data row0 col29" >-36.26</td>
#       <td id="T_170bf_row0_col30" class="data row0 col30" >-36.26</td>
#       <td id="T_170bf_row0_col31" class="data row0 col31" >-36.26</td>
#       <td id="T_170bf_row0_col32" class="data row0 col32" >-36.26</td>
#       <td id="T_170bf_row0_col33" class="data row0 col33" >-36.26</td>
#       <td id="T_170bf_row0_col34" class="data row0 col34" >-36.26</td>
#       <td id="T_170bf_row0_col35" class="data row0 col35" >-36.26</td>
#       <td id="T_170bf_row0_col36" class="data row0 col36" >-36.26</td>
#       <td id="T_170bf_row0_col37" class="data row0 col37" >-36.26</td>
#       <td id="T_170bf_row0_col38" class="data row0 col38" >-36.26</td>
#       <td id="T_170bf_row0_col39" class="data row0 col39" >-36.26</td>
#       <td id="T_170bf_row0_col40" class="data row0 col40" >-36.26</td>
#       <td id="T_170bf_row0_col41" class="data row0 col41" >-36.26</td>
#       <td id="T_170bf_row0_col42" class="data row0 col42" >-36.26</td>
#       <td id="T_170bf_row0_col43" class="data row0 col43" >-36.26</td>
#       <td id="T_170bf_row0_col44" class="data row0 col44" >-36.26</td>
#       <td id="T_170bf_row0_col45" class="data row0 col45" >-36.26</td>
#       <td id="T_170bf_row0_col46" class="data row0 col46" >0.00</td>
#       <td id="T_170bf_row0_col47" class="data row0 col47" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_170bf_level0_row1" class="row_heading level0 row1" >compressor_depreciation</th>
#       <td id="T_170bf_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_170bf_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_170bf_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_170bf_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_170bf_row1_col4" class="data row1 col4" >0.00</td>
#       <td id="T_170bf_row1_col5" class="data row1 col5" >0.00</td>
#       <td id="T_170bf_

# %%
# now we need the interest costs, but these are in Excel linked to dept&loan.
# so first we will work on the debt & loan part, later continue with: interest costs, ebt, tax expenses, net profits

# %% [markdown]
# Debt and loan - part 1

# %%
def debt_and_loan_part1(pipeline_capex_variable, 
                        compression_capex_variable,
                        loan_percentage_variable,
                        loan_interest_rate_variable,
                        lifetime_investment_variable,
                        pipeline_length_variable):
    
    ''' This function creates a dataframe that contains all cashflows for debt and loans
        It consists of two parts because it is dependent on the taxes & profits calculations'''

    # construct df
    row_names = [
    "begin_of_year",
    "drawdown",
    "repayment_capital",
    "end_of_year",
    "repayment_interest",]

    df_debt_and_loan = pd.DataFrame(0.0, index=row_names, columns=construct_calendar_year_list(lifetime_investment_variable))
    df_debt_and_loan.columns.name = "debt_and_loan"
    
    # calcualte cost data

    HT_loan = (pipeline_capex_variable*pipeline_length_variable + compression_capex_variable) * HT_loan_percentage  #This excludes loan for pipelines

    # numpy financial calculates the annuity payment for the loan. Same as the PMT function in Excel (but slightly different arguments). See 'Cost data ET' cell C9.
    HT_annuity_loan = -npf.pmt(HT_loan_interest_rate, HT_length_of_loan, HT_loan, fv=0, when='end')


    #### function
    def debt_drawdown():
        ''' This function calculates the amount that is lent for the capex investments for each of the consturction years
            CAPEX re-investments are not included in debt drawdown, as it is assumed that no additional debt is taken on during the project
            and instead it is financed by project cash streams.'''   

        drawdown_list = []

        for x in construct_calendar_year_list(lifetime_investment_variable):
            if x in construction_years_list:
                drawdown_list.append((pipeline_capex_variable * pipeline_length_variable + compression_capex_variable) *loan_percentage_variable/duration_construction)
            else: 
                drawdown_list.append(0)

        return drawdown_list  

    # add debt drawdown to df
    df_debt_and_loan.loc["drawdown"] = debt_drawdown()

    #### function
    def debt_calculations(loan_interest_rate_variable):
        ''' This function calculates debt at the begin of the year, debt at the end of the year, 
            repayment of interest and repayment of capital. 
            These are dependent on each other and therefore combined into one function'''


        for x in construct_calendar_year_list(lifetime_investment_variable):
        
            #begin of year
            if x == tender_year:
                df_debt_and_loan.loc['begin_of_year',x] = 0
            else:
                df_debt_and_loan.loc['begin_of_year',x] = df_debt_and_loan.loc['end_of_year',x-1]
        
            #repayment interest
            if x in construct_operations_years_list(lifetime_investment_variable):
                df_debt_and_loan.loc['repayment_interest',x] = (-(df_debt_and_loan.loc['begin_of_year',x] + 
                                                               df_debt_and_loan.loc['drawdown',x]) * loan_interest_rate_variable)

            else:
                df_debt_and_loan.loc['repayment_interest',x] = 0
            
            #repayment capital
            if x in construct_operations_years_list(lifetime_investment_variable):

                # the min-function returns the lowest item, so min(5,10) will return 5
                df_debt_and_loan.loc['repayment_capital',x] = (-min(df_debt_and_loan.loc['begin_of_year',x] + 
                                                                 df_debt_and_loan.loc['drawdown',x], 
                                                                 HT_annuity_loan + df_debt_and_loan.loc['repayment_interest',x]))

            else: 
                df_debt_and_loan.loc['repayment_capital',x] = 0
            
            #end of year
            df_debt_and_loan.loc['end_of_year',x] = (df_debt_and_loan.loc['begin_of_year',x] + df_debt_and_loan.loc['drawdown',x] + 
                                                  df_debt_and_loan.loc['repayment_capital',x])

        return df_debt_and_loan


    return debt_calculations(loan_interest_rate_variable)

# %%
debt_and_loan_part1(pipeline_capex, compression_capex, HT_loan_percentage,HT_loan_interest_rate,HT_lifetime, pipeline_distance).style.format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_12d19">
#   <thead>
#     <tr>
#       <th class="index_name level0" >debt_and_loan</th>
#       <th id="T_12d19_level0_col0" class="col_heading level0 col0" >2045</th>
#       <th id="T_12d19_level0_col1" class="col_heading level0 col1" >2046</th>
#       <th id="T_12d19_level0_col2" class="col_heading level0 col2" >2047</th>
#       <th id="T_12d19_level0_col3" class="col_heading level0 col3" >2048</th>
#       <th id="T_12d19_level0_col4" class="col_heading level0 col4" >2049</th>
#       <th id="T_12d19_level0_col5" class="col_heading level0 col5" >2050</th>
#       <th id="T_12d19_level0_col6" class="col_heading level0 col6" >2051</th>
#       <th id="T_12d19_level0_col7" class="col_heading level0 col7" >2052</th>
#       <th id="T_12d19_level0_col8" class="col_heading level0 col8" >2053</th>
#       <th id="T_12d19_level0_col9" class="col_heading level0 col9" >2054</th>
#       <th id="T_12d19_level0_col10" class="col_heading level0 col10" >2055</th>
#       <th id="T_12d19_level0_col11" class="col_heading level0 col11" >2056</th>
#       <th id="T_12d19_level0_col12" class="col_heading level0 col12" >2057</th>
#       <th id="T_12d19_level0_col13" class="col_heading level0 col13" >2058</th>
#       <th id="T_12d19_level0_col14" class="col_heading level0 col14" >2059</th>
#       <th id="T_12d19_level0_col15" class="col_heading level0 col15" >2060</th>
#       <th id="T_12d19_level0_col16" class="col_heading level0 col16" >2061</th>
#       <th id="T_12d19_level0_col17" class="col_heading level0 col17" >2062</th>
#       <th id="T_12d19_level0_col18" class="col_heading level0 col18" >2063</th>
#       <th id="T_12d19_level0_col19" class="col_heading level0 col19" >2064</th>
#       <th id="T_12d19_level0_col20" class="col_heading level0 col20" >2065</th>
#       <th id="T_12d19_level0_col21" class="col_heading level0 col21" >2066</th>
#       <th id="T_12d19_level0_col22" class="col_heading level0 col22" >2067</th>
#       <th id="T_12d19_level0_col23" class="col_heading level0 col23" >2068</th>
#       <th id="T_12d19_level0_col24" class="col_heading level0 col24" >2069</th>
#       <th id="T_12d19_level0_col25" class="col_heading level0 col25" >2070</th>
#       <th id="T_12d19_level0_col26" class="col_heading level0 col26" >2071</th>
#       <th id="T_12d19_level0_col27" class="col_heading level0 col27" >2072</th>
#       <th id="T_12d19_level0_col28" class="col_heading level0 col28" >2073</th>
#       <th id="T_12d19_level0_col29" class="col_heading level0 col29" >2074</th>
#       <th id="T_12d19_level0_col30" class="col_heading level0 col30" >2075</th>
#       <th id="T_12d19_level0_col31" class="col_heading level0 col31" >2076</th>
#       <th id="T_12d19_level0_col32" class="col_heading level0 col32" >2077</th>
#       <th id="T_12d19_level0_col33" class="col_heading level0 col33" >2078</th>
#       <th id="T_12d19_level0_col34" class="col_heading level0 col34" >2079</th>
#       <th id="T_12d19_level0_col35" class="col_heading level0 col35" >2080</th>
#       <th id="T_12d19_level0_col36" class="col_heading level0 col36" >2081</th>
#       <th id="T_12d19_level0_col37" class="col_heading level0 col37" >2082</th>
#       <th id="T_12d19_level0_col38" class="col_heading level0 col38" >2083</th>
#       <th id="T_12d19_level0_col39" class="col_heading level0 col39" >2084</th>
#       <th id="T_12d19_level0_col40" class="col_heading level0 col40" >2085</th>
#       <th id="T_12d19_level0_col41" class="col_heading level0 col41" >2086</th>
#       <th id="T_12d19_level0_col42" class="col_heading level0 col42" >2087</th>
#       <th id="T_12d19_level0_col43" class="col_heading level0 col43" >2088</th>
#       <th id="T_12d19_level0_col44" class="col_heading level0 col44" >2089</th>
#       <th id="T_12d19_level0_col45" class="col_heading level0 col45" >2090</th>
#       <th id="T_12d19_level0_col46" class="col_heading level0 col46" >2091</th>
#       <th id="T_12d19_level0_col47" class="col_heading level0 col47" >2092</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12d19_level0_row0" class="row_heading level0 row0" >begin_of_year</th>
#       <td id="T_12d19_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_12d19_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_12d19_row0_col2" class="data row0 col2" >392.37</td>
#       <td id="T_12d19_row0_col3" class="data row0 col3" >784.74</td>
#       <td id="T_12d19_row0_col4" class="data row0 col4" >1177.11</td>
#       <td id="T_12d19_row0_col5" class="data row0 col5" >1569.48</td>
#       <td id="T_12d19_row0_col6" class="data row0 col6" >1961.85</td>
#       <td id="T_12d19_row0_col7" class="data row0 col7" >1920.61</td>
#       <td id="T_12d19_row0_col8" class="data row0 col8" >1878.14</td>
#       <td id="T_12d19_row0_col9" class="data row0 col9" >1834.39</td>
#       <td id="T_12d19_row0_col10" class="data row0 col10" >1789.33</td>
#       <td id="T_12d19_row0_col11" class="data row0 col11" >1742.92</td>
#       <td id="T_12d19_row0_col12" class="data row0 col12" >1695.11</td>
#       <td id="T_12d19_row0_col13" class="data row0 col13" >1645.88</td>
#       <td id="T_12d19_row0_col14" class="data row0 col14" >1595.16</td>
#       <td id="T_12d19_row0_col15" class="data row0 col15" >1542.92</td>
#       <td id="T_12d19_row0_col16" class="data row0 col16" >1489.12</td>
#       <td id="T_12d19_row0_col17" class="data row0 col17" >1433.70</td>
#       <td id="T_12d19_row0_col18" class="data row0 col18" >1376.62</td>
#       <td id="T_12d19_row0_col19" class="data row0 col19" >1317.82</td>
#       <td id="T_12d19_row0_col20" class="data row0 col20" >1257.27</td>
#       <td id="T_12d19_row0_col21" class="data row0 col21" >1194.89</td>
#       <td id="T_12d19_row0_col22" class="data row0 col22" >1130.65</td>
#       <td id="T_12d19_row0_col23" class="data row0 col23" >1064.48</td>
#       <td id="T_12d19_row0_col24" class="data row0 col24" >996.32</td>
#       <td id="T_12d19_row0_col25" class="data row0 col25" >926.11</td>
#       <td id="T_12d19_row0_col26" class="data row0 col26" >853.81</td>
#       <td id="T_12d19_row0_col27" class="data row0 col27" >779.33</td>
#       <td id="T_12d19_row0_col28" class="data row0 col28" >702.62</td>
#       <td id="T_12d19_row0_col29" class="data row0 col29" >623.60</td>
#       <td id="T_12d19_row0_col30" class="data row0 col30" >542.22</td>
#       <td id="T_12d19_row0_col31" class="data row0 col31" >458.39</td>
#       <td id="T_12d19_row0_col32" class="data row0 col32" >372.05</td>
#       <td id="T_12d19_row0_col33" class="data row0 col33" >283.12</td>
#       <td id="T_12d19_row0_col34" class="data row0 col34" >191.52</td>
#       <td id="T_12d19_row0_col35" class="data row0 col35" >97.18</td>
#       <td id="T_12d19_row0_col36" class="data row0 col36" >0.00</td>
#       <td id="T_12d19_row0_col37" class="data row0 col37" >0.00</td>
#       <td id="T_12d19_row0_col38" class="data row0 col38" >0.00</td>
#       <td id="T_12d19_row0_col39" class="data row0 col39" >0.00</td>
#       <td id="T_12d19_row0_col40" class="data row0 col40" >0.00</td>
#       <td id="T_12d19_row0_col41" class="data row0 col41" >0.00</td>
#       <td id="T_12d19_row0_col42" class="data row0 col42" >0.00</td>
#       <td id="T_12d19_row0_col43" class="data row0 col43" >0.00</td>
#       <td id="T_12d19_row0_col44" class="data row0 col44" >0.00</td>
#       <td id="T_12d19_row0_col45" class="data row0 col45" >0.00</td>
#       <td id="T_12d19_row0_col46" class="data row0 col46" >0.00</td>
#       <td id="T_12d19_row0_col47" class="data row0 col47" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_12d19_level0_row1" class="row_heading level0 row1" >drawdown</th>
#       <td id="T_12d19_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_12d19_row1_col1" class="data row1 col1" >392.37</td>
#       <td id="T_12d19_row1_col2" class="data row1 col2" >392.37</td>
#       <td id="T_12d19_row1_col3" class="data row1 col3" >392.37</td>
#       <td id="T_12d19_row1_col4" class="data row1 col4" >392.37</td>
#       <td id="T_12d19_row1_col5" class="data row1 col5" >392.37</td>
#       <td id="T_12d19_row1_col6"

# %%
# For the cash flow available for debt service, we need the tax expenses. So here we go back to Taxes & profits, and after that is finished we go back to Debt & loan - part 2

# %% [markdown]
# Taxes & profits - part 2

# %%
# continue with: interest costs, ebt, tax expenses, net profits

# %%
def taxes_and_profits_part2(pipeline_capex_variable,
                            compression_capex_variable,
                            df_opex_variable,
                            df_opex_compressor_variable,
                            df_compressor_power_costs_variable,
                            inflation_variable,
                            df_revenues_transport_tariffs,
                            df_revenues_connection_tariffs,
                            loan_percentage_variable,
                            loan_interest_rate_variable,
                            income_tax_rate_variable,
                            lifetime_investment_variable,
                            pipeline_length_variable):
    ''' This function creates a dataframe that contains all cashflows for taxes and profits
        This is the second part of the taxes and profits calculations.'''

    # load the dataframe that was constructed in part 1 of the taxes and profits calculations
    df_taxes_profits = taxes_and_profits_part1(pipeline_capex_variable,
                                               compression_capex_variable,
                                               df_opex_variable,
                                               df_opex_compressor_variable,
                                               df_compressor_power_costs_variable,
                                               inflation_variable,
                                               df_revenues_transport_tariffs,
                                               df_revenues_connection_tariffs,
                                               lifetime_investment_variable,
                                               pipeline_length_variable)

    # the interest costs were calculated in the debt_and_loan_part1 function
    # they are imported into this dataframe because they are used to calculate ebt from ebit
    interest_costs = np.array(debt_and_loan_part1(pipeline_capex_variable,
                                                  compression_capex_variable,
                                                  loan_percentage_variable,
                                                  loan_interest_rate_variable,
                                                  lifetime_investment_variable,
                                                  pipeline_length_variable).loc['repayment_interest'])   
    
    df_taxes_profits.loc['interest_costs'] = interest_costs

    # the ebt is calculated by adding the ebit to the interest costs (which is negative) and added to the df
    ebit = df_taxes_profits.loc['ebit'].tolist()
    ebt = ebit + interest_costs
    df_taxes_profits.loc['ebt'] = ebt

    #### function
    def tax_expenses(income_tax_rate_variable):
        '''This function calculates the taxes that have to be paid if ebt is positive'''

        tax_expenses_list = []

        for i,x in enumerate(construct_calendar_year_list(lifetime_investment_variable)):   
            if ebt[i] > 0:
                tax_expenses_list.append(-ebt[i] * income_tax_rate_variable)
            else:
                tax_expenses_list.append(0)

        return tax_expenses_list
    
    # add tax expenses to df 
    df_taxes_profits.loc['tax_expenses'] = tax_expenses(income_tax_rate_variable)

    # calculate net profits by adding tax expenses to ebt and add to df
    net_profits =  ebt + np.array(tax_expenses(income_tax_rate_variable))
    df_taxes_profits.loc['net_profits'] = net_profits

    return df_taxes_profits

# %%
taxes_and_profits_part2(pipeline_capex,
                        compression_capex,
                        df_HT_opex,
                        df_opex_compressor,
                        df_HT_compressor_power_costs,
                        HT_inflation,
                        df_HT_revenues_transport, 
                        df_HT_revenues_connections,
                        HT_loan_percentage,
                        HT_loan_interest_rate,
                        HT_income_tax_rate,
                        HT_lifetime,
                        pipeline_distance).style.format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1cbb2">
#   <thead>
#     <tr>
#       <th class="index_name level0" >taxes_and_profits</th>
#       <th id="T_1cbb2_level0_col0" class="col_heading level0 col0" >2045</th>
#       <th id="T_1cbb2_level0_col1" class="col_heading level0 col1" >2046</th>
#       <th id="T_1cbb2_level0_col2" class="col_heading level0 col2" >2047</th>
#       <th id="T_1cbb2_level0_col3" class="col_heading level0 col3" >2048</th>
#       <th id="T_1cbb2_level0_col4" class="col_heading level0 col4" >2049</th>
#       <th id="T_1cbb2_level0_col5" class="col_heading level0 col5" >2050</th>
#       <th id="T_1cbb2_level0_col6" class="col_heading level0 col6" >2051</th>
#       <th id="T_1cbb2_level0_col7" class="col_heading level0 col7" >2052</th>
#       <th id="T_1cbb2_level0_col8" class="col_heading level0 col8" >2053</th>
#       <th id="T_1cbb2_level0_col9" class="col_heading level0 col9" >2054</th>
#       <th id="T_1cbb2_level0_col10" class="col_heading level0 col10" >2055</th>
#       <th id="T_1cbb2_level0_col11" class="col_heading level0 col11" >2056</th>
#       <th id="T_1cbb2_level0_col12" class="col_heading level0 col12" >2057</th>
#       <th id="T_1cbb2_level0_col13" class="col_heading level0 col13" >2058</th>
#       <th id="T_1cbb2_level0_col14" class="col_heading level0 col14" >2059</th>
#       <th id="T_1cbb2_level0_col15" class="col_heading level0 col15" >2060</th>
#       <th id="T_1cbb2_level0_col16" class="col_heading level0 col16" >2061</th>
#       <th id="T_1cbb2_level0_col17" class="col_heading level0 col17" >2062</th>
#       <th id="T_1cbb2_level0_col18" class="col_heading level0 col18" >2063</th>
#       <th id="T_1cbb2_level0_col19" class="col_heading level0 col19" >2064</th>
#       <th id="T_1cbb2_level0_col20" class="col_heading level0 col20" >2065</th>
#       <th id="T_1cbb2_level0_col21" class="col_heading level0 col21" >2066</th>
#       <th id="T_1cbb2_level0_col22" class="col_heading level0 col22" >2067</th>
#       <th id="T_1cbb2_level0_col23" class="col_heading level0 col23" >2068</th>
#       <th id="T_1cbb2_level0_col24" class="col_heading level0 col24" >2069</th>
#       <th id="T_1cbb2_level0_col25" class="col_heading level0 col25" >2070</th>
#       <th id="T_1cbb2_level0_col26" class="col_heading level0 col26" >2071</th>
#       <th id="T_1cbb2_level0_col27" class="col_heading level0 col27" >2072</th>
#       <th id="T_1cbb2_level0_col28" class="col_heading level0 col28" >2073</th>
#       <th id="T_1cbb2_level0_col29" class="col_heading level0 col29" >2074</th>
#       <th id="T_1cbb2_level0_col30" class="col_heading level0 col30" >2075</th>
#       <th id="T_1cbb2_level0_col31" class="col_heading level0 col31" >2076</th>
#       <th id="T_1cbb2_level0_col32" class="col_heading level0 col32" >2077</th>
#       <th id="T_1cbb2_level0_col33" class="col_heading level0 col33" >2078</th>
#       <th id="T_1cbb2_level0_col34" class="col_heading level0 col34" >2079</th>
#       <th id="T_1cbb2_level0_col35" class="col_heading level0 col35" >2080</th>
#       <th id="T_1cbb2_level0_col36" class="col_heading level0 col36" >2081</th>
#       <th id="T_1cbb2_level0_col37" class="col_heading level0 col37" >2082</th>
#       <th id="T_1cbb2_level0_col38" class="col_heading level0 col38" >2083</th>
#       <th id="T_1cbb2_level0_col39" class="col_heading level0 col39" >2084</th>
#       <th id="T_1cbb2_level0_col40" class="col_heading level0 col40" >2085</th>
#       <th id="T_1cbb2_level0_col41" class="col_heading level0 col41" >2086</th>
#       <th id="T_1cbb2_level0_col42" class="col_heading level0 col42" >2087</th>
#       <th id="T_1cbb2_level0_col43" class="col_heading level0 col43" >2088</th>
#       <th id="T_1cbb2_level0_col44" class="col_heading level0 col44" >2089</th>
#       <th id="T_1cbb2_level0_col45" class="col_heading level0 col45" >2090</th>
#       <th id="T_1cbb2_level0_col46" class="col_heading level0 col46" >2091</th>
#       <th id="T_1cbb2_level0_col47" class="col_heading level0 col47" >2092</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1cbb2_level0_row0" class="row_heading level0 row0" >pipeline_depreciation</th>
#       <td id="T_1cbb2_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_1cbb2_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_1cbb2_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_1cbb2_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_1cbb2_row0_col4" class="data row0 col4" >0.00</td>
#       <td id="T_1cbb2_row0_col5" class="data row0 col5" >0.00</td>
#       <td id="T_1cbb2_row0_col6" class="data row0 col6" >-36.26</td>
#       <td id="T_1cbb2_row0_col7" class="data row0 col7" >-36.26</td>
#       <td id="T_1cbb2_row0_col8" class="data row0 col8" >-36.26</td>
#       <td id="T_1cbb2_row0_col9" class="data row0 col9" >-36.26</td>
#       <td id="T_1cbb2_row0_col10" class="data row0 col10" >-36.26</td>
#       <td id="T_1cbb2_row0_col11" class="data row0 col11" >-36.26</td>
#       <td id="T_1cbb2_row0_col12" class="data row0 col12" >-36.26</td>
#       <td id="T_1cbb2_row0_col13" class="data row0 col13" >-36.26</td>
#       <td id="T_1cbb2_row0_col14" class="data row0 col14" >-36.26</td>
#       <td id="T_1cbb2_row0_col15" class="data row0 col15" >-36.26</td>
#       <td id="T_1cbb2_row0_col16" class="data row0 col16" >-36.26</td>
#       <td id="T_1cbb2_row0_col17" class="data row0 col17" >-36.26</td>
#       <td id="T_1cbb2_row0_col18" class="data row0 col18" >-36.26</td>
#       <td id="T_1cbb2_row0_col19" class="data row0 col19" >-36.26</td>
#       <td id="T_1cbb2_row0_col20" class="data row0 col20" >-36.26</td>
#       <td id="T_1cbb2_row0_col21" class="data row0 col21" >-36.26</td>
#       <td id="T_1cbb2_row0_col22" class="data row0 col22" >-36.26</td>
#       <td id="T_1cbb2_row0_col23" class="data row0 col23" >-36.26</td>
#       <td id="T_1cbb2_row0_col24" class="data row0 col24" >-36.26</td>
#       <td id="T_1cbb2_row0_col25" class="data row0 col25" >-36.26</td>
#       <td id="T_1cbb2_row0_col26" class="data row0 col26" >-36.26</td>
#       <td id="T_1cbb2_row0_col27" class="data row0 col27" >-36.26</td>
#       <td id="T_1cbb2_row0_col28" class="data row0 col28" >-36.26</td>
#       <td id="T_1cbb2_row0_col29" class="data row0 col29" >-36.26</td>
#       <td id="T_1cbb2_row0_col30" class="data row0 col30" >-36.26</td>
#       <td id="T_1cbb2_row0_col31" class="data row0 col31" >-36.26</td>
#       <td id="T_1cbb2_row0_col32" class="data row0 col32" >-36.26</td>
#       <td id="T_1cbb2_row0_col33" class="data row0 col33" >-36.26</td>
#       <td id="T_1cbb2_row0_col34" class="data row0 col34" >-36.26</td>
#       <td id="T_1cbb2_row0_col35" class="data row0 col35" >-36.26</td>
#       <td id="T_1cbb2_row0_col36" class="data row0 col36" >-36.26</td>
#       <td id="T_1cbb2_row0_col37" class="data row0 col37" >-36.26</td>
#       <td id="T_1cbb2_row0_col38" class="data row0 col38" >-36.26</td>
#       <td id="T_1cbb2_row0_col39" class="data row0 col39" >-36.26</td>
#       <td id="T_1cbb2_row0_col40" class="data row0 col40" >-36.26</td>
#       <td id="T_1cbb2_row0_col41" class="data row0 col41" >-36.26</td>
#       <td id="T_1cbb2_row0_col42" class="data row0 col42" >-36.26</td>
#       <td id="T_1cbb2_row0_col43" class="data row0 col43" >-36.26</td>
#       <td id="T_1cbb2_row0_col44" class="data row0 col44" >-36.26</td>
#       <td id="T_1cbb2_row0_col45" class="data row0 col45" >-36.26</td>
#       <td id="T_1cbb2_row0_col46" class="data row0 col46" >0.00</td>
#       <td id="T_1cbb2_row0_col47" class="data row0 col47" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_1cbb2_level0_row1" class="row_heading level0 row1" >compressor_depreciation</th>
#       <td id="T_1cbb2_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_1cbb2_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_1cbb2_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_1cbb2_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_1cbb2_row1_col4" class="data row1 col4" >0.00</td>
#       <td id="T_1cbb2_row1_col5" class="data row1 col5" >0.00</td>
#       <td id="T_1cbb2_

# %% [markdown]
# Debt & loan - part 2

# %%
# still to do for debt & loan: 

#cash flow available for debt service
#debt service (capital + interest)
#cash flow after debt service

# %%
def debt_and_loan_part2(pipeline_capex_variable,
                        compression_capex_variable,
                        df_opex_variable,
                        df_opex_compressor_variable,
                        df_compressor_power_costs_variable,
                        inflation_variable,
                        df_revenues_transport_tariffs,
                        df_revenues_connection_tariffs,
                        loan_percentage_variable,
                        loan_interest_rate_variable,
                        income_tax_rate_variable,
                        lifetime_investment_variable,
                        pipeline_length_variable):
    ''' This function creates a dataframe that contains all cashflows for debt and loans
        This is the second part of the debt and loans calculations.'''

    # inport the df from debt_and_loan_part1 to continue with the same df
    df_debt_and_loan = debt_and_loan_part1(pipeline_capex_variable,
                                           compression_capex_variable,
                                           loan_percentage_variable,
                                           loan_interest_rate_variable,
                                           lifetime_investment_variable, 
                                           pipeline_length_variable)

    # the tax expenses were calculated in taxes_and_profits_part2 and are imported here
    # the cashflow available for debt is calculated by adding tax expenses to the net cashflow of operations
    # add cashflow for debt to df
    tax_expenses = (taxes_and_profits_part2(pipeline_capex_variable,
                                            compression_capex_variable,
                                            df_opex_variable,
                                            df_opex_compressor_variable,
                                            df_compressor_power_costs_variable,
                                            inflation_variable,
                                            df_revenues_transport_tariffs,
                                            df_revenues_connection_tariffs,
                                            loan_percentage_variable,
                                            loan_interest_rate_variable,
                                            income_tax_rate_variable,
                                            lifetime_investment_variable,
                                            pipeline_length_variable).loc['tax_expenses'])
    
    net_cashflow_operations = (operational_phase(df_opex_variable,
                                                 df_opex_compressor_variable,
                                                 df_compressor_power_costs_variable,
                                                 inflation_variable,
                                                 df_revenues_transport_tariffs,
                                                 df_revenues_connection_tariffs,
                                                 lifetime_investment_variable,
                                                 pipeline_length_variable).loc['net_cashflow_operations'])
    
    cash_flow_for_debt = np.array(tax_expenses) + np.array(net_cashflow_operations)
    df_debt_and_loan.loc['cash_flow_for_debt'] = cash_flow_for_debt

    #### function
    def debt_service():
        ''' This function calculates debt service (i.e. capital and interest repayments)'''
        debt_service_list = []

        for x in construct_calendar_year_list(lifetime_investment_variable): 
            debt_service_list.append(df_debt_and_loan.loc['repayment_capital',x] + df_debt_and_loan.loc['repayment_interest',x])

        return debt_service_list
    
    # add debt service to df
    df_debt_and_loan.loc['debt_service'] = debt_service()

    # calculate cash after debt service and add it to the df
    cash_after_debt_service = cash_flow_for_debt + debt_service()
    df_debt_and_loan.loc['cash_after_debt_service'] = cash_after_debt_service
    
    return df_debt_and_loan

# %%
debt_and_loan_part2(pipeline_capex,
                    compression_capex,
                    df_HT_opex,
                    df_opex_compressor,
                    df_HT_compressor_power_costs,
                    HT_inflation,
                    df_HT_revenues_transport, 
                    df_HT_revenues_connections,
                    HT_loan_percentage,
                    HT_loan_interest_rate,
                    HT_income_tax_rate,
                    HT_lifetime,
                    pipeline_distance).style.format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_11dd1">
#   <thead>
#     <tr>
#       <th class="index_name level0" >debt_and_loan</th>
#       <th id="T_11dd1_level0_col0" class="col_heading level0 col0" >2045</th>
#       <th id="T_11dd1_level0_col1" class="col_heading level0 col1" >2046</th>
#       <th id="T_11dd1_level0_col2" class="col_heading level0 col2" >2047</th>
#       <th id="T_11dd1_level0_col3" class="col_heading level0 col3" >2048</th>
#       <th id="T_11dd1_level0_col4" class="col_heading level0 col4" >2049</th>
#       <th id="T_11dd1_level0_col5" class="col_heading level0 col5" >2050</th>
#       <th id="T_11dd1_level0_col6" class="col_heading level0 col6" >2051</th>
#       <th id="T_11dd1_level0_col7" class="col_heading level0 col7" >2052</th>
#       <th id="T_11dd1_level0_col8" class="col_heading level0 col8" >2053</th>
#       <th id="T_11dd1_level0_col9" class="col_heading level0 col9" >2054</th>
#       <th id="T_11dd1_level0_col10" class="col_heading level0 col10" >2055</th>
#       <th id="T_11dd1_level0_col11" class="col_heading level0 col11" >2056</th>
#       <th id="T_11dd1_level0_col12" class="col_heading level0 col12" >2057</th>
#       <th id="T_11dd1_level0_col13" class="col_heading level0 col13" >2058</th>
#       <th id="T_11dd1_level0_col14" class="col_heading level0 col14" >2059</th>
#       <th id="T_11dd1_level0_col15" class="col_heading level0 col15" >2060</th>
#       <th id="T_11dd1_level0_col16" class="col_heading level0 col16" >2061</th>
#       <th id="T_11dd1_level0_col17" class="col_heading level0 col17" >2062</th>
#       <th id="T_11dd1_level0_col18" class="col_heading level0 col18" >2063</th>
#       <th id="T_11dd1_level0_col19" class="col_heading level0 col19" >2064</th>
#       <th id="T_11dd1_level0_col20" class="col_heading level0 col20" >2065</th>
#       <th id="T_11dd1_level0_col21" class="col_heading level0 col21" >2066</th>
#       <th id="T_11dd1_level0_col22" class="col_heading level0 col22" >2067</th>
#       <th id="T_11dd1_level0_col23" class="col_heading level0 col23" >2068</th>
#       <th id="T_11dd1_level0_col24" class="col_heading level0 col24" >2069</th>
#       <th id="T_11dd1_level0_col25" class="col_heading level0 col25" >2070</th>
#       <th id="T_11dd1_level0_col26" class="col_heading level0 col26" >2071</th>
#       <th id="T_11dd1_level0_col27" class="col_heading level0 col27" >2072</th>
#       <th id="T_11dd1_level0_col28" class="col_heading level0 col28" >2073</th>
#       <th id="T_11dd1_level0_col29" class="col_heading level0 col29" >2074</th>
#       <th id="T_11dd1_level0_col30" class="col_heading level0 col30" >2075</th>
#       <th id="T_11dd1_level0_col31" class="col_heading level0 col31" >2076</th>
#       <th id="T_11dd1_level0_col32" class="col_heading level0 col32" >2077</th>
#       <th id="T_11dd1_level0_col33" class="col_heading level0 col33" >2078</th>
#       <th id="T_11dd1_level0_col34" class="col_heading level0 col34" >2079</th>
#       <th id="T_11dd1_level0_col35" class="col_heading level0 col35" >2080</th>
#       <th id="T_11dd1_level0_col36" class="col_heading level0 col36" >2081</th>
#       <th id="T_11dd1_level0_col37" class="col_heading level0 col37" >2082</th>
#       <th id="T_11dd1_level0_col38" class="col_heading level0 col38" >2083</th>
#       <th id="T_11dd1_level0_col39" class="col_heading level0 col39" >2084</th>
#       <th id="T_11dd1_level0_col40" class="col_heading level0 col40" >2085</th>
#       <th id="T_11dd1_level0_col41" class="col_heading level0 col41" >2086</th>
#       <th id="T_11dd1_level0_col42" class="col_heading level0 col42" >2087</th>
#       <th id="T_11dd1_level0_col43" class="col_heading level0 col43" >2088</th>
#       <th id="T_11dd1_level0_col44" class="col_heading level0 col44" >2089</th>
#       <th id="T_11dd1_level0_col45" class="col_heading level0 col45" >2090</th>
#       <th id="T_11dd1_level0_col46" class="col_heading level0 col46" >2091</th>
#       <th id="T_11dd1_level0_col47" class="col_heading level0 col47" >2092</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11dd1_level0_row0" class="row_heading level0 row0" >begin_of_year</th>
#       <td id="T_11dd1_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_11dd1_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_11dd1_row0_col2" class="data row0 col2" >392.37</td>
#       <td id="T_11dd1_row0_col3" class="data row0 col3" >784.74</td>
#       <td id="T_11dd1_row0_col4" class="data row0 col4" >1177.11</td>
#       <td id="T_11dd1_row0_col5" class="data row0 col5" >1569.48</td>
#       <td id="T_11dd1_row0_col6" class="data row0 col6" >1961.85</td>
#       <td id="T_11dd1_row0_col7" class="data row0 col7" >1920.61</td>
#       <td id="T_11dd1_row0_col8" class="data row0 col8" >1878.14</td>
#       <td id="T_11dd1_row0_col9" class="data row0 col9" >1834.39</td>
#       <td id="T_11dd1_row0_col10" class="data row0 col10" >1789.33</td>
#       <td id="T_11dd1_row0_col11" class="data row0 col11" >1742.92</td>
#       <td id="T_11dd1_row0_col12" class="data row0 col12" >1695.11</td>
#       <td id="T_11dd1_row0_col13" class="data row0 col13" >1645.88</td>
#       <td id="T_11dd1_row0_col14" class="data row0 col14" >1595.16</td>
#       <td id="T_11dd1_row0_col15" class="data row0 col15" >1542.92</td>
#       <td id="T_11dd1_row0_col16" class="data row0 col16" >1489.12</td>
#       <td id="T_11dd1_row0_col17" class="data row0 col17" >1433.70</td>
#       <td id="T_11dd1_row0_col18" class="data row0 col18" >1376.62</td>
#       <td id="T_11dd1_row0_col19" class="data row0 col19" >1317.82</td>
#       <td id="T_11dd1_row0_col20" class="data row0 col20" >1257.27</td>
#       <td id="T_11dd1_row0_col21" class="data row0 col21" >1194.89</td>
#       <td id="T_11dd1_row0_col22" class="data row0 col22" >1130.65</td>
#       <td id="T_11dd1_row0_col23" class="data row0 col23" >1064.48</td>
#       <td id="T_11dd1_row0_col24" class="data row0 col24" >996.32</td>
#       <td id="T_11dd1_row0_col25" class="data row0 col25" >926.11</td>
#       <td id="T_11dd1_row0_col26" class="data row0 col26" >853.81</td>
#       <td id="T_11dd1_row0_col27" class="data row0 col27" >779.33</td>
#       <td id="T_11dd1_row0_col28" class="data row0 col28" >702.62</td>
#       <td id="T_11dd1_row0_col29" class="data row0 col29" >623.60</td>
#       <td id="T_11dd1_row0_col30" class="data row0 col30" >542.22</td>
#       <td id="T_11dd1_row0_col31" class="data row0 col31" >458.39</td>
#       <td id="T_11dd1_row0_col32" class="data row0 col32" >372.05</td>
#       <td id="T_11dd1_row0_col33" class="data row0 col33" >283.12</td>
#       <td id="T_11dd1_row0_col34" class="data row0 col34" >191.52</td>
#       <td id="T_11dd1_row0_col35" class="data row0 col35" >97.18</td>
#       <td id="T_11dd1_row0_col36" class="data row0 col36" >0.00</td>
#       <td id="T_11dd1_row0_col37" class="data row0 col37" >0.00</td>
#       <td id="T_11dd1_row0_col38" class="data row0 col38" >0.00</td>
#       <td id="T_11dd1_row0_col39" class="data row0 col39" >0.00</td>
#       <td id="T_11dd1_row0_col40" class="data row0 col40" >0.00</td>
#       <td id="T_11dd1_row0_col41" class="data row0 col41" >0.00</td>
#       <td id="T_11dd1_row0_col42" class="data row0 col42" >0.00</td>
#       <td id="T_11dd1_row0_col43" class="data row0 col43" >0.00</td>
#       <td id="T_11dd1_row0_col44" class="data row0 col44" >0.00</td>
#       <td id="T_11dd1_row0_col45" class="data row0 col45" >0.00</td>
#       <td id="T_11dd1_row0_col46" class="data row0 col46" >0.00</td>
#       <td id="T_11dd1_row0_col47" class="data row0 col47" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_11dd1_level0_row1" class="row_heading level0 row1" >drawdown</th>
#       <td id="T_11dd1_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_11dd1_row1_col1" class="data row1 col1" >392.37</td>
#       <td id="T_11dd1_row1_col2" class="data row1 col2" >392.37</td>
#       <td id="T_11dd1_row1_col3" class="data row1 col3" >392.37</td>
#       <td id="T_11dd1_row1_col4" class="data row1 col4" >392.37</td>
#       <td id="T_11dd1_row1_col5" class="data row1 col5" >392.37</td>
#       <td id="T_11dd1_row1_col6"

# %% [markdown]
# Project reserves

# %%
def project_reserves(pipeline_capex_variable,
                     compression_capex_variable, 
                     lifetime_investment_variable,
                     pipeline_length_variable):
    '''This function creates a dataframe that contains all cashflows for project reserves (i.e., contingency) '''

    #construct df
    row_names = [
    "contingency_injection",
    "contingency_reserve_balance",
    "contingency_reserve_to_dividents",]

    df_project_reserves = pd.DataFrame(0.0, index=row_names, columns=construct_calendar_year_list(lifetime_investment_variable))
    df_project_reserves.columns.name = "project_reserves"

    #### function 
    def contingency_injection():
        '''This function calculates the contingency required for the project'''
        contingency_injection_list = []

        for x in construct_calendar_year_list(lifetime_investment_variable):
            
            if x == tender_year:
                contingency_injection_list.append(-(pipeline_capex_variable * pipeline_length_variable + compression_capex_variable) * HT_contingency)
        
            else:
                contingency_injection_list.append(0)

        return contingency_injection_list

    # add contingency injection to df
    df_project_reserves.loc['contingency_injection'] = contingency_injection()


    #### function to calculate contingency reserve balance and contingency reserve to dividents
    def contingency_project():
        ''' This function calculates the balance of contingency for each year 
            and the amount that is left over in the last year that is going to dividents'''

        for x in construct_calendar_year_list(lifetime_investment_variable):

            #contingency_reserve_balance
            if x == tender_year:
                df_project_reserves.loc['contingency_reserve_balance',x] = -df_project_reserves.loc['contingency_injection',x]
            else: 
                df_project_reserves.loc['contingency_reserve_balance',x] = (df_project_reserves.loc['contingency_reserve_balance',x-1] -
                                                                         df_project_reserves.loc['contingency_injection',x] - 
                                                                         df_project_reserves.loc['contingency_reserve_to_dividents',x])

            #contingency_reserve_to_dividents
            if (x == construct_calendar_year_list(lifetime_investment_variable)[-1] and 
                                                  df_project_reserves.loc['contingency_reserve_balance',x] > 0):
                df_project_reserves.loc['contingency_reserve_to_dividents',x] = df_project_reserves.loc['contingency_reserve_balance',x]
            else:
                df_project_reserves.loc['contingency_reserve_to_dividents',x] = 0

        return df_project_reserves


    return contingency_project()

# %%
project_reserves(pipeline_capex,
                 compression_capex,
                 HT_lifetime, 
                 pipeline_distance).style.format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1d1e0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >project_reserves</th>
#       <th id="T_1d1e0_level0_col0" class="col_heading level0 col0" >2045</th>
#       <th id="T_1d1e0_level0_col1" class="col_heading level0 col1" >2046</th>
#       <th id="T_1d1e0_level0_col2" class="col_heading level0 col2" >2047</th>
#       <th id="T_1d1e0_level0_col3" class="col_heading level0 col3" >2048</th>
#       <th id="T_1d1e0_level0_col4" class="col_heading level0 col4" >2049</th>
#       <th id="T_1d1e0_level0_col5" class="col_heading level0 col5" >2050</th>
#       <th id="T_1d1e0_level0_col6" class="col_heading level0 col6" >2051</th>
#       <th id="T_1d1e0_level0_col7" class="col_heading level0 col7" >2052</th>
#       <th id="T_1d1e0_level0_col8" class="col_heading level0 col8" >2053</th>
#       <th id="T_1d1e0_level0_col9" class="col_heading level0 col9" >2054</th>
#       <th id="T_1d1e0_level0_col10" class="col_heading level0 col10" >2055</th>
#       <th id="T_1d1e0_level0_col11" class="col_heading level0 col11" >2056</th>
#       <th id="T_1d1e0_level0_col12" class="col_heading level0 col12" >2057</th>
#       <th id="T_1d1e0_level0_col13" class="col_heading level0 col13" >2058</th>
#       <th id="T_1d1e0_level0_col14" class="col_heading level0 col14" >2059</th>
#       <th id="T_1d1e0_level0_col15" class="col_heading level0 col15" >2060</th>
#       <th id="T_1d1e0_level0_col16" class="col_heading level0 col16" >2061</th>
#       <th id="T_1d1e0_level0_col17" class="col_heading level0 col17" >2062</th>
#       <th id="T_1d1e0_level0_col18" class="col_heading level0 col18" >2063</th>
#       <th id="T_1d1e0_level0_col19" class="col_heading level0 col19" >2064</th>
#       <th id="T_1d1e0_level0_col20" class="col_heading level0 col20" >2065</th>
#       <th id="T_1d1e0_level0_col21" class="col_heading level0 col21" >2066</th>
#       <th id="T_1d1e0_level0_col22" class="col_heading level0 col22" >2067</th>
#       <th id="T_1d1e0_level0_col23" class="col_heading level0 col23" >2068</th>
#       <th id="T_1d1e0_level0_col24" class="col_heading level0 col24" >2069</th>
#       <th id="T_1d1e0_level0_col25" class="col_heading level0 col25" >2070</th>
#       <th id="T_1d1e0_level0_col26" class="col_heading level0 col26" >2071</th>
#       <th id="T_1d1e0_level0_col27" class="col_heading level0 col27" >2072</th>
#       <th id="T_1d1e0_level0_col28" class="col_heading level0 col28" >2073</th>
#       <th id="T_1d1e0_level0_col29" class="col_heading level0 col29" >2074</th>
#       <th id="T_1d1e0_level0_col30" class="col_heading level0 col30" >2075</th>
#       <th id="T_1d1e0_level0_col31" class="col_heading level0 col31" >2076</th>
#       <th id="T_1d1e0_level0_col32" class="col_heading level0 col32" >2077</th>
#       <th id="T_1d1e0_level0_col33" class="col_heading level0 col33" >2078</th>
#       <th id="T_1d1e0_level0_col34" class="col_heading level0 col34" >2079</th>
#       <th id="T_1d1e0_level0_col35" class="col_heading level0 col35" >2080</th>
#       <th id="T_1d1e0_level0_col36" class="col_heading level0 col36" >2081</th>
#       <th id="T_1d1e0_level0_col37" class="col_heading level0 col37" >2082</th>
#       <th id="T_1d1e0_level0_col38" class="col_heading level0 col38" >2083</th>
#       <th id="T_1d1e0_level0_col39" class="col_heading level0 col39" >2084</th>
#       <th id="T_1d1e0_level0_col40" class="col_heading level0 col40" >2085</th>
#       <th id="T_1d1e0_level0_col41" class="col_heading level0 col41" >2086</th>
#       <th id="T_1d1e0_level0_col42" class="col_heading level0 col42" >2087</th>
#       <th id="T_1d1e0_level0_col43" class="col_heading level0 col43" >2088</th>
#       <th id="T_1d1e0_level0_col44" class="col_heading level0 col44" >2089</th>
#       <th id="T_1d1e0_level0_col45" class="col_heading level0 col45" >2090</th>
#       <th id="T_1d1e0_level0_col46" class="col_heading level0 col46" >2091</th>
#       <th id="T_1d1e0_level0_col47" class="col_heading level0 col47" >2092</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d1e0_level0_row0" class="row_heading level0 row0" >contingency_injection</th>
#       <td id="T_1d1e0_row0_col0" class="data row0 col0" >-130.79</td>
#       <td id="T_1d1e0_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_1d1e0_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_1d1e0_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_1d1e0_row0_col4" class="data row0 col4" >0.00</td>
#       <td id="T_1d1e0_row0_col5" class="data row0 col5" >0.00</td>
#       <td id="T_1d1e0_row0_col6" class="data row0 col6" >0.00</td>
#       <td id="T_1d1e0_row0_col7" class="data row0 col7" >0.00</td>
#       <td id="T_1d1e0_row0_col8" class="data row0 col8" >0.00</td>
#       <td id="T_1d1e0_row0_col9" class="data row0 col9" >0.00</td>
#       <td id="T_1d1e0_row0_col10" class="data row0 col10" >0.00</td>
#       <td id="T_1d1e0_row0_col11" class="data row0 col11" >0.00</td>
#       <td id="T_1d1e0_row0_col12" class="data row0 col12" >0.00</td>
#       <td id="T_1d1e0_row0_col13" class="data row0 col13" >0.00</td>
#       <td id="T_1d1e0_row0_col14" class="data row0 col14" >0.00</td>
#       <td id="T_1d1e0_row0_col15" class="data row0 col15" >0.00</td>
#       <td id="T_1d1e0_row0_col16" class="data row0 col16" >0.00</td>
#       <td id="T_1d1e0_row0_col17" class="data row0 col17" >0.00</td>
#       <td id="T_1d1e0_row0_col18" class="data row0 col18" >0.00</td>
#       <td id="T_1d1e0_row0_col19" class="data row0 col19" >0.00</td>
#       <td id="T_1d1e0_row0_col20" class="data row0 col20" >0.00</td>
#       <td id="T_1d1e0_row0_col21" class="data row0 col21" >0.00</td>
#       <td id="T_1d1e0_row0_col22" class="data row0 col22" >0.00</td>
#       <td id="T_1d1e0_row0_col23" class="data row0 col23" >0.00</td>
#       <td id="T_1d1e0_row0_col24" class="data row0 col24" >0.00</td>
#       <td id="T_1d1e0_row0_col25" class="data row0 col25" >0.00</td>
#       <td id="T_1d1e0_row0_col26" class="data row0 col26" >0.00</td>
#       <td id="T_1d1e0_row0_col27" class="data row0 col27" >0.00</td>
#       <td id="T_1d1e0_row0_col28" class="data row0 col28" >0.00</td>
#       <td id="T_1d1e0_row0_col29" class="data row0 col29" >0.00</td>
#       <td id="T_1d1e0_row0_col30" class="data row0 col30" >0.00</td>
#       <td id="T_1d1e0_row0_col31" class="data row0 col31" >0.00</td>
#       <td id="T_1d1e0_row0_col32" class="data row0 col32" >0.00</td>
#       <td id="T_1d1e0_row0_col33" class="data row0 col33" >0.00</td>
#       <td id="T_1d1e0_row0_col34" class="data row0 col34" >0.00</td>
#       <td id="T_1d1e0_row0_col35" class="data row0 col35" >0.00</td>
#       <td id="T_1d1e0_row0_col36" class="data row0 col36" >0.00</td>
#       <td id="T_1d1e0_row0_col37" class="data row0 col37" >0.00</td>
#       <td id="T_1d1e0_row0_col38" class="data row0 col38" >0.00</td>
#       <td id="T_1d1e0_row0_col39" class="data row0 col39" >0.00</td>
#       <td id="T_1d1e0_row0_col40" class="data row0 col40" >0.00</td>
#       <td id="T_1d1e0_row0_col41" class="data row0 col41" >0.00</td>
#       <td id="T_1d1e0_row0_col42" class="data row0 col42" >0.00</td>
#       <td id="T_1d1e0_row0_col43" class="data row0 col43" >0.00</td>
#       <td id="T_1d1e0_row0_col44" class="data row0 col44" >0.00</td>
#       <td id="T_1d1e0_row0_col45" class="data row0 col45" >0.00</td>
#       <td id="T_1d1e0_row0_col46" class="data row0 col46" >0.00</td>
#       <td id="T_1d1e0_row0_col47" class="data row0 col47" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_1d1e0_level0_row1" class="row_heading level0 row1" >contingency_reserve_balance</th>
#       <td id="T_1d1e0_row1_col0" class="data row1 col0" >130.79</td>
#       <td id="T_1d1e0_row1_col1" class="data row1 col1" >130.79</td>
#       <td id="T_1d1e0_row1_col2" class="data row1 col2" >130.79</td>
#       <td id="T_1d1e0_row1_col3" class="data row1 col3" >130.79</td>
#       <td id="T_1d1e0_row1_col4" class="data row1 col4" >130.79</td>
#       <td id="T_1d1e0_row1_col5" class="data row1 col5" >130.79</td>
#       <td id="T_1d1e0_row1_col6" class="data row1 col6" >130.79</td>
#       <td id="T

# %% [markdown]
# Equity funding

# %%
def equity_funding(pipeline_capex_variable,
                   compression_capex_variable,
                   df_opex_variable,
                   df_opex_compressor_variable,
                   df_compressor_power_costs_variable,
                   inflation_variable,
                   df_revenues_connection_tariffs,
                   df_revenues_transport_tariffs,
                   decommissioning_variable,
                   loan_percentage_variable,
                   loan_interest_rate_variable,
                   income_tax_rate_variable,
                   lifetime_investment_variable,
                   pipeline_length_variable):
    '''This function creates a dataframe that contains all cashflows for equity funding '''

    # construct df
    df_equity_funding = pd.DataFrame(columns=construct_calendar_year_list(lifetime_investment_variable))
    df_equity_funding.columns.name = "equity_funding"
    
    # get input data required for calculations
    contingency_injection = project_reserves(pipeline_capex_variable,
                                             compression_capex_variable,
                                             lifetime_investment_variable, 
                                             pipeline_length_variable).loc['contingency_injection']

    total_cashflow_decommissioning = decommissioning_phase(pipeline_capex_variable,
                                                           compression_capex_variable,
                                                           inflation_variable,
                                                           decommissioning_variable,
                                                           lifetime_investment_variable, 
                                                           pipeline_length_variable).loc['total_cashflow_decommissioning']

    cash_after_debt_service = (debt_and_loan_part2(pipeline_capex_variable,
                                                   compression_capex_variable,
                                                   df_opex_variable,
                                                   df_opex_compressor_variable,
                                                   df_compressor_power_costs_variable,
                                                   inflation_variable,
                                                   df_revenues_connection_tariffs,
                                                   df_revenues_transport_tariffs,
                                                   loan_percentage_variable,
                                                   loan_interest_rate_variable,
                                                   income_tax_rate_variable,
                                                   lifetime_investment_variable,
                                                   pipeline_length_variable).loc['cash_after_debt_service'])
    
    capex = construction_phase(pipeline_capex_variable, 
                               compression_capex_variable, 
                               inflation_variable, 
                               lifetime_investment_variable, 
                               pipeline_length_variable).loc['total_cashflow_investment']
    
    contingency_reserve_to_dividents = np.array(project_reserves(pipeline_capex_variable,
                                                                 compression_capex_variable,
                                                                 lifetime_investment_variable, 
                                                                 pipeline_length_variable).loc['contingency_reserve_to_dividents'])

    # calculate equity injection and add to df
    equity_injection = contingency_injection + (capex *(1-HT_loan_percentage)) + total_cashflow_decommissioning
    df_equity_funding.loc['equity_injection'] = equity_injection

    # calculate dividents results and add to df
    dividents_results = cash_after_debt_service + contingency_reserve_to_dividents
    df_equity_funding.loc['dividents_results'] = dividents_results

    # calculate equity cash flow result and add to df
    equity_cash_flow_result = equity_injection + dividents_results 
    df_equity_funding.loc['equity_cash_flow_result'] = equity_cash_flow_result

    return df_equity_funding

# %%
equity_funding(pipeline_capex, 
               compression_capex, 
               df_HT_opex,
               df_opex_compressor,
               df_HT_compressor_power_costs,
               HT_inflation,
               df_HT_revenues_transport, 
               df_HT_revenues_connections,
               HT_decomissioning_percentage,
               HT_loan_percentage,
               HT_loan_interest_rate,
               HT_income_tax_rate,
               HT_lifetime,
               pipeline_distance).style.format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_216ee">
#   <thead>
#     <tr>
#       <th class="index_name level0" >equity_funding</th>
#       <th id="T_216ee_level0_col0" class="col_heading level0 col0" >2045</th>
#       <th id="T_216ee_level0_col1" class="col_heading level0 col1" >2046</th>
#       <th id="T_216ee_level0_col2" class="col_heading level0 col2" >2047</th>
#       <th id="T_216ee_level0_col3" class="col_heading level0 col3" >2048</th>
#       <th id="T_216ee_level0_col4" class="col_heading level0 col4" >2049</th>
#       <th id="T_216ee_level0_col5" class="col_heading level0 col5" >2050</th>
#       <th id="T_216ee_level0_col6" class="col_heading level0 col6" >2051</th>
#       <th id="T_216ee_level0_col7" class="col_heading level0 col7" >2052</th>
#       <th id="T_216ee_level0_col8" class="col_heading level0 col8" >2053</th>
#       <th id="T_216ee_level0_col9" class="col_heading level0 col9" >2054</th>
#       <th id="T_216ee_level0_col10" class="col_heading level0 col10" >2055</th>
#       <th id="T_216ee_level0_col11" class="col_heading level0 col11" >2056</th>
#       <th id="T_216ee_level0_col12" class="col_heading level0 col12" >2057</th>
#       <th id="T_216ee_level0_col13" class="col_heading level0 col13" >2058</th>
#       <th id="T_216ee_level0_col14" class="col_heading level0 col14" >2059</th>
#       <th id="T_216ee_level0_col15" class="col_heading level0 col15" >2060</th>
#       <th id="T_216ee_level0_col16" class="col_heading level0 col16" >2061</th>
#       <th id="T_216ee_level0_col17" class="col_heading level0 col17" >2062</th>
#       <th id="T_216ee_level0_col18" class="col_heading level0 col18" >2063</th>
#       <th id="T_216ee_level0_col19" class="col_heading level0 col19" >2064</th>
#       <th id="T_216ee_level0_col20" class="col_heading level0 col20" >2065</th>
#       <th id="T_216ee_level0_col21" class="col_heading level0 col21" >2066</th>
#       <th id="T_216ee_level0_col22" class="col_heading level0 col22" >2067</th>
#       <th id="T_216ee_level0_col23" class="col_heading level0 col23" >2068</th>
#       <th id="T_216ee_level0_col24" class="col_heading level0 col24" >2069</th>
#       <th id="T_216ee_level0_col25" class="col_heading level0 col25" >2070</th>
#       <th id="T_216ee_level0_col26" class="col_heading level0 col26" >2071</th>
#       <th id="T_216ee_level0_col27" class="col_heading level0 col27" >2072</th>
#       <th id="T_216ee_level0_col28" class="col_heading level0 col28" >2073</th>
#       <th id="T_216ee_level0_col29" class="col_heading level0 col29" >2074</th>
#       <th id="T_216ee_level0_col30" class="col_heading level0 col30" >2075</th>
#       <th id="T_216ee_level0_col31" class="col_heading level0 col31" >2076</th>
#       <th id="T_216ee_level0_col32" class="col_heading level0 col32" >2077</th>
#       <th id="T_216ee_level0_col33" class="col_heading level0 col33" >2078</th>
#       <th id="T_216ee_level0_col34" class="col_heading level0 col34" >2079</th>
#       <th id="T_216ee_level0_col35" class="col_heading level0 col35" >2080</th>
#       <th id="T_216ee_level0_col36" class="col_heading level0 col36" >2081</th>
#       <th id="T_216ee_level0_col37" class="col_heading level0 col37" >2082</th>
#       <th id="T_216ee_level0_col38" class="col_heading level0 col38" >2083</th>
#       <th id="T_216ee_level0_col39" class="col_heading level0 col39" >2084</th>
#       <th id="T_216ee_level0_col40" class="col_heading level0 col40" >2085</th>
#       <th id="T_216ee_level0_col41" class="col_heading level0 col41" >2086</th>
#       <th id="T_216ee_level0_col42" class="col_heading level0 col42" >2087</th>
#       <th id="T_216ee_level0_col43" class="col_heading level0 col43" >2088</th>
#       <th id="T_216ee_level0_col44" class="col_heading level0 col44" >2089</th>
#       <th id="T_216ee_level0_col45" class="col_heading level0 col45" >2090</th>
#       <th id="T_216ee_level0_col46" class="col_heading level0 col46" >2091</th>
#       <th id="T_216ee_level0_col47" class="col_heading level0 col47" >2092</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_216ee_level0_row0" class="row_heading level0 row0" >equity_injection</th>
#       <td id="T_216ee_row0_col0" class="data row0 col0" >-130.79</td>
#       <td id="T_216ee_row0_col1" class="data row0 col1" >-130.79</td>
#       <td id="T_216ee_row0_col2" class="data row0 col2" >-130.79</td>
#       <td id="T_216ee_row0_col3" class="data row0 col3" >-130.79</td>
#       <td id="T_216ee_row0_col4" class="data row0 col4" >-130.79</td>
#       <td id="T_216ee_row0_col5" class="data row0 col5" >-130.79</td>
#       <td id="T_216ee_row0_col6" class="data row0 col6" >0.00</td>
#       <td id="T_216ee_row0_col7" class="data row0 col7" >0.00</td>
#       <td id="T_216ee_row0_col8" class="data row0 col8" >0.00</td>
#       <td id="T_216ee_row0_col9" class="data row0 col9" >0.00</td>
#       <td id="T_216ee_row0_col10" class="data row0 col10" >0.00</td>
#       <td id="T_216ee_row0_col11" class="data row0 col11" >0.00</td>
#       <td id="T_216ee_row0_col12" class="data row0 col12" >0.00</td>
#       <td id="T_216ee_row0_col13" class="data row0 col13" >0.00</td>
#       <td id="T_216ee_row0_col14" class="data row0 col14" >0.00</td>
#       <td id="T_216ee_row0_col15" class="data row0 col15" >0.00</td>
#       <td id="T_216ee_row0_col16" class="data row0 col16" >0.00</td>
#       <td id="T_216ee_row0_col17" class="data row0 col17" >0.00</td>
#       <td id="T_216ee_row0_col18" class="data row0 col18" >0.00</td>
#       <td id="T_216ee_row0_col19" class="data row0 col19" >0.00</td>
#       <td id="T_216ee_row0_col20" class="data row0 col20" >-433.00</td>
#       <td id="T_216ee_row0_col21" class="data row0 col21" >0.00</td>
#       <td id="T_216ee_row0_col22" class="data row0 col22" >0.00</td>
#       <td id="T_216ee_row0_col23" class="data row0 col23" >0.00</td>
#       <td id="T_216ee_row0_col24" class="data row0 col24" >0.00</td>
#       <td id="T_216ee_row0_col25" class="data row0 col25" >0.00</td>
#       <td id="T_216ee_row0_col26" class="data row0 col26" >0.00</td>
#       <td id="T_216ee_row0_col27" class="data row0 col27" >0.00</td>
#       <td id="T_216ee_row0_col28" class="data row0 col28" >0.00</td>
#       <td id="T_216ee_row0_col29" class="data row0 col29" >0.00</td>
#       <td id="T_216ee_row0_col30" class="data row0 col30" >0.00</td>
#       <td id="T_216ee_row0_col31" class="data row0 col31" >0.00</td>
#       <td id="T_216ee_row0_col32" class="data row0 col32" >0.00</td>
#       <td id="T_216ee_row0_col33" class="data row0 col33" >0.00</td>
#       <td id="T_216ee_row0_col34" class="data row0 col34" >0.00</td>
#       <td id="T_216ee_row0_col35" class="data row0 col35" >-582.76</td>
#       <td id="T_216ee_row0_col36" class="data row0 col36" >0.00</td>
#       <td id="T_216ee_row0_col37" class="data row0 col37" >0.00</td>
#       <td id="T_216ee_row0_col38" class="data row0 col38" >0.00</td>
#       <td id="T_216ee_row0_col39" class="data row0 col39" >0.00</td>
#       <td id="T_216ee_row0_col40" class="data row0 col40" >0.00</td>
#       <td id="T_216ee_row0_col41" class="data row0 col41" >0.00</td>
#       <td id="T_216ee_row0_col42" class="data row0 col42" >0.00</td>
#       <td id="T_216ee_row0_col43" class="data row0 col43" >0.00</td>
#       <td id="T_216ee_row0_col44" class="data row0 col44" >0.00</td>
#       <td id="T_216ee_row0_col45" class="data row0 col45" >0.00</td>
#       <td id="T_216ee_row0_col46" class="data row0 col46" >25.31</td>
#       <td id="T_216ee_row0_col47" class="data row0 col47" >-132.69</td>
#     </tr>
#     <tr>
#       <th id="T_216ee_level0_row1" class="row_heading level0 row1" >dividents_results</th>
#       <td id="T_216ee_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_216ee_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_216ee_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_216ee_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_216ee_row1_col4" class="data row1 col4" >0.00</td>
#       <td id="T_216ee_row1_col5" class="data row1 col5" >0.00</td>
#       <td id="T_216ee_row1_col6" class="data row1 col6" >-356.37</td>
#       <td id="T_21

# %% [markdown]
# Display all cashflows

# %%
# # Display all individual dataframes

# display(construction_phase(owf_capex,owf_lifetime).style.format(precision=2))
# display(operational_phase(df_owf_opex,owf_inflation,owf_revenues_to_electrolyser,owf_revenues_to_market,owf_lifetime).style.format(precision=2))
# display(decommissioning_phase(owf_capex,owf_inflation,owf_lifetime).style.format(precision=2))
# display(taxes_and_profits_part2(owf_capex,df_owf_opex,owf_inflation,owf_revenues_to_electrolyser,owf_revenues_to_market,owf_loan_percentage,owf_loan_interest_rate,owf_income_tax_rate,owf_lifetime).style.format(precision=2))
# display(debt_and_loan_part2(owf_capex,df_owf_opex,owf_inflation,owf_revenues_to_electrolyser,owf_revenues_to_market,owf_loan_percentage,owf_loan_interest_rate,owf_income_tax_rate,owf_lifetime).style.format(precision=2))
# display(project_reserves(owf_capex,owf_lifetime).style.format(precision=2))
# display(equity_funding(owf_capex,df_owf_opex,owf_inflation,owf_revenues_to_electrolyser,owf_revenues_to_market,owf_loan_percentage,owf_loan_interest_rate,owf_income_tax_rate,owf_lifetime).style.format(precision=2))

# %%
# construct large df including all rows
all_dfs = [construction_phase(pipeline_capex, compression_capex, HT_inflation, HT_lifetime, pipeline_distance),
           operational_phase(df_HT_opex,df_opex_compressor,df_HT_compressor_power_costs,HT_inflation,df_HT_revenues_transport,df_HT_revenues_connections,HT_lifetime,pipeline_distance),
           decommissioning_phase(pipeline_capex,compression_capex, HT_inflation, HT_decomissioning_percentage, HT_lifetime, pipeline_distance),
           taxes_and_profits_part2(pipeline_capex,compression_capex,df_HT_opex,df_opex_compressor,df_HT_compressor_power_costs,HT_inflation,df_HT_revenues_transport, df_HT_revenues_connections,HT_loan_percentage,HT_loan_interest_rate,HT_income_tax_rate,HT_lifetime,pipeline_distance),
           debt_and_loan_part2(pipeline_capex,compression_capex,df_HT_opex,df_opex_compressor,df_HT_compressor_power_costs,HT_inflation,df_HT_revenues_transport, df_HT_revenues_connections,HT_loan_percentage,HT_loan_interest_rate,HT_income_tax_rate,HT_lifetime,pipeline_distance),
           project_reserves(pipeline_capex,compression_capex,HT_lifetime,pipeline_distance),
           equity_funding(pipeline_capex, compression_capex,df_HT_opex,df_opex_compressor,df_HT_compressor_power_costs,HT_inflation,df_HT_revenues_transport, df_HT_revenues_connections,HT_decomissioning_percentage,HT_loan_percentage,HT_loan_interest_rate,HT_income_tax_rate,HT_lifetime,pipeline_distance)]

full_df = pd.concat(all_dfs)
# full_df.style.format(precision=2)   #shows the full df

# %% [markdown]
# Present value of cash flows

# %%
def present_value_cashflows(pipeline_capex_variable,
                            compression_capex_variable,
                            df_opex_variable,
                            df_opex_compressor_variable,
                            df_compressor_power_costs_variable,
                            inflation_variable,
                            df_revenues_transport_tariffs,
                            df_revenues_connection_tariffs,
                            decommissioning_variable,
                            loan_percentage_variable,
                            loan_interest_rate_variable,
                            income_tax_rate_variable,
                            wacc_variable,
                            lifetime_investment_variable,
                            pipeline_length_variable):
    ''' This function creates a dataframe that contains all present value cashflows '''

    # construct df
    df_present_value = pd.DataFrame(columns=construct_calendar_year_list(lifetime_investment_variable))
    df_present_value.columns.name = "present_value"
    
    # calculate sum of the net project cashflows and add to df
    total_cashflow_investment = construction_phase(pipeline_capex_variable, 
                                                   compression_capex_variable, 
                                                   inflation_variable,
                                                   lifetime_investment_variable, 
                                                   pipeline_length_variable).loc['total_cashflow_investment']

    net_cashflow_operations = (operational_phase(df_opex_variable,
                                                 df_opex_compressor_variable,
                                                 df_compressor_power_costs_variable,
                                                 inflation_variable,
                                                 df_revenues_transport_tariffs,
                                                 df_revenues_connection_tariffs,
                                                 lifetime_investment_variable,
                                                 pipeline_length_variable).loc['net_cashflow_operations'])

    total_cashflow_decommissioning = decommissioning_phase(pipeline_capex,
                                                           compression_capex, 
                                                           inflation_variable, 
                                                           decommissioning_variable, 
                                                           lifetime_investment_variable, 
                                                           pipeline_length_variable).loc['total_cashflow_decommissioning']
    
    sum_net_project_cash_flows = total_cashflow_investment + net_cashflow_operations + total_cashflow_decommissioning
    df_present_value.loc['sum_net_project_cash_flows'] = sum_net_project_cash_flows
    
    #### function
    def present_value_net_cashflows():
        '''This function calculates the present value of the net cashflows'''

        present_value_net_cashflows_list = []

        for x in construct_business_case_year_list(lifetime_investment_variable):    
        
            present_value_net_cashflows_list.append(sum_net_project_cash_flows.tolist()[x] / (1 + wacc_variable) ** x)

        return present_value_net_cashflows_list
    
    # add present value of net cashflows to df
    df_present_value.loc['present_value_net_cashflows'] = present_value_net_cashflows()

    #### function
    def cumulative_value_net_cashflows():
        '''This function calculates the cumulative value of the net cashflows'''
        cumulative_value_net_cashflows_list = []

        for i, x in enumerate(construct_calendar_year_list(lifetime_investment_variable)):
            if x == tender_year:
                cumulative_value_net_cashflows_list.append(present_value_net_cashflows()[i])
            else:
                cumulative_value_net_cashflows_list.append(present_value_net_cashflows()[i] + cumulative_value_net_cashflows_list[i-1])

        return cumulative_value_net_cashflows_list

    # add cumulative value of net cashflows to df
    df_present_value.loc['cumulative_value_net_cashflows'] = cumulative_value_net_cashflows()

    #### function 
    def present_value_equity_cashflows():
        '''This function calculates the present value of equity cashflows'''

        present_value_equity_cashflows_list = []
        equity_cash_flow_result = (equity_funding(pipeline_capex_variable,
                                                  compression_capex_variable,
                                                  df_opex_variable,
                                                  df_opex_compressor_variable,
                                                  df_compressor_power_costs_variable,
                                                  inflation_variable,
                                                  df_revenues_transport_tariffs,
                                                  df_revenues_connection_tariffs,
                                                  decommissioning_variable,
                                                  loan_percentage_variable,
                                                  loan_interest_rate_variable,
                                                  income_tax_rate_variable,
                                                  lifetime_investment_variable,
                                                  pipeline_length_variable).loc['equity_cash_flow_result'].tolist())

        for x in construct_business_case_year_list(lifetime_investment_variable):      
            present_value_equity_cashflows_list.append(equity_cash_flow_result[x] / (1 + wacc_variable) ** x)

        return present_value_equity_cashflows_list

    # add present value of equity cashflows to df
    df_present_value.loc['present_value_equity_cashflows'] = present_value_equity_cashflows()

    return df_present_value

# %%
present_value_cashflows(pipeline_capex, 
                        compression_capex, 
                        df_HT_opex,
                        df_opex_compressor,
                        df_HT_compressor_power_costs,
                        HT_inflation,
                        df_HT_revenues_transport, 
                        df_HT_revenues_connections,
                        HT_decomissioning_percentage,
                        HT_loan_percentage,
                        HT_loan_interest_rate,
                        HT_income_tax_rate,
                        HT_general_WACC,
                        HT_lifetime,
                        pipeline_distance).style.format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c91dc">
#   <thead>
#     <tr>
#       <th class="index_name level0" >present_value</th>
#       <th id="T_c91dc_level0_col0" class="col_heading level0 col0" >2045</th>
#       <th id="T_c91dc_level0_col1" class="col_heading level0 col1" >2046</th>
#       <th id="T_c91dc_level0_col2" class="col_heading level0 col2" >2047</th>
#       <th id="T_c91dc_level0_col3" class="col_heading level0 col3" >2048</th>
#       <th id="T_c91dc_level0_col4" class="col_heading level0 col4" >2049</th>
#       <th id="T_c91dc_level0_col5" class="col_heading level0 col5" >2050</th>
#       <th id="T_c91dc_level0_col6" class="col_heading level0 col6" >2051</th>
#       <th id="T_c91dc_level0_col7" class="col_heading level0 col7" >2052</th>
#       <th id="T_c91dc_level0_col8" class="col_heading level0 col8" >2053</th>
#       <th id="T_c91dc_level0_col9" class="col_heading level0 col9" >2054</th>
#       <th id="T_c91dc_level0_col10" class="col_heading level0 col10" >2055</th>
#       <th id="T_c91dc_level0_col11" class="col_heading level0 col11" >2056</th>
#       <th id="T_c91dc_level0_col12" class="col_heading level0 col12" >2057</th>
#       <th id="T_c91dc_level0_col13" class="col_heading level0 col13" >2058</th>
#       <th id="T_c91dc_level0_col14" class="col_heading level0 col14" >2059</th>
#       <th id="T_c91dc_level0_col15" class="col_heading level0 col15" >2060</th>
#       <th id="T_c91dc_level0_col16" class="col_heading level0 col16" >2061</th>
#       <th id="T_c91dc_level0_col17" class="col_heading level0 col17" >2062</th>
#       <th id="T_c91dc_level0_col18" class="col_heading level0 col18" >2063</th>
#       <th id="T_c91dc_level0_col19" class="col_heading level0 col19" >2064</th>
#       <th id="T_c91dc_level0_col20" class="col_heading level0 col20" >2065</th>
#       <th id="T_c91dc_level0_col21" class="col_heading level0 col21" >2066</th>
#       <th id="T_c91dc_level0_col22" class="col_heading level0 col22" >2067</th>
#       <th id="T_c91dc_level0_col23" class="col_heading level0 col23" >2068</th>
#       <th id="T_c91dc_level0_col24" class="col_heading level0 col24" >2069</th>
#       <th id="T_c91dc_level0_col25" class="col_heading level0 col25" >2070</th>
#       <th id="T_c91dc_level0_col26" class="col_heading level0 col26" >2071</th>
#       <th id="T_c91dc_level0_col27" class="col_heading level0 col27" >2072</th>
#       <th id="T_c91dc_level0_col28" class="col_heading level0 col28" >2073</th>
#       <th id="T_c91dc_level0_col29" class="col_heading level0 col29" >2074</th>
#       <th id="T_c91dc_level0_col30" class="col_heading level0 col30" >2075</th>
#       <th id="T_c91dc_level0_col31" class="col_heading level0 col31" >2076</th>
#       <th id="T_c91dc_level0_col32" class="col_heading level0 col32" >2077</th>
#       <th id="T_c91dc_level0_col33" class="col_heading level0 col33" >2078</th>
#       <th id="T_c91dc_level0_col34" class="col_heading level0 col34" >2079</th>
#       <th id="T_c91dc_level0_col35" class="col_heading level0 col35" >2080</th>
#       <th id="T_c91dc_level0_col36" class="col_heading level0 col36" >2081</th>
#       <th id="T_c91dc_level0_col37" class="col_heading level0 col37" >2082</th>
#       <th id="T_c91dc_level0_col38" class="col_heading level0 col38" >2083</th>
#       <th id="T_c91dc_level0_col39" class="col_heading level0 col39" >2084</th>
#       <th id="T_c91dc_level0_col40" class="col_heading level0 col40" >2085</th>
#       <th id="T_c91dc_level0_col41" class="col_heading level0 col41" >2086</th>
#       <th id="T_c91dc_level0_col42" class="col_heading level0 col42" >2087</th>
#       <th id="T_c91dc_level0_col43" class="col_heading level0 col43" >2088</th>
#       <th id="T_c91dc_level0_col44" class="col_heading level0 col44" >2089</th>
#       <th id="T_c91dc_level0_col45" class="col_heading level0 col45" >2090</th>
#       <th id="T_c91dc_level0_col46" class="col_heading level0 col46" >2091</th>
#       <th id="T_c91dc_level0_col47" class="col_heading level0 col47" >2092</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c91dc_level0_row0" class="row_heading level0 row0" >sum_net_project_cash_flows</th>
#       <td id="T_c91dc_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_c91dc_row0_col1" class="data row0 col1" >-523.16</td>
#       <td id="T_c91dc_row0_col2" class="data row0 col2" >-523.16</td>
#       <td id="T_c91dc_row0_col3" class="data row0 col3" >-523.16</td>
#       <td id="T_c91dc_row0_col4" class="data row0 col4" >-523.16</td>
#       <td id="T_c91dc_row0_col5" class="data row0 col5" >-523.16</td>
#       <td id="T_c91dc_row0_col6" class="data row0 col6" >-256.28</td>
#       <td id="T_c91dc_row0_col7" class="data row0 col7" >-261.41</td>
#       <td id="T_c91dc_row0_col8" class="data row0 col8" >-266.64</td>
#       <td id="T_c91dc_row0_col9" class="data row0 col9" >-271.97</td>
#       <td id="T_c91dc_row0_col10" class="data row0 col10" >-277.41</td>
#       <td id="T_c91dc_row0_col11" class="data row0 col11" >-282.96</td>
#       <td id="T_c91dc_row0_col12" class="data row0 col12" >-288.61</td>
#       <td id="T_c91dc_row0_col13" class="data row0 col13" >-294.39</td>
#       <td id="T_c91dc_row0_col14" class="data row0 col14" >-300.27</td>
#       <td id="T_c91dc_row0_col15" class="data row0 col15" >-306.28</td>
#       <td id="T_c91dc_row0_col16" class="data row0 col16" >-312.41</td>
#       <td id="T_c91dc_row0_col17" class="data row0 col17" >-318.65</td>
#       <td id="T_c91dc_row0_col18" class="data row0 col18" >-325.03</td>
#       <td id="T_c91dc_row0_col19" class="data row0 col19" >-331.53</td>
#       <td id="T_c91dc_row0_col20" class="data row0 col20" >-2070.15</td>
#       <td id="T_c91dc_row0_col21" class="data row0 col21" >-344.92</td>
#       <td id="T_c91dc_row0_col22" class="data row0 col22" >-351.82</td>
#       <td id="T_c91dc_row0_col23" class="data row0 col23" >-358.86</td>
#       <td id="T_c91dc_row0_col24" class="data row0 col24" >-366.03</td>
#       <td id="T_c91dc_row0_col25" class="data row0 col25" >-373.35</td>
#       <td id="T_c91dc_row0_col26" class="data row0 col26" >-380.82</td>
#       <td id="T_c91dc_row0_col27" class="data row0 col27" >-388.44</td>
#       <td id="T_c91dc_row0_col28" class="data row0 col28" >-396.21</td>
#       <td id="T_c91dc_row0_col29" class="data row0 col29" >-404.13</td>
#       <td id="T_c91dc_row0_col30" class="data row0 col30" >-412.21</td>
#       <td id="T_c91dc_row0_col31" class="data row0 col31" >-420.46</td>
#       <td id="T_c91dc_row0_col32" class="data row0 col32" >-428.87</td>
#       <td id="T_c91dc_row0_col33" class="data row0 col33" >-437.44</td>
#       <td id="T_c91dc_row0_col34" class="data row0 col34" >-446.19</td>
#       <td id="T_c91dc_row0_col35" class="data row0 col35" >-2786.15</td>
#       <td id="T_c91dc_row0_col36" class="data row0 col36" >-464.22</td>
#       <td id="T_c91dc_row0_col37" class="data row0 col37" >-473.50</td>
#       <td id="T_c91dc_row0_col38" class="data row0 col38" >-482.97</td>
#       <td id="T_c91dc_row0_col39" class="data row0 col39" >-492.63</td>
#       <td id="T_c91dc_row0_col40" class="data row0 col40" >-502.49</td>
#       <td id="T_c91dc_row0_col41" class="data row0 col41" >-512.54</td>
#       <td id="T_c91dc_row0_col42" class="data row0 col42" >-522.79</td>
#       <td id="T_c91dc_row0_col43" class="data row0 col43" >-533.24</td>
#       <td id="T_c91dc_row0_col44" class="data row0 col44" >-543.91</td>
#       <td id="T_c91dc_row0_col45" class="data row0 col45" >-554.78</td>
#       <td id="T_c91dc_row0_col46" class="data row0 col46" >491.52</td>
#       <td id="T_c91dc_row0_col47" class="data row0 col47" >-132.69</td>
#     </tr>
#     <tr>
#       <th id="T_c91dc_level0_row1" class="row_heading level0 row1" >present_value_net_cashflows</th>
#       <td id="T_c91dc_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_c91dc_row1_col1" class="data row1 col1" >-503.04</td>
#       <td id="T_c91dc_row1_col2" class="data row1 col2" >-483.69</td>
#       <td id="T_c91dc_row1_col3" class="data row1 col3" >-465.09</td>
#       <td id="T_c91dc_row1_col4" class="data row1 col4" >-447.20</td>
#       <td

# %% [markdown]
# Cumulative equity and debt cash flows

# %%
def cumulative_equity_and_debt_cashflows(pipeline_capex_variable,
                                         compression_capex_variable,
                                         df_opex_variable,
                                         df_opex_compressor_variable,
                                         df_compressor_power_costs_variable,
                                         inflation_variable,
                                         df_revenues_transport_tariffs,
                                         df_revenues_connection_tariffs,
                                         decommissioning_variable,
                                         loan_percentage_variable,
                                         loan_interest_rate_variable,
                                         income_tax_rate_variable,
                                         lifetime_investment_variable,
                                         pipeline_length_variable):
    '''This function creates a dataframe that contains the cumulative equity and debt cashflows'''

    # construct df
    df_cumulative_equity_and_debt = pd.DataFrame(columns=construct_calendar_year_list(lifetime_investment_variable))
    df_cumulative_equity_and_debt.columns.name = "cumulative equity and debt"
    
    ### function 
    def cumulative_equity_cashflow():
        ''' This function calculates the cumulative equity cashflow'''

        cumulative_equity_cashflow_list = []
        equity_cash_flow_result = (equity_funding(pipeline_capex_variable,
                                                  compression_capex_variable,
                                                  df_opex_variable,
                                                  df_opex_compressor_variable,
                                                  df_compressor_power_costs_variable,
                                                  inflation_variable,
                                                  df_revenues_transport_tariffs,
                                                  df_revenues_connection_tariffs,
                                                  decommissioning_variable,
                                                  loan_percentage_variable,
                                                  loan_interest_rate_variable,
                                                  income_tax_rate_variable,
                                                  lifetime_investment_variable,
                                                  pipeline_length_variable).loc['equity_cash_flow_result'].tolist())

        for i, x in enumerate(construct_calendar_year_list(lifetime_investment_variable)): 
            if x == tender_year:
                cumulative_equity_cashflow_list.append(equity_cash_flow_result[i])

            else:
                cumulative_equity_cashflow_list.append(equity_cash_flow_result[i] + cumulative_equity_cashflow_list[i-1])

        return cumulative_equity_cashflow_list

    # add cumulative equity cashflow to df
    df_cumulative_equity_and_debt.loc['cumulative_equity_cashflow'] = cumulative_equity_cashflow()

    #### function to calculate cumulative debt cashflow
    def cumulative_debt_cashflow():
        '''This function calculates the cumulative debt cashflow'''

        cumulative_debt_cashflow_list = []

        for x in construct_calendar_year_list(lifetime_investment_variable):
            cumulative_debt_cashflow_list.append(-debt_and_loan_part1(pipeline_capex_variable,
                                                                      compression_capex_variable,
                                                                      loan_percentage_variable,
                                                                      loan_interest_rate_variable,
                                                                      lifetime_investment_variable, 
                                                                      pipeline_length_variable).loc['end_of_year',x])

        return cumulative_debt_cashflow_list
    
    # add cumulative debt cashflow to df
    df_cumulative_equity_and_debt.loc['cumulative_debt_cashflow'] = cumulative_debt_cashflow()
    
    return df_cumulative_equity_and_debt

# %%
cumulative_equity_and_debt_cashflows(pipeline_capex, 
                                     compression_capex, 
                                     df_HT_opex,
                                     df_opex_compressor,
                                     df_HT_compressor_power_costs,
                                     HT_inflation,
                                     df_HT_revenues_transport, 
                                     df_HT_revenues_connections,
                                     HT_decomissioning_percentage,
                                     HT_loan_percentage,
                                     HT_loan_interest_rate,
                                     HT_income_tax_rate,
                                     HT_lifetime,
                                     pipeline_distance).style.format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_14290">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cumulative equity and debt</th>
#       <th id="T_14290_level0_col0" class="col_heading level0 col0" >2045</th>
#       <th id="T_14290_level0_col1" class="col_heading level0 col1" >2046</th>
#       <th id="T_14290_level0_col2" class="col_heading level0 col2" >2047</th>
#       <th id="T_14290_level0_col3" class="col_heading level0 col3" >2048</th>
#       <th id="T_14290_level0_col4" class="col_heading level0 col4" >2049</th>
#       <th id="T_14290_level0_col5" class="col_heading level0 col5" >2050</th>
#       <th id="T_14290_level0_col6" class="col_heading level0 col6" >2051</th>
#       <th id="T_14290_level0_col7" class="col_heading level0 col7" >2052</th>
#       <th id="T_14290_level0_col8" class="col_heading level0 col8" >2053</th>
#       <th id="T_14290_level0_col9" class="col_heading level0 col9" >2054</th>
#       <th id="T_14290_level0_col10" class="col_heading level0 col10" >2055</th>
#       <th id="T_14290_level0_col11" class="col_heading level0 col11" >2056</th>
#       <th id="T_14290_level0_col12" class="col_heading level0 col12" >2057</th>
#       <th id="T_14290_level0_col13" class="col_heading level0 col13" >2058</th>
#       <th id="T_14290_level0_col14" class="col_heading level0 col14" >2059</th>
#       <th id="T_14290_level0_col15" class="col_heading level0 col15" >2060</th>
#       <th id="T_14290_level0_col16" class="col_heading level0 col16" >2061</th>
#       <th id="T_14290_level0_col17" class="col_heading level0 col17" >2062</th>
#       <th id="T_14290_level0_col18" class="col_heading level0 col18" >2063</th>
#       <th id="T_14290_level0_col19" class="col_heading level0 col19" >2064</th>
#       <th id="T_14290_level0_col20" class="col_heading level0 col20" >2065</th>
#       <th id="T_14290_level0_col21" class="col_heading level0 col21" >2066</th>
#       <th id="T_14290_level0_col22" class="col_heading level0 col22" >2067</th>
#       <th id="T_14290_level0_col23" class="col_heading level0 col23" >2068</th>
#       <th id="T_14290_level0_col24" class="col_heading level0 col24" >2069</th>
#       <th id="T_14290_level0_col25" class="col_heading level0 col25" >2070</th>
#       <th id="T_14290_level0_col26" class="col_heading level0 col26" >2071</th>
#       <th id="T_14290_level0_col27" class="col_heading level0 col27" >2072</th>
#       <th id="T_14290_level0_col28" class="col_heading level0 col28" >2073</th>
#       <th id="T_14290_level0_col29" class="col_heading level0 col29" >2074</th>
#       <th id="T_14290_level0_col30" class="col_heading level0 col30" >2075</th>
#       <th id="T_14290_level0_col31" class="col_heading level0 col31" >2076</th>
#       <th id="T_14290_level0_col32" class="col_heading level0 col32" >2077</th>
#       <th id="T_14290_level0_col33" class="col_heading level0 col33" >2078</th>
#       <th id="T_14290_level0_col34" class="col_heading level0 col34" >2079</th>
#       <th id="T_14290_level0_col35" class="col_heading level0 col35" >2080</th>
#       <th id="T_14290_level0_col36" class="col_heading level0 col36" >2081</th>
#       <th id="T_14290_level0_col37" class="col_heading level0 col37" >2082</th>
#       <th id="T_14290_level0_col38" class="col_heading level0 col38" >2083</th>
#       <th id="T_14290_level0_col39" class="col_heading level0 col39" >2084</th>
#       <th id="T_14290_level0_col40" class="col_heading level0 col40" >2085</th>
#       <th id="T_14290_level0_col41" class="col_heading level0 col41" >2086</th>
#       <th id="T_14290_level0_col42" class="col_heading level0 col42" >2087</th>
#       <th id="T_14290_level0_col43" class="col_heading level0 col43" >2088</th>
#       <th id="T_14290_level0_col44" class="col_heading level0 col44" >2089</th>
#       <th id="T_14290_level0_col45" class="col_heading level0 col45" >2090</th>
#       <th id="T_14290_level0_col46" class="col_heading level0 col46" >2091</th>
#       <th id="T_14290_level0_col47" class="col_heading level0 col47" >2092</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14290_level0_row0" class="row_heading level0 row0" >cumulative_equity_cashflow</th>
#       <td id="T_14290_row0_col0" class="data row0 col0" >-130.79</td>
#       <td id="T_14290_row0_col1" class="data row0 col1" >-261.58</td>
#       <td id="T_14290_row0_col2" class="data row0 col2" >-392.37</td>
#       <td id="T_14290_row0_col3" class="data row0 col3" >-523.16</td>
#       <td id="T_14290_row0_col4" class="data row0 col4" >-653.95</td>
#       <td id="T_14290_row0_col5" class="data row0 col5" >-784.74</td>
#       <td id="T_14290_row0_col6" class="data row0 col6" >-1141.11</td>
#       <td id="T_14290_row0_col7" class="data row0 col7" >-1502.61</td>
#       <td id="T_14290_row0_col8" class="data row0 col8" >-1869.34</td>
#       <td id="T_14290_row0_col9" class="data row0 col9" >-2241.40</td>
#       <td id="T_14290_row0_col10" class="data row0 col10" >-2618.90</td>
#       <td id="T_14290_row0_col11" class="data row0 col11" >-3001.95</td>
#       <td id="T_14290_row0_col12" class="data row0 col12" >-3390.66</td>
#       <td id="T_14290_row0_col13" class="data row0 col13" >-3785.13</td>
#       <td id="T_14290_row0_col14" class="data row0 col14" >-4185.50</td>
#       <td id="T_14290_row0_col15" class="data row0 col15" >-4591.87</td>
#       <td id="T_14290_row0_col16" class="data row0 col16" >-5004.37</td>
#       <td id="T_14290_row0_col17" class="data row0 col17" >-5423.12</td>
#       <td id="T_14290_row0_col18" class="data row0 col18" >-5848.24</td>
#       <td id="T_14290_row0_col19" class="data row0 col19" >-6279.86</td>
#       <td id="T_14290_row0_col20" class="data row0 col20" >-7151.11</td>
#       <td id="T_14290_row0_col21" class="data row0 col21" >-7596.12</td>
#       <td id="T_14290_row0_col22" class="data row0 col22" >-8048.03</td>
#       <td id="T_14290_row0_col23" class="data row0 col23" >-8506.98</td>
#       <td id="T_14290_row0_col24" class="data row0 col24" >-8973.10</td>
#       <td id="T_14290_row0_col25" class="data row0 col25" >-9446.55</td>
#       <td id="T_14290_row0_col26" class="data row0 col26" >-9927.46</td>
#       <td id="T_14290_row0_col27" class="data row0 col27" >-10415.99</td>
#       <td id="T_14290_row0_col28" class="data row0 col28" >-10912.29</td>
#       <td id="T_14290_row0_col29" class="data row0 col29" >-11416.51</td>
#       <td id="T_14290_row0_col30" class="data row0 col30" >-11928.82</td>
#       <td id="T_14290_row0_col31" class="data row0 col31" >-12449.37</td>
#       <td id="T_14290_row0_col32" class="data row0 col32" >-12978.33</td>
#       <td id="T_14290_row0_col33" class="data row0 col33" >-13515.86</td>
#       <td id="T_14290_row0_col34" class="data row0 col34" >-14062.15</td>
#       <td id="T_14290_row0_col35" class="data row0 col35" >-15200.11</td>
#       <td id="T_14290_row0_col36" class="data row0 col36" >-15664.33</td>
#       <td id="T_14290_row0_col37" class="data row0 col37" >-16137.84</td>
#       <td id="T_14290_row0_col38" class="data row0 col38" >-16620.81</td>
#       <td id="T_14290_row0_col39" class="data row0 col39" >-17113.44</td>
#       <td id="T_14290_row0_col40" class="data row0 col40" >-17615.93</td>
#       <td id="T_14290_row0_col41" class="data row0 col41" >-18128.46</td>
#       <td id="T_14290_row0_col42" class="data row0 col42" >-18651.25</td>
#       <td id="T_14290_row0_col43" class="data row0 col43" >-19184.49</td>
#       <td id="T_14290_row0_col44" class="data row0 col44" >-19728.40</td>
#       <td id="T_14290_row0_col45" class="data row0 col45" >-20283.18</td>
#       <td id="T_14290_row0_col46" class="data row0 col46" >-20257.87</td>
#       <td id="T_14290_row0_col47" class="data row0 col47" >-20259.77</td>
#     </tr>
#     <tr>
#       <th id="T_14290_level0_row1" class="row_heading level0 row1" >cumulative_debt_cashflow</th>
#       <td id="T_14290_row1_col0" class="data row1 col0" >-0.00</td>
#       <td id="T_14290_row1_col1" class="data row1 col1" >-392.37</td>
#       <td id="T_14290_row1_col2" class="data row1 col2" >-784.74</td>
#       <td id="T_14290_row1_col3" class="data row1 col3" >-1177.11</td>

# %% [markdown]
# Discounted cash flows for levelized cost

# %%
def discounted_cashflows_for_levelized_cost(pipeline_capex_variable,
                                            compression_capex_variable,
                                            df_opex_variable,
                                            df_opex_compressor_variable,
                                            df_compressor_power_costs_variable,
                                            inflation_variable,
                                            df_revenues_transport_tariffs,
                                            df_revenues_connection_tariffs,
                                            decommissioning_variable,
                                            loan_percentage_variable,
                                            loan_interest_rate_variable,
                                            income_tax_rate_variable,
                                            wacc_variable,
                                            lifetime_investment_variable,
                                            pipeline_length_variable):
    '''This function creates a dataframe that contains the discounted cashflows for levelized cost calculations'''

    # construct df
    df_discounted_cashflows_for_levelized_cost = pd.DataFrame(columns=construct_calendar_year_list(lifetime_investment_variable))
    df_discounted_cashflows_for_levelized_cost.columns.name = "discounted cashflows for levelized cost"
    
    # set up variables for calculations
    pipeline_capex = construction_phase(pipeline_capex_variable, compression_capex_variable, inflation_variable, lifetime_investment_variable, pipeline_length_variable).loc['pipeline_capex']
    compression_capex = construction_phase(pipeline_capex_variable, compression_capex_variable, inflation_variable, lifetime_investment_variable, pipeline_length_variable).loc['compression_capex']
    
    time = construct_business_case_year_list(lifetime_investment_variable)
    discount_term = (1 + wacc_variable) ** time

    # calculate dicounted capex and add to df
    df_discounted_cashflows_for_levelized_cost.loc['pipeline_capex'] = pipeline_capex / discount_term
    df_discounted_cashflows_for_levelized_cost.loc['compression_capex'] = compression_capex / discount_term

    df_operational_phase = operational_phase(df_opex_variable,
                                            df_opex_compressor_variable,
                                            df_compressor_power_costs_variable,
                                            inflation_variable,
                                            df_revenues_transport_tariffs,
                                            df_revenues_connection_tariffs,
                                            lifetime_investment_variable,
                                            pipeline_length_variable)

    # calculate discounted opex and add to df
    opex = df_operational_phase.loc['opex']
    opex_compressor = df_operational_phase.loc['opex_compressor']
    compressor_power_consumption = df_operational_phase.loc['compressor_power_consumption']

    df_discounted_cashflows_for_levelized_cost.loc['opex'] = opex / discount_term
    df_discounted_cashflows_for_levelized_cost.loc['opex_compressor'] = opex_compressor / discount_term
    df_discounted_cashflows_for_levelized_cost.loc['compressor_power_consumption'] = compressor_power_consumption / discount_term

    # calculate discounted decomissioning cost
    df_decommissioning_phase = decommissioning_phase(pipeline_capex_variable,
                                                          compression_capex_variable,
                                                          inflation_variable, 
                                                          decommissioning_variable, 
                                                          lifetime_investment_variable, 
                                                          pipeline_length_variable)
    
    pipeline_decommissioning_cost = df_decommissioning_phase.loc['pipeline_decommissioning_cost']
    compressor_decommissioning_cost = df_decommissioning_phase.loc['compressor_decommissioning_cost']
    
    df_discounted_cashflows_for_levelized_cost.loc['decommissioning_pipeline'] = pipeline_decommissioning_cost / discount_term 
    df_discounted_cashflows_for_levelized_cost.loc['decommissioning_compressor'] = compressor_decommissioning_cost / discount_term


    # calculate discounted interest costs
    interest_costs = (taxes_and_profits_part2(pipeline_capex_variable,
                                              compression_capex_variable,
                                              df_opex_variable,
                                              df_opex_compressor_variable,
                                              df_compressor_power_costs_variable,
                                              inflation_variable,
                                              df_revenues_transport_tariffs,
                                              df_revenues_connection_tariffs,
                                              loan_percentage_variable,
                                              loan_interest_rate_variable,
                                              income_tax_rate_variable,
                                              lifetime_investment_variable,
                                              pipeline_length_variable).loc['interest_costs'])
    
    df_discounted_cashflows_for_levelized_cost.loc['interest_costs'] = interest_costs / discount_term

    # calculate discounted contingency injection
    contingency_injection = project_reserves(pipeline_capex_variable,
                                             compression_capex_variable,
                                             lifetime_investment_variable, 
                                             pipeline_length_variable).loc['contingency_injection']
    
    contingency_to_dividents = project_reserves(pipeline_capex_variable,
                                                compression_capex_variable,
                                                lifetime_investment_variable,
                                                pipeline_length_variable).loc['contingency_reserve_to_dividents']
    
    df_discounted_cashflows_for_levelized_cost.loc['contingency'] = ((contingency_injection + contingency_to_dividents) / 
                                                                     discount_term)

    # calculate discounted tax expenses
    tax_expenses = (taxes_and_profits_part2(pipeline_capex_variable,
                                            compression_capex_variable,
                                            df_opex_variable,
                                            df_opex_compressor_variable,
                                            df_compressor_power_costs_variable,
                                            inflation_variable,
                                            df_revenues_transport_tariffs,
                                            df_revenues_connection_tariffs,
                                            loan_percentage_variable,
                                            loan_interest_rate_variable,
                                            income_tax_rate_variable,
                                            lifetime_investment_variable,
                                            pipeline_length_variable).loc['tax_expenses'])
    
    df_discounted_cashflows_for_levelized_cost.loc['tax_expenses'] = tax_expenses / discount_term

    # calculate discounted revenues 
    revenues_connection = df_operational_phase.loc['revenues_connection_tariffs']
    revenues_transport = df_operational_phase.loc['revenues_transport_tariffs']
    
    df_discounted_cashflows_for_levelized_cost.loc['revenues_connection_tariffs'] = revenues_connection / discount_term
    df_discounted_cashflows_for_levelized_cost.loc['revenues_transport_tariffs'] = revenues_transport / discount_term
    
    #### function   
    def total_electricity_produced(): 
        '''This function discounts the total electricity produced during the operational years'''

        total_electricity_produced_list = []

        for i, x in enumerate(construct_calendar_year_list(lifetime_investment_variable)):
            if x in construct_operations_years_list(lifetime_investment_variable):
                total_electricity_produced_list.append((HT_hydrogen_volume.loc['HT_hydrogen_volume',x]) / (1 + wacc_variable) ** i)

            else: 
                total_electricity_produced_list.append(0)
        
        return total_electricity_produced_list

    # add total electricity produced to df
    df_discounted_cashflows_for_levelized_cost.loc['total_electricity_transported'] = total_electricity_produced()
    
    return df_discounted_cashflows_for_levelized_cost

# %%
discounted_cashflows_for_levelized_cost(pipeline_capex, 
                                        compression_capex, 
                                        df_HT_opex,
                                        df_opex_compressor,
                                        df_HT_compressor_power_costs,
                                        HT_inflation,
                                        df_HT_revenues_transport, 
                                        df_HT_revenues_connections,
                                        HT_decomissioning_percentage,
                                        HT_loan_percentage,
                                        HT_loan_interest_rate,
                                        HT_income_tax_rate,
                                        HT_general_WACC,
                                        HT_lifetime,
                                        pipeline_distance).style.format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f5f33">
#   <thead>
#     <tr>
#       <th class="index_name level0" >discounted cashflows for levelized cost</th>
#       <th id="T_f5f33_level0_col0" class="col_heading level0 col0" >2045</th>
#       <th id="T_f5f33_level0_col1" class="col_heading level0 col1" >2046</th>
#       <th id="T_f5f33_level0_col2" class="col_heading level0 col2" >2047</th>
#       <th id="T_f5f33_level0_col3" class="col_heading level0 col3" >2048</th>
#       <th id="T_f5f33_level0_col4" class="col_heading level0 col4" >2049</th>
#       <th id="T_f5f33_level0_col5" class="col_heading level0 col5" >2050</th>
#       <th id="T_f5f33_level0_col6" class="col_heading level0 col6" >2051</th>
#       <th id="T_f5f33_level0_col7" class="col_heading level0 col7" >2052</th>
#       <th id="T_f5f33_level0_col8" class="col_heading level0 col8" >2053</th>
#       <th id="T_f5f33_level0_col9" class="col_heading level0 col9" >2054</th>
#       <th id="T_f5f33_level0_col10" class="col_heading level0 col10" >2055</th>
#       <th id="T_f5f33_level0_col11" class="col_heading level0 col11" >2056</th>
#       <th id="T_f5f33_level0_col12" class="col_heading level0 col12" >2057</th>
#       <th id="T_f5f33_level0_col13" class="col_heading level0 col13" >2058</th>
#       <th id="T_f5f33_level0_col14" class="col_heading level0 col14" >2059</th>
#       <th id="T_f5f33_level0_col15" class="col_heading level0 col15" >2060</th>
#       <th id="T_f5f33_level0_col16" class="col_heading level0 col16" >2061</th>
#       <th id="T_f5f33_level0_col17" class="col_heading level0 col17" >2062</th>
#       <th id="T_f5f33_level0_col18" class="col_heading level0 col18" >2063</th>
#       <th id="T_f5f33_level0_col19" class="col_heading level0 col19" >2064</th>
#       <th id="T_f5f33_level0_col20" class="col_heading level0 col20" >2065</th>
#       <th id="T_f5f33_level0_col21" class="col_heading level0 col21" >2066</th>
#       <th id="T_f5f33_level0_col22" class="col_heading level0 col22" >2067</th>
#       <th id="T_f5f33_level0_col23" class="col_heading level0 col23" >2068</th>
#       <th id="T_f5f33_level0_col24" class="col_heading level0 col24" >2069</th>
#       <th id="T_f5f33_level0_col25" class="col_heading level0 col25" >2070</th>
#       <th id="T_f5f33_level0_col26" class="col_heading level0 col26" >2071</th>
#       <th id="T_f5f33_level0_col27" class="col_heading level0 col27" >2072</th>
#       <th id="T_f5f33_level0_col28" class="col_heading level0 col28" >2073</th>
#       <th id="T_f5f33_level0_col29" class="col_heading level0 col29" >2074</th>
#       <th id="T_f5f33_level0_col30" class="col_heading level0 col30" >2075</th>
#       <th id="T_f5f33_level0_col31" class="col_heading level0 col31" >2076</th>
#       <th id="T_f5f33_level0_col32" class="col_heading level0 col32" >2077</th>
#       <th id="T_f5f33_level0_col33" class="col_heading level0 col33" >2078</th>
#       <th id="T_f5f33_level0_col34" class="col_heading level0 col34" >2079</th>
#       <th id="T_f5f33_level0_col35" class="col_heading level0 col35" >2080</th>
#       <th id="T_f5f33_level0_col36" class="col_heading level0 col36" >2081</th>
#       <th id="T_f5f33_level0_col37" class="col_heading level0 col37" >2082</th>
#       <th id="T_f5f33_level0_col38" class="col_heading level0 col38" >2083</th>
#       <th id="T_f5f33_level0_col39" class="col_heading level0 col39" >2084</th>
#       <th id="T_f5f33_level0_col40" class="col_heading level0 col40" >2085</th>
#       <th id="T_f5f33_level0_col41" class="col_heading level0 col41" >2086</th>
#       <th id="T_f5f33_level0_col42" class="col_heading level0 col42" >2087</th>
#       <th id="T_f5f33_level0_col43" class="col_heading level0 col43" >2088</th>
#       <th id="T_f5f33_level0_col44" class="col_heading level0 col44" >2089</th>
#       <th id="T_f5f33_level0_col45" class="col_heading level0 col45" >2090</th>
#       <th id="T_f5f33_level0_col46" class="col_heading level0 col46" >2091</th>
#       <th id="T_f5f33_level0_col47" class="col_heading level0 col47" >2092</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5f33_level0_row0" class="row_heading level0 row0" >pipeline_capex</th>
#       <td id="T_f5f33_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_f5f33_row0_col1" class="data row0 col1" >-278.89</td>
#       <td id="T_f5f33_row0_col2" class="data row0 col2" >-268.16</td>
#       <td id="T_f5f33_row0_col3" class="data row0 col3" >-257.85</td>
#       <td id="T_f5f33_row0_col4" class="data row0 col4" >-247.93</td>
#       <td id="T_f5f33_row0_col5" class="data row0 col5" >-238.39</td>
#       <td id="T_f5f33_row0_col6" class="data row0 col6" >0.00</td>
#       <td id="T_f5f33_row0_col7" class="data row0 col7" >0.00</td>
#       <td id="T_f5f33_row0_col8" class="data row0 col8" >0.00</td>
#       <td id="T_f5f33_row0_col9" class="data row0 col9" >0.00</td>
#       <td id="T_f5f33_row0_col10" class="data row0 col10" >0.00</td>
#       <td id="T_f5f33_row0_col11" class="data row0 col11" >0.00</td>
#       <td id="T_f5f33_row0_col12" class="data row0 col12" >0.00</td>
#       <td id="T_f5f33_row0_col13" class="data row0 col13" >0.00</td>
#       <td id="T_f5f33_row0_col14" class="data row0 col14" >0.00</td>
#       <td id="T_f5f33_row0_col15" class="data row0 col15" >0.00</td>
#       <td id="T_f5f33_row0_col16" class="data row0 col16" >0.00</td>
#       <td id="T_f5f33_row0_col17" class="data row0 col17" >0.00</td>
#       <td id="T_f5f33_row0_col18" class="data row0 col18" >0.00</td>
#       <td id="T_f5f33_row0_col19" class="data row0 col19" >0.00</td>
#       <td id="T_f5f33_row0_col20" class="data row0 col20" >0.00</td>
#       <td id="T_f5f33_row0_col21" class="data row0 col21" >0.00</td>
#       <td id="T_f5f33_row0_col22" class="data row0 col22" >0.00</td>
#       <td id="T_f5f33_row0_col23" class="data row0 col23" >0.00</td>
#       <td id="T_f5f33_row0_col24" class="data row0 col24" >0.00</td>
#       <td id="T_f5f33_row0_col25" class="data row0 col25" >0.00</td>
#       <td id="T_f5f33_row0_col26" class="data row0 col26" >0.00</td>
#       <td id="T_f5f33_row0_col27" class="data row0 col27" >0.00</td>
#       <td id="T_f5f33_row0_col28" class="data row0 col28" >0.00</td>
#       <td id="T_f5f33_row0_col29" class="data row0 col29" >0.00</td>
#       <td id="T_f5f33_row0_col30" class="data row0 col30" >0.00</td>
#       <td id="T_f5f33_row0_col31" class="data row0 col31" >0.00</td>
#       <td id="T_f5f33_row0_col32" class="data row0 col32" >0.00</td>
#       <td id="T_f5f33_row0_col33" class="data row0 col33" >0.00</td>
#       <td id="T_f5f33_row0_col34" class="data row0 col34" >0.00</td>
#       <td id="T_f5f33_row0_col35" class="data row0 col35" >0.00</td>
#       <td id="T_f5f33_row0_col36" class="data row0 col36" >0.00</td>
#       <td id="T_f5f33_row0_col37" class="data row0 col37" >0.00</td>
#       <td id="T_f5f33_row0_col38" class="data row0 col38" >0.00</td>
#       <td id="T_f5f33_row0_col39" class="data row0 col39" >0.00</td>
#       <td id="T_f5f33_row0_col40" class="data row0 col40" >0.00</td>
#       <td id="T_f5f33_row0_col41" class="data row0 col41" >0.00</td>
#       <td id="T_f5f33_row0_col42" class="data row0 col42" >0.00</td>
#       <td id="T_f5f33_row0_col43" class="data row0 col43" >0.00</td>
#       <td id="T_f5f33_row0_col44" class="data row0 col44" >0.00</td>
#       <td id="T_f5f33_row0_col45" class="data row0 col45" >0.00</td>
#       <td id="T_f5f33_row0_col46" class="data row0 col46" >0.00</td>
#       <td id="T_f5f33_row0_col47" class="data row0 col47" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_f5f33_level0_row1" class="row_heading level0 row1" >compression_capex</th>
#       <td id="T_f5f33_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_f5f33_row1_col1" class="data row1 col1" >-224.15</td>
#       <td id="T_f5f33_row1_col2" class="data row1 col2" >-215.53</td>
#       <td id="T_f5f33_row1_col3" class="data row1 col3" >-207.24</td>
#       <td id="T_f5f33_row1_col4" class="data row1 col4" >-199.27</td>
#       <td id="T_f5f33_row1_col5" class="data row1 col5" >-191.60</td>
#       <td id="T_f5f33_row1_col6" class="data row1 col6" >0.00</

# %% [markdown]
# Levelized costs

# %%
def levelized_cost_and_revenues(pipeline_capex_variable,
                                compression_capex_variable,
                                df_opex_variable,
                                df_opex_compressor_variable,
                                df_compressor_power_costs_variable,
                                inflation_variable,
                                df_revenues_transport_tariffs,
                                df_revenues_connection_tariffs,
                                decommissioning_variable,
                                loan_percentage_variable,
                                loan_interest_rate_variable,
                                income_tax_rate_variable,
                                wacc_variable,
                                lifetime_investment_variable,
                                pipeline_length_variable):
    ''' This function creates a dataframe that contains the levelized costs and revenues'''

    # construct df
    row_names_levelized_cost = (discounted_cashflows_for_levelized_cost(pipeline_capex_variable,
                                                                        compression_capex_variable,
                                                                        df_opex_variable,
                                                                        df_opex_compressor_variable,
                                                                        df_compressor_power_costs_variable,
                                                                        inflation_variable,
                                                                        df_revenues_transport_tariffs,
                                                                        df_revenues_connection_tariffs,
                                                                        decommissioning_variable,
                                                                        loan_percentage_variable,
                                                                        loan_interest_rate_variable,
                                                                        income_tax_rate_variable,
                                                                        wacc_variable,
                                                                        lifetime_investment_variable,
                                                                        pipeline_length_variable).index.tolist())
    row_names_levelized_cost.pop()

    df_levelized_cost = pd.DataFrame(0.0, index=row_names_levelized_cost, columns=['cost','revenues'])
    df_levelized_cost.columns.name = "levelized cost calculations"

    #### function
    def levelized_cost():
        '''This function calculates the levelized costs and revenues'''

        total_electricity_produced_sum = (discounted_cashflows_for_levelized_cost(pipeline_capex_variable,
                                                                                  compression_capex_variable,
                                                                                  df_opex_variable,
                                                                                  df_opex_compressor_variable,
                                                                                  df_compressor_power_costs_variable,
                                                                                  inflation_variable,
                                                                                  df_revenues_transport_tariffs,
                                                                                  df_revenues_connection_tariffs,
                                                                                  decommissioning_variable,
                                                                                  loan_percentage_variable,
                                                                                  loan_interest_rate_variable,
                                                                                  income_tax_rate_variable,
                                                                                  wacc_variable,
                                                                                  lifetime_investment_variable,
                                                                                  pipeline_length_variable)
                                                                                  .loc['total_electricity_transported'].sum())

        for x in row_names_levelized_cost:

            if (discounted_cashflows_for_levelized_cost(pipeline_capex_variable,
                                                        compression_capex_variable,
                                                        df_opex_variable,
                                                        df_opex_compressor_variable,
                                                        df_compressor_power_costs_variable,
                                                        inflation_variable,
                                                        df_revenues_transport_tariffs,
                                                        df_revenues_connection_tariffs,
                                                        decommissioning_variable,
                                                        loan_percentage_variable,
                                                        loan_interest_rate_variable,
                                                        income_tax_rate_variable,
                                                        wacc_variable,
                                                        lifetime_investment_variable,
                                                        pipeline_length_variable).loc[x].sum() > 0):

                df_levelized_cost.loc[x,'revenues'] = (discounted_cashflows_for_levelized_cost(pipeline_capex_variable,
                                                                                               compression_capex_variable,
                                                                                               df_opex_variable,
                                                                                               df_opex_compressor_variable,
                                                                                               df_compressor_power_costs_variable,
                                                                                               inflation_variable,
                                                                                               df_revenues_transport_tariffs,
                                                                                               df_revenues_connection_tariffs,
                                                                                               decommissioning_variable,
                                                                                               loan_percentage_variable,
                                                                                               loan_interest_rate_variable,
                                                                                               income_tax_rate_variable,
                                                                                               wacc_variable,
                                                                                               lifetime_investment_variable,
                                                                                               pipeline_length_variable)
                                                        .loc[x].sum() * 1E6 / total_electricity_produced_sum)
            else:
                df_levelized_cost.loc[x,'cost'] = (-discounted_cashflows_for_levelized_cost(pipeline_capex_variable,
                                                                                            compression_capex_variable,
                                                                                            df_opex_variable,
                                                                                            df_opex_compressor_variable,
                                                                                            df_compressor_power_costs_variable,
                                                                                            inflation_variable,
                                                                                            df_revenues_transport_tariffs,
                                                                                            df_revenues_connection_tariffs,
                                                                                            decommissioning_variable,
                                                                                            loan_percentage_variable,
                                                                                            loan_interest_rate_variable,
                                                                                            income_tax_rate_variable,
                                                                                            wacc_variable,
                                                                                            lifetime_investment_variable,
                                                                                            pipeline_length_variable)
                                                                                            .loc[x].sum() * 1E6 / total_electricity_produced_sum)

        return df_levelized_cost

    # update df to that obtained from function
    df_levelized_cost = levelized_cost()

    #### function
    def profits():
        '''This function calculates the profits'''

        if df_levelized_cost['cost'].sum() < df_levelized_cost['revenues'].sum():
            profits = df_levelized_cost['revenues'].sum() - df_levelized_cost['cost'].sum()

        else:
            profits = 0

        return profits
    
    # add profits to df
    df_levelized_cost.loc['profits'] = [0,0]
    df_levelized_cost.loc['profits','cost'] = profits()

    #### function   
    def unprofitable_gap():
        '''This function calculates the unprofitable gap'''

        if df_levelized_cost['cost'].sum() > df_levelized_cost['revenues'].sum():
            gap = df_levelized_cost['cost'].sum() - df_levelized_cost['revenues'].sum()

        else:
            gap = 0

        return gap
    
    # add unprofitable gap to df
    df_levelized_cost.loc['unprofitable_gap'] = [0,0]
    df_levelized_cost.loc['unprofitable_gap','revenues'] = unprofitable_gap()

    return df_levelized_cost

# %%
levelized_cost_and_revenues(pipeline_capex, 
                            compression_capex,   
                            df_HT_opex,
                            df_opex_compressor,
                            df_HT_compressor_power_costs,
                            HT_inflation,
                            df_HT_revenues_transport, 
                            df_HT_revenues_connections,
                            HT_decomissioning_percentage,
                            HT_loan_percentage,
                            HT_loan_interest_rate,
                            HT_income_tax_rate,
                            HT_general_WACC,
                            HT_lifetime,
                            pipeline_distance).style.format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_292ed">
#   <thead>
#     <tr>
#       <th class="index_name level0" >levelized cost calculations</th>
#       <th id="T_292ed_level0_col0" class="col_heading level0 col0" >cost</th>
#       <th id="T_292ed_level0_col1" class="col_heading level0 col1" >revenues</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_292ed_level0_row0" class="row_heading level0 row0" >pipeline_capex</th>
#       <td id="T_292ed_row0_col0" class="data row0 col0" >0.95</td>
#       <td id="T_292ed_row0_col1" class="data row0 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_292ed_level0_row1" class="row_heading level0 row1" >compression_capex</th>
#       <td id="T_292ed_row1_col0" class="data row1 col0" >1.71</td>
#       <td id="T_292ed_row1_col1" class="data row1 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_292ed_level0_row2" class="row_heading level0 row2" >opex</th>
#       <td id="T_292ed_row2_col0" class="data row2 col0" >1.01</td>
#       <td id="T_292ed_row2_col1" class="data row2 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_292ed_level0_row3" class="row_heading level0 row3" >opex_compressor</th>
#       <td id="T_292ed_row3_col0" class="data row3 col0" >1.08</td>
#       <td id="T_292ed_row3_col1" class="data row3 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_292ed_level0_row4" class="row_heading level0 row4" >compressor_power_consumption</th>
#       <td id="T_292ed_row4_col0" class="data row4 col0" >2.12</td>
#       <td id="T_292ed_row4_col1" class="data row4 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_292ed_level0_row5" class="row_heading level0 row5" >decommissioning_pipeline</th>
#       <td id="T_292ed_row5_col0" class="data row5 col0" >0.02</td>
#       <td id="T_292ed_row5_col1" class="data row5 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_292ed_level0_row6" class="row_heading level0 row6" >decommissioning_compressor</th>
#       <td id="T_292ed_row6_col0" class="data row6 col0" >0.01</td>
#       <td id="T_292ed_row6_col1" class="data row6 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_292ed_level0_row7" class="row_heading level0 row7" >interest_costs</th>
#       <td id="T_292ed_row7_col0" class="data row7 col0" >0.42</td>
#       <td id="T_292ed_row7_col1" class="data row7 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_292ed_level0_row8" class="row_heading level0 row8" >contingency</th>
#       <td id="T_292ed_row8_col0" class="data row8 col0" >0.08</td>
#       <td id="T_292ed_row8_col1" class="data row8 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_292ed_level0_row9" class="row_heading level0 row9" >tax_expenses</th>
#       <td id="T_292ed_row9_col0" class="data row9 col0" >-0.00</td>
#       <td id="T_292ed_row9_col1" class="data row9 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_292ed_level0_row10" class="row_heading level0 row10" >revenues_connection_tariffs</th>
#       <td id="T_292ed_row10_col0" class="data row10 col0" >-0.00</td>
#       <td id="T_292ed_row10_col1" class="data row10 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_292ed_level0_row11" class="row_heading level0 row11" >revenues_transport_tariffs</th>
#       <td id="T_292ed_row11_col0" class="data row11 col0" >-0.00</td>
#       <td id="T_292ed_row11_col1" class="data row11 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_292ed_level0_row12" class="row_heading level0 row12" >profits</th>
#       <td id="T_292ed_row12_col0" class="data row12 col0" >0.00</td>
#       <td id="T_292ed_row12_col1" class="data row12 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_292ed_level0_row13" class="row_heading level0 row13" >unprofitable_gap</th>
#       <td id="T_292ed_row13_col0" class="data row13 col0" >0.00</td>
#       <td id="T_292ed_row13_col1" class="data row13 col1" >7.40</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Project KPI's

# %%
def project_kpi(pipeline_capex_variable,
                compression_capex_variable,                          
                df_opex_variable,
                df_opex_compressor_variable,
                df_compressor_power_costs_variable,
                inflation_variable,
                df_revenues_transport_tariffs,
                df_revenues_connection_tariffs,
                decommissioning_variable,
                loan_percentage_variable,
                loan_interest_rate_variable,
                income_tax_rate_variable,
                wacc_variable,
                lifetime_investment_variable,
                pipeline_length_variable):
    '''This function creates a dataframe that contains the project KPI's'''

    # create df
    df_project_kpi = pd.DataFrame(columns=['Value','Unit'])
    df_project_kpi.columns.name = "Project KPIs"
    
    # get input data
    sum_net_project_cashflows = present_value_cashflows(pipeline_capex_variable,
                                                        compression_capex_variable,
                                                        df_opex_variable,
                                                        df_opex_compressor_variable,
                                                        df_compressor_power_costs_variable,
                                                        inflation_variable,
                                                        df_revenues_transport_tariffs,
                                                        df_revenues_connection_tariffs,
                                                        decommissioning_variable,
                                                        loan_percentage_variable,
                                                        loan_interest_rate_variable,
                                                        income_tax_rate_variable,
                                                        wacc_variable,
                                                        lifetime_investment_variable,
                                                        pipeline_length_variable).loc['sum_net_project_cash_flows'].tolist()
    
    net_profits = (taxes_and_profits_part2(pipeline_capex_variable,
                                           compression_capex_variable,
                                           df_opex_variable,
                                           df_opex_compressor_variable,
                                           df_compressor_power_costs_variable,
                                           inflation_variable,
                                           df_revenues_transport_tariffs,
                                           df_revenues_connection_tariffs,
                                           loan_percentage_variable,
                                           loan_interest_rate_variable,
                                           income_tax_rate_variable,
                                           lifetime_investment_variable,
                                           pipeline_length_variable).loc['net_profits'].tolist())
    
    total_cashflow_investment = construction_phase(pipeline_capex_variable, 
                                                   compression_capex_variable, 
                                                   inflation_variable,
                                                   lifetime_investment_variable, 
                                                   pipeline_length_variable).loc['total_cashflow_investment'].tolist()

    present_value_net_cashflows = present_value_cashflows(pipeline_capex_variable,
                                                          compression_capex_variable,
                                                          df_opex_variable,
                                                          df_opex_compressor_variable,
                                                          df_compressor_power_costs_variable,
                                                          inflation_variable,
                                                          df_revenues_transport_tariffs,
                                                          df_revenues_connection_tariffs,
                                                          decommissioning_variable,
                                                          loan_percentage_variable,
                                                          loan_interest_rate_variable,
                                                          income_tax_rate_variable,
                                                          wacc_variable,
                                                          lifetime_investment_variable,
                                                          pipeline_length_variable).loc['present_value_net_cashflows'].tolist()
    
    # calculate NPV and add to df
    net_present_value = [npf.npv(wacc_variable,sum_net_project_cashflows), 'MEUR']
    df_project_kpi.loc['net_present_value'] = net_present_value

    # calculate IRR and add to df
    internal_rate_of_return = [npf.irr(sum_net_project_cashflows) * 100,'%']    # timex 100 to give percentage
    df_project_kpi.loc['internal_rate_of_return'] = internal_rate_of_return

    # calculate ROI and add to df
    return_on_investment = [np.array(net_profits).sum() / -np.array(total_cashflow_investment).sum() * 100,'%']
    df_project_kpi.loc['return_on_investment'] = return_on_investment
    
    # calculate PP and add to df
    payback_period = [-np.array(total_cashflow_investment).sum() / 
                      (np.array(net_profits).sum() / lifetime_investment_variable), 'years']
    df_project_kpi.loc['payback_period'] = payback_period


    ##### function
    def discounted_return_on_investment():
        ''' This function calculates the discounted return on investment'''

        pv_investment = 0
        pv_returns = 0

        for i, x in enumerate(construct_calendar_year_list(lifetime_investment_variable)):
            if x in construction_years_list:
                pv_investment = pv_investment + present_value_net_cashflows[i]   

            elif x in construct_operations_years_list(lifetime_investment_variable):
                pv_returns = pv_returns + present_value_net_cashflows[i]       
    
        discounted_roi_list = [(pv_investment + pv_returns) / -pv_investment * 100,'%']     # times 100 to convert to percentage

        return discounted_roi_list
    
    # add discounted ROI to df
    df_project_kpi.loc['discounted_return_on_investment'] = discounted_return_on_investment()

    #### function
    def discounted_payback_period():
        '''This function calculates the discounted payback period'''

        pv_investment = 0
        pv_returns = 0

        for i, x in enumerate(construct_calendar_year_list(lifetime_investment_variable)):
            if x in construction_years_list:
                pv_investment = pv_investment + present_value_net_cashflows[i]   

            elif x in construct_operations_years_list(lifetime_investment_variable):
                pv_returns = pv_returns + present_value_net_cashflows[i]       


        discounted_pp_list = [-pv_investment / (pv_returns / lifetime_investment_variable),'years']
    
        return discounted_pp_list


    #### add discounted payback period to df
    df_project_kpi.loc['discounted_payback_period'] = discounted_payback_period()

    
    return df_project_kpi

# %%
project_kpi(pipeline_capex, 
            compression_capex,                           
            df_HT_opex,
            df_opex_compressor,
            df_HT_compressor_power_costs,
            HT_inflation,
            df_HT_revenues_transport, 
            df_HT_revenues_connections,
            HT_decomissioning_percentage,
            HT_loan_percentage,
            HT_loan_interest_rate,
            HT_income_tax_rate,
            HT_general_WACC,
            HT_lifetime,
            pipeline_distance).style.format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0ece5">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Project KPIs</th>
#       <th id="T_0ece5_level0_col0" class="col_heading level0 col0" >Value</th>
#       <th id="T_0ece5_level0_col1" class="col_heading level0 col1" >Unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ece5_level0_row0" class="row_heading level0 row0" >net_present_value</th>
#       <td id="T_0ece5_row0_col0" class="data row0 col0" >-9338.64</td>
#       <td id="T_0ece5_row0_col1" class="data row0 col1" >MEUR</td>
#     </tr>
#     <tr>
#       <th id="T_0ece5_level0_row1" class="row_heading level0 row1" >internal_rate_of_return</th>
#       <td id="T_0ece5_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_0ece5_row1_col1" class="data row1 col1" >%</td>
#     </tr>
#     <tr>
#       <th id="T_0ece5_level0_row2" class="row_heading level0 row2" >return_on_investment</th>
#       <td id="T_0ece5_row2_col0" class="data row2 col0" >-370.18</td>
#       <td id="T_0ece5_row2_col1" class="data row2 col1" >%</td>
#     </tr>
#     <tr>
#       <th id="T_0ece5_level0_row3" class="row_heading level0 row3" >payback_period</th>
#       <td id="T_0ece5_row3_col0" class="data row3 col0" >-10.81</td>
#       <td id="T_0ece5_row3_col1" class="data row3 col1" >years</td>
#     </tr>
#     <tr>
#       <th id="T_0ece5_level0_row4" class="row_heading level0 row4" >discounted_return_on_investment</th>
#       <td id="T_0ece5_row4_col0" class="data row4 col0" >-403.54</td>
#       <td id="T_0ece5_row4_col1" class="data row4 col1" >%</td>
#     </tr>
#     <tr>
#       <th id="T_0ece5_level0_row5" class="row_heading level0 row5" >discounted_payback_period</th>
#       <td id="T_0ece5_row5_col0" class="data row5 col0" >-13.18</td>
#       <td id="T_0ece5_row5_col1" class="data row5 col1" >years</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Equity KPI's

# %%
def equity_kpi(pipeline_capex_variable,
               compression_capex_variable,                           
               df_opex_variable,
               df_opex_compressor_variable,
               df_compressor_power_costs_variable,
               inflation_variable,
               df_revenues_transport_tariffs,
               df_revenues_connection_tariffs,
               decommissioning_variable,
               loan_percentage_variable,
               loan_interest_rate_variable,
               income_tax_rate_variable,
               wacc_variable,
               lifetime_investment_variable,
               pipeline_length_variable):
    '''This function creates a dataframe that contains the equity KPI's'''

    # construct df
    df_equity_kpi = pd.DataFrame(columns=['Value','Unit'])
    df_equity_kpi.columns.name = "Equity KPIs"
    
    # get input data
    equity_injection = (equity_funding(pipeline_capex_variable,
                                       compression_capex_variable,
                                       df_opex_variable,
                                       df_opex_compressor_variable,
                                       df_compressor_power_costs_variable,
                                       inflation_variable,
                                       df_revenues_transport_tariffs,
                                       df_revenues_connection_tariffs,
                                       decommissioning_variable,
                                       loan_percentage_variable,
                                       loan_interest_rate_variable,
                                       income_tax_rate_variable,
                                       lifetime_investment_variable,
                                       pipeline_length_variable).loc['equity_injection'].tolist())
    
    dividents_results = (equity_funding(pipeline_capex_variable,
                                        compression_capex_variable,  
                                        df_opex_variable,
                                        df_opex_compressor_variable,
                                        df_compressor_power_costs_variable,
                                        inflation_variable,
                                        df_revenues_transport_tariffs,
                                        df_revenues_connection_tariffs,
                                        decommissioning_variable,
                                        loan_percentage_variable,
                                        loan_interest_rate_variable,
                                        income_tax_rate_variable,
                                        lifetime_investment_variable,
                                        pipeline_length_variable).loc['dividents_results'].tolist())
    
    equity_cash_flow_result = (equity_funding(pipeline_capex_variable,
                                              compression_capex_variable,
                                              df_opex_variable,
                                              df_opex_compressor_variable,
                                              df_compressor_power_costs_variable,
                                              inflation_variable,
                                              df_revenues_transport_tariffs,
                                              df_revenues_connection_tariffs,
                                              decommissioning_variable,
                                              loan_percentage_variable,
                                              loan_interest_rate_variable,
                                              income_tax_rate_variable,
                                              lifetime_investment_variable,
                                              pipeline_length_variable).loc['equity_cash_flow_result'].tolist())
    
    present_value_equity_cashflows = present_value_cashflows(pipeline_capex_variable,
                                                             compression_capex_variable,
                                                             df_opex_variable,
                                                             df_opex_compressor_variable,
                                                             df_compressor_power_costs_variable,
                                                             inflation_variable,
                                                             df_revenues_transport_tariffs,
                                                             df_revenues_connection_tariffs,
                                                             decommissioning_variable,
                                                             loan_percentage_variable,
                                                             loan_interest_rate_variable,
                                                             income_tax_rate_variable,
                                                             wacc_variable,
                                                             lifetime_investment_variable,
                                                             pipeline_length_variable).loc['present_value_equity_cashflows'].tolist()
    
    # calculate NPV and add to df
    net_present_value = [npf.npv(wacc_variable,equity_cash_flow_result), 'MEUR']
    df_equity_kpi.loc['net_present_value'] = net_present_value

    # calculate IRR and add to df
    internal_rate_of_return = [npf.irr(equity_cash_flow_result) * 100,'%']    # timex 100 to give percentage
    df_equity_kpi.loc['internal_rate_of_return'] = internal_rate_of_return

    # calculate ROI and add to df
    return_on_investment = [np.array(dividents_results).sum() / -np.array(equity_injection).sum() *100,'%']
    df_equity_kpi.loc['return_of_investment'] = return_on_investment

    # calculate PP and add to df
    payback_period = [-np.array(equity_injection).sum() / (np.array(dividents_results).sum() / lifetime_investment_variable), 'years']
    df_equity_kpi.loc['payback_period'] = payback_period
    
    
    ##### function
    def discounted_return_on_investment():
        '''This function calculates the discounted return on investment'''

        pv_investment = 0
        pv_returns = 0

        for i, x in enumerate(construct_calendar_year_list(lifetime_investment_variable)):
            if x in construction_years_list:
                pv_investment = pv_investment + present_value_equity_cashflows[i]    

            elif x in construct_operations_years_list(lifetime_investment_variable):
                pv_returns = pv_returns + present_value_equity_cashflows[i]     
    
        discounted_roi_list = [(pv_investment + pv_returns) / -pv_investment * 100,'%']     # times 100 to convert to percentage

        return discounted_roi_list
    
    # add discounted ROI to df
    df_equity_kpi.loc['discounted_return_on_investment'] = discounted_return_on_investment()

    #### function
    def discounted_payback_period():
        '''This function calculates the discounted payback period'''

        pv_investment = 0
        pv_returns = 0

        for i, x in enumerate(construct_calendar_year_list(lifetime_investment_variable)):
            if x in construction_years_list:
                pv_investment = pv_investment + present_value_equity_cashflows[i]    

            elif x in construct_operations_years_list(lifetime_investment_variable):
                pv_returns = pv_returns + present_value_equity_cashflows[i]      


        discounted_pp_list = [-pv_investment / (pv_returns / lifetime_investment_variable),'years']
    
        return discounted_pp_list


    # add discounted payback period to df
    df_equity_kpi.loc['discounted_payback_period'] = discounted_payback_period()
    
    return df_equity_kpi

# %%
equity_kpi(pipeline_capex, 
           compression_capex,                      
           df_HT_opex,
           df_opex_compressor,
           df_HT_compressor_power_costs,
           HT_inflation,
           df_HT_revenues_transport, 
           df_HT_revenues_connections,
           HT_decomissioning_percentage,
           HT_loan_percentage,
           HT_loan_interest_rate,
           HT_income_tax_rate,
           HT_general_WACC,
           HT_lifetime,
           pipeline_distance).style.format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_26659">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Equity KPIs</th>
#       <th id="T_26659_level0_col0" class="col_heading level0 col0" >Value</th>
#       <th id="T_26659_level0_col1" class="col_heading level0 col1" >Unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26659_level0_row0" class="row_heading level0 row0" >net_present_value</th>
#       <td id="T_26659_row0_col0" class="data row0 col0" >-8165.41</td>
#       <td id="T_26659_row0_col1" class="data row0 col1" >MEUR</td>
#     </tr>
#     <tr>
#       <th id="T_26659_level0_row1" class="row_heading level0 row1" >internal_rate_of_return</th>
#       <td id="T_26659_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_26659_row1_col1" class="data row1 col1" >%</td>
#     </tr>
#     <tr>
#       <th id="T_26659_level0_row2" class="row_heading level0 row2" >return_of_investment</th>
#       <td id="T_26659_row2_col0" class="data row2 col0" >-961.90</td>
#       <td id="T_26659_row2_col1" class="data row2 col1" >%</td>
#     </tr>
#     <tr>
#       <th id="T_26659_level0_row3" class="row_heading level0 row3" >payback_period</th>
#       <td id="T_26659_row3_col0" class="data row3 col0" >-4.16</td>
#       <td id="T_26659_row3_col1" class="data row3 col1" >years</td>
#     </tr>
#     <tr>
#       <th id="T_26659_level0_row4" class="row_heading level0 row4" >discounted_return_on_investment</th>
#       <td id="T_26659_row4_col0" class="data row4 col0" >-1380.58</td>
#       <td id="T_26659_row4_col1" class="data row4 col1" >%</td>
#     </tr>
#     <tr>
#       <th id="T_26659_level0_row5" class="row_heading level0 row5" >discounted_payback_period</th>
#       <td id="T_26659_row5_col0" class="data row5 col0" >-3.12</td>
#       <td id="T_26659_row5_col1" class="data row5 col1" >years</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Output KPI's

# %%
def output_kpi(pipeline_capex_variable,
               compression_capex_variable,                           
               df_opex_variable,
               df_opex_compressor_variable,
               df_compressor_power_costs_variable,
               inflation_variable,
               df_revenues_transport_tariffs,
               df_revenues_connection_tariffs,
               decommissioning_variable,
               loan_percentage_variable,
               loan_interest_rate_variable,
               income_tax_rate_variable,
               wacc_variable,
               lifetime_investment_variable,
               pipeline_length_variable):
    '''This function creates a dataframe that contains the output KPI's'''

    # construct df
    df_output_kpi = pd.DataFrame(columns=['Value','Unit'])
    df_output_kpi.columns.name = "Output KPIs" 
    
    df_levelized_costs_and_revenues = levelized_cost_and_revenues(pipeline_capex_variable,
                                                                  compression_capex_variable,
                                                                  df_opex_variable,
                                                                  df_opex_compressor_variable,
                                                                  df_compressor_power_costs_variable,
                                                                  inflation_variable,
                                                                  df_revenues_transport_tariffs,
                                                                  df_revenues_connection_tariffs,
                                                                  decommissioning_variable,
                                                                  loan_percentage_variable,
                                                                  loan_interest_rate_variable,
                                                                  income_tax_rate_variable,
                                                                  wacc_variable,
                                                                  lifetime_investment_variable,
                                                                  pipeline_length_variable)

    # calculate levelized costs and add to df
    levelized_costs = [df_levelized_costs_and_revenues['cost'].sum() - 
                       df_levelized_costs_and_revenues.loc['profits','cost'],'Eur/MWh']
    df_output_kpi.loc['levelized_cost'] = levelized_costs
    
    # calculate levelized revenues and add to df
    levelized_revenues = [df_levelized_costs_and_revenues['revenues'].sum() - 
                          df_levelized_costs_and_revenues.loc['unprofitable_gap','revenues'],'Eur/MWh']
    df_output_kpi.loc['levelized_revenues'] = levelized_revenues

    # calculate levelized profits and add to df
    levelized_profits = [df_output_kpi.loc['levelized_revenues','Value'] - df_output_kpi.loc['levelized_cost','Value'],'Eur/MWh']
    df_output_kpi.loc['levelized_profits'] = levelized_profits

    return df_output_kpi

# %%
output_kpi(pipeline_capex, 
           compression_capex,                           
           df_HT_opex,
           df_opex_compressor,
           df_HT_compressor_power_costs,
           HT_inflation,
           df_HT_revenues_transport, 
           df_HT_revenues_connections,
           HT_decomissioning_percentage,
           HT_loan_percentage,
           HT_loan_interest_rate,
           HT_income_tax_rate,
           HT_general_WACC,
           HT_lifetime,
           pipeline_distance).style.format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fe064">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Output KPIs</th>
#       <th id="T_fe064_level0_col0" class="col_heading level0 col0" >Value</th>
#       <th id="T_fe064_level0_col1" class="col_heading level0 col1" >Unit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe064_level0_row0" class="row_heading level0 row0" >levelized_cost</th>
#       <td id="T_fe064_row0_col0" class="data row0 col0" >7.40</td>
#       <td id="T_fe064_row0_col1" class="data row0 col1" >Eur/MWh</td>
#     </tr>
#     <tr>
#       <th id="T_fe064_level0_row1" class="row_heading level0 row1" >levelized_revenues</th>
#       <td id="T_fe064_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_fe064_row1_col1" class="data row1 col1" >Eur/MWh</td>
#     </tr>
#     <tr>
#       <th id="T_fe064_level0_row2" class="row_heading level0 row2" >levelized_profits</th>
#       <td id="T_fe064_row2_col0" class="data row2 col0" >-7.40</td>
#       <td id="T_fe064_row2_col1" class="data row2 col1" >Eur/MWh</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# End of base case business case calculations

# %%
# This is to prevent the script to always run the sensitivity analysis.
# Comment the code to run the sensitivity analsys

# raise SystemExit("Stopping execution before the next section.")

# %% [markdown]
# Sensitivity analysis - manually

# %%
from HT_func_run_all_functions import HT_run_all_functions

# %%
def manual_sensitivity(pipeline_capex_variable,
                       compression_capex_variable,                   
                       df_opex_variable,
                       df_opex_compressor_variable,
                       df_compressor_power_costs_variable,
                       inflation_variable,
                       df_revenues_transport_tariffs,
                       df_revenues_connection_tariffs,
                       decommissioning_variable,
                       loan_percentage_variable,
                       loan_interest_rate_variable,
                       income_tax_rate_variable,
                       wacc_variable,
                       lifetime_investment_variable,
                       pipeline_length_variable):
    '''This function can be used to manually calculate the sensitivity of a paramater,
       for example by assigning a new value to the capex'''
    
    
   # to test the sensitivity of a variable here we manually assign it to x * old-variable

   #  pipeline_capex_variable = pipeline_capex_variable * 1.1
   # compression_capex_variable = compression_capex_variable * 1.1
   #  df_opex_variable = df_opex_variable * 1.1
   # df_opex_compressor_variable = df_opex_compressor_variable * 1.1
   # df_compressor_power_costs_variable = df_compressor_power_costs_variable * 1.1
   #  inflation_variable = inflation_variable * 0.9
   #  df_revenues_connection_tariffs = df_revenues_connection_tariffs * 0.9
   #  df_revenues_transport_tariffs = df_revenues_transport_tariffs * 0.9
   #  loan_percentage_variable = loan_percentage_variable * 0.9
   #  loan_interest_rate_variable = loan_interest_rate_variable * 0.9
   #  income_tax_rate_variable = income_tax_rate_variable * 0.9
    # wacc_variable = wacc_variable * 0.9
    lifetime_investment_variable = int(Decimal(lifetime_investment_variable*0.9).to_integral_value(rounding=ROUND_HALF_UP))
   #  pipeline_length_variable = pipeline_length_variable * 1.1

       # Then all functions are run again, to calculate the new KPI's with the adjusted variable
    HT_run_all_functions(pipeline_capex_variable,
                         compression_capex_variable,
                         df_opex_variable,
                         df_opex_compressor_variable,
                         df_compressor_power_costs_variable,
                         inflation_variable,
                         df_revenues_transport_tariffs,
                         df_revenues_connection_tariffs,
                         decommissioning_variable,
                         loan_percentage_variable,
                         loan_interest_rate_variable,
                         income_tax_rate_variable,
                         wacc_variable,
                         lifetime_investment_variable,
                         pipeline_length_variable)
    
    # This can be used to display the KPI dataframes!

    display(project_kpi(pipeline_capex_variable,
                        compression_capex_variable,                  
                        df_opex_variable,
                        df_opex_compressor_variable,
                        df_compressor_power_costs_variable,
                        inflation_variable,
                        df_revenues_transport_tariffs,
                        df_revenues_connection_tariffs,
                        decommissioning_variable,
                        loan_percentage_variable,
                        loan_interest_rate_variable,
                        income_tax_rate_variable,
                        wacc_variable,
                        lifetime_investment_variable,
                        pipeline_length_variable))

    # display(equity_kpi(pipeline_capex_variable,
    #                    compression_capex_variable,
    #                    df_opex_variable,
    #                    df_opex_compressor_variable,
    #                    df_compressor_power_costs_variable,
    #                    inflation_variable,
    #                    df_revenues_transport_tariffs,
    #                    df_revenues_connection_tariffs,
    #                    decommissioning_variable,
    #                    loan_percentage_variable,
    #                    loan_interest_rate_variable,
    #                    income_tax_rate_variable,
    #                    wacc_variable,
    #                    lifetime_investment_variable,
    #                    pipeline_length_variable))

   #  display(output_kpi(pipeline_capex_variable,
   #                     compression_capex_variable,                  
   #                     df_opex_variable,
   #                     df_opex_compressor_variable,
   #                     df_compressor_power_costs_variable,
   #                     inflation_variable,
   #                     df_revenues_transport_tariffs,
   #                     df_revenues_connection_tariffs,
   #                     decommissioning_variable,
   #                     loan_percentage_variable,
   #                     loan_interest_rate_variable,
   #                     income_tax_rate_variable,
   #                     wacc_variable,
   #                     lifetime_investment_variable,
   #                     pipeline_length_variable))

# %%
manual_sensitivity(pipeline_capex, 
                   compression_capex,                  
                   df_HT_opex,
                   df_opex_compressor,
                   df_HT_compressor_power_costs,
                   HT_inflation,
                   df_HT_revenues_transport, 
                   df_HT_revenues_connections,
                   HT_decomissioning_percentage,
                   HT_loan_percentage,
                   HT_loan_interest_rate,
                   HT_income_tax_rate,
                   HT_general_WACC,
                   HT_lifetime,
                   pipeline_distance)
# Out:
# Project KPIs                           Value   Unit
# net_present_value               -8813.744072   MEUR
# internal_rate_of_return           -37.189219      %
# return_on_investment             -358.769606      %
# payback_period                    -10.034295  years
# discounted_return_on_investment  -386.743436      %
# discounted_payback_period         -12.554777  years

# %% [markdown]
# Sensitivity analysis - automatic

# %%
def sensitivity_analysis(pipeline_capex_variable,
                         compression_capex_variable,            
                         df_opex_variable,
                         df_opex_compressor_variable,
                         df_compressor_power_costs_variable,
                         inflation_variable,
                         df_revenues_transport_tariffs,
                         df_revenues_connection_tariffs,
                         decommissioning_variable,
                         loan_percentage_variable,
                         loan_interest_rate_variable,
                         income_tax_rate_variable,
                         wacc_variable,
                         lifetime_investment_variable,
                         pipeline_length_variable):
    '''This function can be used to automatically calculate the sensitivity of all paramaters
       The sensitivity matrix initially consists of 1's, which each correspond to a variable.
       Then we can write a loop that changes one 1 to 0.9 or 1.1 and re-runs all functions, 
       to automatically check the sensitivities.'''
    
    # first we construct the sensitivity matrix
    sensitivity_matrix = pd.Series(data=1.0,index=range(15))
   
    # then we constuct an empty dataframe that we can put our results into
    df_sensitivity_analaysis_project_npv = pd.DataFrame(0.0, index=input_variables_list, columns = ['- 10%','+ 10%'])
    df_sensitivity_analaysis_project_npv.columns.name = 'project npv' 

    df_sensitivity_analaysis_equity_npv = pd.DataFrame(0.0, index=input_variables_list, columns = ['- 10%','+ 10%'])
    df_sensitivity_analaysis_equity_npv.columns.name = 'equity npv' 

    df_sensitivity_analaysis_levelised_cost = pd.DataFrame(0.0, index=input_variables_list, columns = ['- 10%','+ 10%'])
    df_sensitivity_analaysis_levelised_cost.columns.name = 'levelised cost' 

    df_sensitivity_analaysis_unprofitable_gap = pd.DataFrame(0.0, index=input_variables_list, columns = ['- 10%','+ 10%'])
    df_sensitivity_analaysis_unprofitable_gap.columns.name = 'unprofitable gap' 

    
    for i,x in enumerate(input_variables_list):
        
        #here we change one of the 1's in the sensitivity matrix to 0.9, and set the previous 0.9 back to 1.
        sensitivity_matrix.iloc[i] = 0.9
        sensitivity_matrix.iloc[i-1] = 1

        # each variable is multiplied by the sensitivity matrix
        # for each variable that corresponds to a 1 in the sensitivity matrix, the variable will stay the same
        # for the variable that corresponds to a 0.9 in the sensitivity matrix, the variable will be updated
        pipeline_capex_variable = pipeline_capex_variable * sensitivity_matrix[0]
        compression_capex_variable = compression_capex_variable * sensitivity_matrix[1]
        df_opex_variable = df_opex_variable * sensitivity_matrix[2]
        df_opex_compressor_variable = df_opex_compressor_variable * sensitivity_matrix[3]
        df_compressor_power_costs_variable = df_compressor_power_costs_variable * sensitivity_matrix[4]
        inflation_variable = inflation_variable * sensitivity_matrix[5]
        df_revenues_transport_tariffs = df_revenues_transport_tariffs * sensitivity_matrix[6]
        df_revenues_connection_tariffs = df_revenues_connection_tariffs * sensitivity_matrix[7]
        decommissioning_variable = decommissioning_variable * sensitivity_matrix[8]
        loan_percentage_variable = loan_percentage_variable * sensitivity_matrix[9]
        loan_interest_rate_variable = loan_interest_rate_variable * sensitivity_matrix[10]
        income_tax_rate_variable = income_tax_rate_variable * sensitivity_matrix[11]
        wacc_variable = wacc_variable * sensitivity_matrix[12]
        lifetime_investment_variable = lifetime_investment_variable * sensitivity_matrix[13]
        pipeline_length_variable = pipeline_length_variable * sensitivity_matrix[14]

        #update capex variable with the modified variables
        # capex_variable = total_capex(pipeline_capex_variable, compression_capex_variable, pipeline_length_variable)

        # Now all functions are re-run, to include the updated variable
        HT_run_all_functions(pipeline_capex_variable,
                             compression_capex_variable,             
                             df_opex_variable,
                             df_opex_compressor_variable,
                             df_compressor_power_costs_variable,
                             inflation_variable,
                             df_revenues_transport_tariffs,
                             df_revenues_connection_tariffs,
                             decommissioning_variable,
                             loan_percentage_variable,
                             loan_interest_rate_variable,
                             income_tax_rate_variable,
                             wacc_variable,
                             lifetime_investment_variable,
                             pipeline_length_variable)
        
        # After re-running all functions, we can select the output that we want and add it to our empty dataframe
        # Note that by default the NPV will be added to the df, but this can be changed if desired. 
        # More columns can be added to the df above and additional results can be added. 
        # It is also possible to change: 'net_present_value' to e.g., 'internal_rate_of_return'.
        # Or to change project_kpi to e.g., equity_kpi
        df_sensitivity_analaysis_project_npv.loc[x,'- 10%'] = project_kpi(pipeline_capex_variable,
                                                                          compression_capex_variable,                          
                                                                          df_opex_variable,
                                                                          df_opex_compressor_variable,
                                                                          df_compressor_power_costs_variable,
                                                                          inflation_variable,
                                                                          df_revenues_transport_tariffs,
                                                                          df_revenues_connection_tariffs,
                                                                          decommissioning_variable,
                                                                          loan_percentage_variable,
                                                                          loan_interest_rate_variable,
                                                                          income_tax_rate_variable,
                                                                          wacc_variable,
                                                                          lifetime_investment_variable,
                                                                          pipeline_length_variable).loc['net_present_value','Value']

        df_sensitivity_analaysis_equity_npv.loc[x,'- 10%'] = equity_kpi(pipeline_capex_variable,
                                                                        compression_capex_variable,                           
                                                                        df_opex_variable,
                                                                        df_opex_compressor_variable,
                                                                        df_compressor_power_costs_variable,
                                                                        inflation_variable,
                                                                        df_revenues_transport_tariffs,
                                                                        df_revenues_connection_tariffs,
                                                                        decommissioning_variable,
                                                                        loan_percentage_variable,
                                                                        loan_interest_rate_variable,
                                                                        income_tax_rate_variable,
                                                                        wacc_variable,
                                                                        lifetime_investment_variable,
                                                                        pipeline_length_variable).loc['net_present_value','Value']
        
        df_sensitivity_analaysis_levelised_cost.loc[x,'- 10%'] = output_kpi(pipeline_capex_variable,
                                                                            compression_capex_variable,                           
                                                                            df_opex_variable,
                                                                            df_opex_compressor_variable,
                                                                            df_compressor_power_costs_variable,
                                                                            inflation_variable,
                                                                            df_revenues_transport_tariffs,
                                                                            df_revenues_connection_tariffs,
                                                                            decommissioning_variable,
                                                                            loan_percentage_variable,
                                                                            loan_interest_rate_variable,
                                                                            income_tax_rate_variable,
                                                                            wacc_variable,
                                                                            lifetime_investment_variable,
                                                                            pipeline_length_variable).loc['levelized_cost','Value']
        
        df_sensitivity_analaysis_unprofitable_gap.loc[x,'- 10%'] = output_kpi(pipeline_capex_variable,
                                                                              compression_capex_variable,                           
                                                                              df_opex_variable,
                                                                              df_opex_compressor_variable,
                                                                              df_compressor_power_costs_variable,
                                                                              inflation_variable,
                                                                              df_revenues_transport_tariffs,
                                                                              df_revenues_connection_tariffs,
                                                                              decommissioning_variable,
                                                                              loan_percentage_variable,
                                                                              loan_interest_rate_variable,
                                                                              income_tax_rate_variable,
                                                                              wacc_variable,
                                                                              lifetime_investment_variable,
                                                                              pipeline_length_variable).loc['levelized_profits','Value']

        # Finally, all variables are returned to their orignial value to prepare for the next loop
        pipeline_capex_variable = pipeline_capex_variable / sensitivity_matrix[0]
        compression_capex_variable = compression_capex_variable / sensitivity_matrix[1]
        df_opex_variable = df_opex_variable / sensitivity_matrix[2]
        df_opex_compressor_variable = df_opex_compressor_variable / sensitivity_matrix[3]
        df_compressor_power_costs_variable = df_compressor_power_costs_variable / sensitivity_matrix[4]
        inflation_variable = inflation_variable / sensitivity_matrix[5]
        df_revenues_transport_tariffs = df_revenues_transport_tariffs / sensitivity_matrix[6]
        df_revenues_connection_tariffs = df_revenues_connection_tariffs / sensitivity_matrix[7]
        decommissioning_variable = decommissioning_variable / sensitivity_matrix[8]
        loan_percentage_variable = loan_percentage_variable / sensitivity_matrix[9]
        loan_interest_rate_variable = loan_interest_rate_variable / sensitivity_matrix[10]
        income_tax_rate_variable = income_tax_rate_variable / sensitivity_matrix[11]
        wacc_variable = wacc_variable / sensitivity_matrix[12]
        lifetime_investment_variable = lifetime_investment_variable / sensitivity_matrix[13]
        pipeline_length_variable = pipeline_length_variable / sensitivity_matrix[14]

    # After the first loop, that calculated all the -10% sensitivities, we repeat everything to calculate the +10% sensitivities
    # First the sensitivity_matrix is re-set to the original values
    sensitivity_matrix = pd.Series(data=1.0,index=range(15))

    # Then the second loop is started
    for i,x in enumerate(input_variables_list):
        
        #here we change one of the 1's in the sensitivity matrix to 1.1, and set the previous 0.9 back to 1.
        sensitivity_matrix.iloc[i] = 1.1
        sensitivity_matrix.iloc[i-1] = 1

        # each variable is multiplied by the sensitivity matrix
        # for each variable that corresponds to a 1 in the sensitivity matrix, the variable will stay the same
        # for the variable that corresponds to a 0.9 in the sensitivity matrix, the variable will be updated
        pipeline_capex_variable = pipeline_capex_variable * sensitivity_matrix[0]
        compression_capex_variable = compression_capex_variable * sensitivity_matrix[1]
        df_opex_variable = df_opex_variable * sensitivity_matrix[2]
        df_opex_compressor_variable = df_opex_compressor_variable * sensitivity_matrix[3]
        df_compressor_power_costs_variable = df_compressor_power_costs_variable * sensitivity_matrix[4]
        inflation_variable = inflation_variable * sensitivity_matrix[5]
        df_revenues_transport_tariffs = df_revenues_transport_tariffs * sensitivity_matrix[6]
        df_revenues_connection_tariffs = df_revenues_connection_tariffs * sensitivity_matrix[7]
        decommissioning_variable = decommissioning_variable * sensitivity_matrix[8]
        loan_percentage_variable = loan_percentage_variable * sensitivity_matrix[9]
        loan_interest_rate_variable = loan_interest_rate_variable * sensitivity_matrix[10]
        income_tax_rate_variable = income_tax_rate_variable * sensitivity_matrix[11]
        wacc_variable = wacc_variable * sensitivity_matrix[12]
        lifetime_investment_variable = lifetime_investment_variable * sensitivity_matrix[13]
        pipeline_length_variable = pipeline_length_variable * sensitivity_matrix[14]

        #update capex variable with the modified variables
        # capex_variable = total_capex(pipeline_capex_variable, compression_capex_variable, pipeline_length_variable)

        # Now all functions are re-run, to include the updated variable
        HT_run_all_functions(pipeline_capex_variable,
                             compression_capex_variable,
                             df_opex_variable,
                             df_opex_compressor_variable,
                             df_compressor_power_costs_variable,
                             inflation_variable,
                             df_revenues_transport_tariffs,
                             df_revenues_connection_tariffs,
                             decommissioning_variable,
                             loan_percentage_variable,
                             loan_interest_rate_variable,
                             income_tax_rate_variable,
                             wacc_variable,
                             lifetime_investment_variable,
                             pipeline_length_variable)
        
        # After re-running all functions, we can select the output that we want and add it to our empty dataframe
        # Note that by default the NPV will be added to the df, but this can be changed if desired. 
        # More columns can be added to the df above and additional results can be added. 
        # It is also possible to change: 'net_present_value' to e.g., 'internal_rate_of_return'.
        # Or to change project_kpi to e.g., equity_kpi
        # But in any case, make sure to allign any changes with the -10% sensitivity above!!
        df_sensitivity_analaysis_project_npv.loc[x,'+ 10%'] = project_kpi(pipeline_capex_variable,
                                                                          compression_capex_variable,                          
                                                                          df_opex_variable,
                                                                          df_opex_compressor_variable,
                                                                          df_compressor_power_costs_variable,
                                                                          inflation_variable,
                                                                          df_revenues_transport_tariffs,
                                                                          df_revenues_connection_tariffs,
                                                                          decommissioning_variable,
                                                                          loan_percentage_variable,
                                                                          loan_interest_rate_variable,
                                                                          income_tax_rate_variable,
                                                                          wacc_variable,
                                                                          lifetime_investment_variable,
                                                                          pipeline_length_variable).loc['net_present_value','Value']

        df_sensitivity_analaysis_equity_npv.loc[x,'+ 10%'] = equity_kpi(pipeline_capex_variable,
                                                                        compression_capex_variable,                           
                                                                        df_opex_variable,
                                                                        df_opex_compressor_variable,
                                                                        df_compressor_power_costs_variable,
                                                                        inflation_variable,
                                                                        df_revenues_transport_tariffs,
                                                                        df_revenues_connection_tariffs,
                                                                        decommissioning_variable,
                                                                        loan_percentage_variable,
                                                                        loan_interest_rate_variable,
                                                                        income_tax_rate_variable,
                                                                        wacc_variable,
                                                                        lifetime_investment_variable,
                                                                        pipeline_length_variable).loc['net_present_value','Value']
        
        df_sensitivity_analaysis_levelised_cost.loc[x,'+ 10%'] = output_kpi(pipeline_capex_variable,
                                                                            compression_capex_variable,                           
                                                                            df_opex_variable,
                                                                            df_opex_compressor_variable,
                                                                            df_compressor_power_costs_variable,
                                                                            inflation_variable,
                                                                            df_revenues_transport_tariffs,
                                                                            df_revenues_connection_tariffs,
                                                                            decommissioning_variable,
                                                                            loan_percentage_variable,
                                                                            loan_interest_rate_variable,
                                                                            income_tax_rate_variable,
                                                                            wacc_variable,
                                                                            lifetime_investment_variable,
                                                                            pipeline_length_variable).loc['levelized_cost','Value']
        
        df_sensitivity_analaysis_unprofitable_gap.loc[x,'+ 10%'] = output_kpi(pipeline_capex_variable,
                                                                              compression_capex_variable,                           
                                                                              df_opex_variable,
                                                                              df_opex_compressor_variable,
                                                                              df_compressor_power_costs_variable,
                                                                              inflation_variable,
                                                                              df_revenues_transport_tariffs,
                                                                              df_revenues_connection_tariffs,
                                                                              decommissioning_variable,
                                                                              loan_percentage_variable,
                                                                              loan_interest_rate_variable,
                                                                              income_tax_rate_variable,
                                                                              wacc_variable,
                                                                              lifetime_investment_variable,
                                                                              pipeline_length_variable).loc['levelized_profits','Value']
        
        # Finally, all variables are returned to their orignial value to prepare for the next loop
        pipeline_capex_variable = pipeline_capex_variable / sensitivity_matrix[0]
        compression_capex_variable = compression_capex_variable / sensitivity_matrix[1]
        df_opex_variable = df_opex_variable / sensitivity_matrix[2]
        df_opex_compressor_variable = df_opex_compressor_variable / sensitivity_matrix[3]
        df_compressor_power_costs_variable = df_compressor_power_costs_variable / sensitivity_matrix[4]
        inflation_variable = inflation_variable / sensitivity_matrix[5]
        df_revenues_transport_tariffs = df_revenues_transport_tariffs / sensitivity_matrix[6]
        df_revenues_connection_tariffs = df_revenues_connection_tariffs / sensitivity_matrix[7]
        decommissioning_variable = decommissioning_variable / sensitivity_matrix[8]
        loan_percentage_variable = loan_percentage_variable / sensitivity_matrix[9]
        loan_interest_rate_variable = loan_interest_rate_variable / sensitivity_matrix[10]
        income_tax_rate_variable = income_tax_rate_variable / sensitivity_matrix[11]
        wacc_variable = wacc_variable / sensitivity_matrix[12]
        lifetime_investment_variable = lifetime_investment_variable / sensitivity_matrix[13]
        pipeline_length_variable = pipeline_length_variable / sensitivity_matrix[14]

    return df_sensitivity_analaysis_project_npv, df_sensitivity_analaysis_equity_npv, df_sensitivity_analaysis_levelised_cost, df_sensitivity_analaysis_unprofitable_gap

# %%
(df_sa_project_npv,
 df_sa_equity_npv,
 df_sa_levelized_cost,
 df_sa_unprofitable_gap) = sensitivity_analysis(pipeline_capex, 
                                                compression_capex,                  
                                                df_HT_opex,
                                                df_opex_compressor,
                                                df_HT_compressor_power_costs,
                                                HT_inflation,
                                                df_HT_revenues_transport, 
                                                df_HT_revenues_connections,
                                                HT_decomissioning_percentage,
                                                HT_loan_percentage,
                                                HT_loan_interest_rate,
                                                HT_income_tax_rate,
                                                HT_general_WACC,
                                                HT_lifetime,
                                                pipeline_distance)

# %%
df_sa_project_npv
# Out:
# project npv                                - 10%        + 10%
# pipeline_capex_variable             -9209.516259 -9467.761073
# compression_capex_variable          -9106.974358 -9570.302974
# df_opex_variable                    -9202.011912 -9475.265420
# df_opex_compressor_variable         -9192.964610 -9484.312722
# df_compressor_power_costs_variable  -9052.104051 -9625.173281
# inflation_variable                  -9023.023502 -9671.827358
# df_revenues_transport_tariffs       -9338.638666 -9338.638666
# df_revenues_connection_tariffs      -9338.638666 -9338.638666
# decomissioning_variable             -9334.396940 -9342.880393
# loan_percentage_variable            -9338.638666 -9338.638666
# loan_interest_rate_variable         -9338.638666 -9338.638666
# income_tax_rate_variable            -9338.638666 -9338.638666
# wacc_variable                      -10033.848826 -8715.123184
# lifetime_investment_variable        -8813.744072 -9799.789775
# pipeline_length_variable            -9070.537859 -9606.739473

# %%
df_sa_equity_npv
# Out:
# equity npv                                - 10%        + 10%
# pipeline_capex_variable            -8045.809920 -8285.019981
# compression_capex_variable         -8037.313911 -8293.515990
# df_opex_variable                   -8028.788197 -8302.041705
# df_opex_compressor_variable        -8019.740895 -8311.089007
# df_compressor_power_costs_variable -7878.880336 -8451.949566
# inflation_variable                 -7896.938329 -8448.922456
# df_revenues_transport_tariffs      -8165.414951 -8165.414951
# df_revenues_connection_tariffs     -8165.414951 -8165.414951
# decomissioning_variable            -8161.173224 -8169.656677
# loan_percentage_variable           -8042.572947 -8282.591638
# loan_interest_rate_variable        -8121.041562 -8214.533376
# income_tax_rate_variable           -8165.414951 -8165.414951
# wacc_variable                      -8840.912134 -7559.466731
# lifetime_investment_variable       -7739.819253 -8552.827856
# pipeline_length_variable           -7909.183166 -8421.646735

# %%
df_sa_levelized_cost
# Out:
# levelised cost                         - 10%     + 10%
# pipeline_capex_variable             7.272668  7.522487
# compression_capex_variable          7.202755  7.592401
# df_opex_variable                    7.296693  7.498462
# df_opex_compressor_variable         7.290013  7.505143
# df_compressor_power_costs_variable  7.186002  7.609153
# inflation_variable                  7.164529  7.643603
# df_revenues_transport_tariffs       7.397578  7.397578
# df_revenues_connection_tariffs      7.397578  7.397578
# decomissioning_variable             7.394446  7.400710
# loan_percentage_variable            7.312497  7.495208
# loan_interest_rate_variable         7.336187  7.466987
# income_tax_rate_variable            7.397578  7.397578
# wacc_variable                       7.323728  7.476390
# lifetime_investment_variable        7.335194  7.455514
# pipeline_length_variable            7.171784  7.623372

# %%
df_sa_unprofitable_gap
# Out:
# unprofitable gap                       - 10%     + 10%
# pipeline_capex_variable            -7.272668 -7.522487
# compression_capex_variable         -7.202755 -7.592401
# df_opex_variable                   -7.296693 -7.498462
# df_opex_compressor_variable        -7.290013 -7.505143
# df_compressor_power_costs_variable -7.186002 -7.609153
# inflation_variable                 -7.164529 -7.643603
# df_revenues_transport_tariffs      -7.397578 -7.397578
# df_revenues_connection_tariffs     -7.397578 -7.397578
# decomissioning_variable            -7.394446 -7.400710
# loan_percentage_variable           -7.312497 -7.495208
# loan_interest_rate_variable        -7.336187 -7.466987
# income_tax_rate_variable           -7.397578 -7.397578
# wacc_variable                      -7.323728 -7.476390
# lifetime_investment_variable       -7.335194 -7.455514
# pipeline_length_variable           -7.171784 -7.623372

# %% [markdown]
# Tornado graph from sensitivity analysis

# %%
project_npv_base_case = project_kpi(pipeline_capex, 
                                    compression_capex,                           
                                    df_HT_opex,
                                    df_opex_compressor,
                                    df_HT_compressor_power_costs,
                                    HT_inflation,
                                    df_HT_revenues_transport, 
                                    df_HT_revenues_connections,
                                    HT_decomissioning_percentage,
                                    HT_loan_percentage,
                                    HT_loan_interest_rate,
                                    HT_income_tax_rate,
                                    HT_general_WACC,
                                    HT_lifetime,
                                    pipeline_distance).loc['net_present_value','Value']

equity_npv_base_case = equity_kpi(pipeline_capex, 
                                  compression_capex,                      
                                  df_HT_opex,
                                  df_opex_compressor,
                                  df_HT_compressor_power_costs,
                                  HT_inflation,
                                  df_HT_revenues_transport, 
                                  df_HT_revenues_connections,
                                  HT_decomissioning_percentage,
                                  HT_loan_percentage,
                                  HT_loan_interest_rate,
                                  HT_income_tax_rate,
                                  HT_general_WACC,
                                  HT_lifetime,
                                  pipeline_distance).loc['net_present_value','Value']

levelized_cost_base_case = output_kpi(pipeline_capex, 
                                      compression_capex, 
                                      df_HT_opex,
                                      df_opex_compressor,
                                      df_HT_compressor_power_costs,
                                      HT_inflation,
                                      df_HT_revenues_transport, 
                                      df_HT_revenues_connections,
                                      HT_decomissioning_percentage,
                                      HT_loan_percentage,
                                      HT_loan_interest_rate,
                                      HT_income_tax_rate,
                                      HT_general_WACC,
                                      HT_lifetime,
                                      pipeline_distance).loc['levelized_cost','Value']

unprofitable_gap_base_case = output_kpi(pipeline_capex, 
                                        compression_capex,                           
                                        df_HT_opex,
                                        df_opex_compressor,
                                        df_HT_compressor_power_costs,
                                        HT_inflation,
                                        df_HT_revenues_transport, 
                                        df_HT_revenues_connections,
                                        HT_decomissioning_percentage,
                                        HT_loan_percentage,
                                        HT_loan_interest_rate,
                                        HT_income_tax_rate,
                                        HT_general_WACC,
                                        HT_lifetime,
                                        pipeline_distance).loc['levelized_profits','Value']

# %%
def tornado_plot(df_sa, base_case, sa_type):

    # Create percentage change from the NPV values
    df_sensitivity_analysis_percentage = -(df_sa-base_case)/base_case*100

    # Sort the values. Here we use ascending=True because the default behavior of matplotlib's barh() function (which creates horizontal bar charts) 
    # is to plot the first entry at the bottom and the last entry at the top.
    df_sensitivity_analysis_percentage.sort_values(by='- 10%', key=abs, ascending=True, inplace=True)

    # Data for the tornado plot
    variables = df_sensitivity_analysis_percentage.index.tolist()

    negative_changes = df_sensitivity_analysis_percentage['- 10%'].tolist()
    positive_changes = df_sensitivity_analysis_percentage['+ 10%'].tolist()

    # Create the tornado plot
    fig, ax = plt.subplots(figsize=(8, 6))

    # Define bar positions
    y_pos = np.arange(len(variables))

    # Create horizontal bars
    ax.barh(y_pos, negative_changes, align='center', color='red', label='-10%')
    ax.barh(y_pos, positive_changes, align='center', color='blue', label='+10%')

    # Add a vertical line at the base value (0)
    ax.axvline(x=0, color='black', linestyle='--')

    # Remove underscore from variables for the figure names
    variables = [var.replace("_", " ")
                 .replace("variable", "")
                 .replace("df", "")
                 .strip()
                 .capitalize()
                 .replace("Capex", "CAPEX")
                 .replace("Opex", "OPEX")
                 .replace("Wacc", "WACC") for var in variables]

    # Set y-axis labels
    ax.set_yticks(y_pos)
    ax.set_yticklabels(variables)

    # Add labels and title
    ax.set_xlabel(f'Change in {sa_type} (%)')
    ax.set_title('Sensitivity Analysis')

    # Add grey horizontal grid lines
    ax.grid(True, axis='y', color='grey', linestyle='-', linewidth=0.5, alpha=0.3)

    # Show legend
    ax.legend()

    # Display the plot
    plt.tight_layout()
    plt.show()

# %%
tornado_plot(df_sa_project_npv, project_npv_base_case, 'Project NPV')

# %%
tornado_plot(df_sa_equity_npv,equity_npv_base_case, 'Equity NPV')

# %%
tornado_plot(df_sa_levelized_cost,levelized_cost_base_case, 'Levelized cost')

# %%
tornado_plot(df_sa_unprofitable_gap,unprofitable_gap_base_case, 'Unprofitable gap')

# %% [markdown]
# Cumulative equity and debt figure

# %%
df_cumulative_equity_and_debt_cashflows = cumulative_equity_and_debt_cashflows(pipeline_capex, 
                                                                               compression_capex, 
                                                                               df_HT_opex,
                                                                               df_opex_compressor,
                                                                               df_HT_compressor_power_costs,
                                                                               HT_inflation,
                                                                               df_HT_revenues_transport, 
                                                                               df_HT_revenues_connections,
                                                                               HT_decomissioning_percentage,
                                                                               HT_loan_percentage,
                                                                               HT_loan_interest_rate,
                                                                               HT_income_tax_rate,
                                                                               HT_lifetime,
                                                                               pipeline_distance)

# %%
# Years from 2027 to 2057
years = construct_calendar_year_list(HT_lifetime)  

cumulative_equity_cashflow = df_cumulative_equity_and_debt_cashflows.loc['cumulative_equity_cashflow'].tolist()

cumulative_debt_cashflow = df_cumulative_equity_and_debt_cashflows.loc['cumulative_debt_cashflow'].tolist()

# Set the width of each bar
bar_width = 0.35

# Set the position of the bars on the x-axis
r1 = np.arange(len(years))
r2 = [x + bar_width for x in r1]

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Create bars for cumulative equity cashflow
ax.bar(r1, cumulative_equity_cashflow, color='blue', width=bar_width, label='Equity Cashflow')

# Create bars for cumulative debt cashflow
ax.bar(r2, cumulative_debt_cashflow, color='red', width=bar_width, label='Debt Cashflow')

# Add a horizontal line at y=0
ax.axhline(y=0, color='black', linestyle='--', linewidth=1)

# Add labels and title
ax.set_xlabel('Year')
ax.set_ylabel('Cumulative Cashflow (MEUR)')
ax.set_title('Cumulative Equity and Debt Cashflows')

# Add xticks on the middle of the group bars
ax.set_xticks([r + bar_width/2 for r in range(len(years))])
ax.set_xticklabels(years, rotation=45)

# Add legend
ax.legend()

# Display the plot
plt.tight_layout()
plt.show()
